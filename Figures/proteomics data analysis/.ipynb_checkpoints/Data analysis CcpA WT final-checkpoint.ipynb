# %% [markdown]
# # Contents
#
# This notebook deals with the data analysis of chemostat experiments with wild type _Lactococcus lactis_ MG1363 and a CcpA mutant 445C1. It consist of the protoeme analysis and the analysis of metabolic fluxes, among which amino acid fluxes.
#
# 1. [Imports and create variables](#section1)
# 2. [Import data](#section2)
# 3. [Mappers uniprotID to locus tag](#mappers)
# 4. [Data selection](#data_selection)
# 4.1 [Statistics and interesting proteins](#statistics)
# 4.2 [iBAQs](#iBAQ)
# 5. [Volcano plots](#volcano_plots)
# 6. [Exchange fluxes](#flux)
# 7. [Principal Component analysis](#pca)

# %% [markdown]
# <a id='section1'></a>

# %% [markdown]
# ## 1. Imports and create variables

# %%
import cbmpy as cbm
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import math
import seaborn as sns
import numpy as np

import scipy
import scipy.stats as stats

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

import sys
import os

# %matplotlib inline 
# %load_ext autoreload
# %autoreload 2
# Out:
# CPLEX 12.9.0.0 is not compatible with this version of Python.
#
#
#
# CPLEX not available
#
# *****
# Using GLPK
# *****
#
#
# CBMPy environment
# ******************
# Revision: r689
#
#
# ***********************************************************************
# * Welcome to CBMPy (0.7.25) - PySCeS Constraint Based Modelling       *
# *                http://cbmpy.sourceforge.net                         *
# * Copyright(C) Brett G. Olivier 2014 - 2019                           *
# * Dept. of Systems Bioinformatics                                     *
# * Vrije Universiteit Amsterdam, Amsterdam, The Netherlands            *
# * CBMPy is developed as part of the BeBasic MetaToolKit Project       *
# * Distributed under the GNU GPL v 3.0 licence, see                    *
# * LICENCE (supplied with this release) for details                    *
# ***********************************************************************

# %%
matplotlib.font_manager._rebuild()

# %%
# set font to Helvetica
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Helvetica']

# %%
# set font to Helvetica for seaborn
sns.set(font='sans-serif', rc=sns._orig_rc_params)

# %%
# To show minus sign (-) with seaborn
rcParams['axes.unicode_minus']=False

# %%
# Set workbookDir
workbookDir = os.getcwd()

# %%
# Import model
input_model = 'MG1363_20190628.xml'
sbml_model = os.path.join('models', input_model)
cmod = cbm.readSBML3FBC(sbml_model)

# Fetch the dictionary containing all gene-protein associations
reacgenasc = cmod.getAllGeneProteinAssociations()
genreacasc = cmod.getAllProteinGeneAssociations()
# Out:
# FBC version: 2
# M.getNumReactions: 858
# M.getNumSpecies: 804
# FBC.getNumObjectives: 1
# FBC.getNumParameters: 9
# FBC.getNumGeneProducts: 608
# FluxBounds process1: 0.027
# INFO: Active objective: obj
# Adding objective: obj
# FluxBounds process2: 0.027
# Groups support: <GroupsModelPlugin>
# Group.getNumGroups: 34
#
# SBML3 load time: 2.025

# %% [markdown]
# <a id='section2'></a>

# %% [markdown]
# ## 2. Import data
#
# In this part the dataframe is loaded and indexed

# %% [markdown]
# #### Proteome data

# %%
preprocessed_data = pd.read_csv(os.path.join(workbookDir, "data", "CcpA_chemostat", "20191014_perseusprocessed.txt"), 
                                sep='\t',
                                na_filter = False)
preprocessed_data.head()
# Out:
#   LFQ intensity BvO325_ccpa_MG1363_1 LFQ intensity BvO326_ccpa_MG1363_2  \
# 0                          #!{Type}E                                  E
# 1            #!{C:Group1}ccpa mutant                        ccpa mutant
# 2                   7.10085296630859                   7.24870872497559
# 3                   6.71917390823364                   6.74067831039429
# 4                   8.33607959747314                   8.33189296722412
#
#   LFQ intensity BvO327_ccpa_MG1363_3 LFQ intensity BvO328_ccpa_MG1363_4  \
# 0                                  E                                  E
# 1                        ccpa mutant                        ccpa mutant
# 2                   7.14429378509521                   7.12968969345093
# 3                   6.78864192962646                    6.8233437538147
# 4                   8.33817768096924                   8.37763404846191
#
#   LFQ intensity BvO329_wt_MG1363_1 LFQ intensity BvO330_wt_MG1363_2  \
# 0                                E                                E
# 1                               wt                               wt
# 2                 7.30323934555054                 7.25556182861328
# 3                 6.82106113433838                 6.78719806671143
# 4                 8.35715293884277                 8.41195583343506
#
#   LFQ intensity BvO331_wt_MG1363_3 LFQ intensity BvO332_wt_MG1363_4  \
# 0                                E                                E
# 1                               wt                               wt
# 2                 7.28990077972412                 7.30323934555054
# 3                  6.7553334236145                 6.92593574523926
# 4                 8.30541610717773                 8.27216625213623
#
#   Only identified by site Reverse  ...  \
# 0                       C       C  ...
# 1                                  ...
# 2                                  ...
# 3                                  ...
# 4                                  ...
#
#   Student's T-test Difference ccpa mutant_wt  \
# 0                                          N
# 1
# 2                         -0.132099032402039
# 3                        -0.0544226169586182
# 4                        0.00927329063415527
#
#   Student's T-test Test statistic ccpa mutant_wt Sequence length_  \
# 0                                              N                N
# 1
# 2                             -0.127738180903135              454
# 3                            -0.0521362373986605             1203
# 4                            0.00898240805177244              371
#
#   Average molecular mass Number of theoretical peptides (trypsin/P, 7-30)  \
# 0                      N                                                N
# 1
# 2       51316.8790799999                                               27
# 3       138945.496780001                                               74
# 4            41241.89178                                               21
#
#   Protein IDs Majority protein IDs  \
# 0           T                    T
# 1
# 2      A2RH74               A2RH74
# 3      A2RH77               A2RH77
# 4      A2RH80               A2RH80
#
#                                        Fasta headers Gene name  \
# 0                                                  T         T
# 1
# 2  sw|A2RH74|DNAA_LACLM Chromosomal replication i...      dnaA
# 3  sw|A2RH77|ADDA_LACLM ATP-dependent helicase/nu...      addA
# 4  tr|A2RH80|A2RH80_LACLM Ribosome-binding ATPase...      ychF
#
#                                      Protein name
# 0                                               T
# 1
# 2  Chromosomal replication initiator protein DnaA
# 3       ATP-dependent helicase/nuclease subunit A
# 4                    Ribosome-binding ATPase YchF
#
# [5 rows x 69 columns]

# %%
# Filter first rows
preprocessed_data.drop([0,1],axis=0, inplace=True)
preprocessed_data.head()
# Out:
#   LFQ intensity BvO325_ccpa_MG1363_1 LFQ intensity BvO326_ccpa_MG1363_2  \
# 2                   7.10085296630859                   7.24870872497559
# 3                   6.71917390823364                   6.74067831039429
# 4                   8.33607959747314                   8.33189296722412
# 5                   6.60785150527954                    6.4954195022583
# 6                   6.63816976547241                   6.88871288299561
#
#   LFQ intensity BvO327_ccpa_MG1363_3 LFQ intensity BvO328_ccpa_MG1363_4  \
# 2                   7.14429378509521                   7.12968969345093
# 3                   6.78864192962646                    6.8233437538147
# 4                   8.33817768096924                   8.37763404846191
# 5                   6.38399457931519                   6.56883525848389
# 6                    6.7448091506958                    6.7226505279541
#
#   LFQ intensity BvO329_wt_MG1363_1 LFQ intensity BvO330_wt_MG1363_2  \
# 2                 7.30323934555054                 7.25556182861328
# 3                 6.82106113433838                 6.78719806671143
# 4                 8.35715293884277                 8.41195583343506
# 5                 6.69289064407349                 6.35147190093994
# 6                 7.00509452819824                 6.90873146057129
#
#   LFQ intensity BvO331_wt_MG1363_3 LFQ intensity BvO332_wt_MG1363_4  \
# 2                 7.28990077972412                 7.30323934555054
# 3                  6.7553334236145                 6.92593574523926
# 4                 8.30541610717773                 8.27216625213623
# 5                 6.39392614364624                 6.67344856262207
# 6                 6.65474414825439                  6.8839225769043
#
#   Only identified by site Reverse  ...  \
# 2                                  ...
# 3                                  ...
# 4                                  ...
# 5                                  ...
# 6                                  ...
#
#   Student's T-test Difference ccpa mutant_wt  \
# 2                         -0.132099032402039
# 3                        -0.0544226169586182
# 4                        0.00927329063415527
# 5                        -0.0139091014862061
# 6                         -0.114537596702576
#
#   Student's T-test Test statistic ccpa mutant_wt Sequence length_  \
# 2                             -0.127738180903135              454
# 3                            -0.0521362373986605             1203
# 4                            0.00898240805177244              371
# 5                            -0.0126137867152507              188
# 6                             -0.105017935810577             1180
#
#   Average molecular mass Number of theoretical peptides (trypsin/P, 7-30)  \
# 2       51316.8790799999                                               27
# 3       138945.496780001                                               74
# 4            41241.89178                                               21
# 5            20963.15308                                               12
# 6       135511.065780001                                               63
#
#   Protein IDs Majority protein IDs  \
# 2      A2RH74               A2RH74
# 3      A2RH77               A2RH77
# 4      A2RH80               A2RH80
# 5      A2RH85               A2RH85
# 6      A2RH86               A2RH86
#
#                                        Fasta headers Gene name  \
# 2  sw|A2RH74|DNAA_LACLM Chromosomal replication i...      dnaA
# 3  sw|A2RH77|ADDA_LACLM ATP-dependent helicase/nu...      addA
# 4  tr|A2RH80|A2RH80_LACLM Ribosome-binding ATPase...      ychF
# 5  sw|A2RH85|PTH_LACLM Peptidyl-tRNA hydrolase OS...       pth
# 6  tr|A2RH86|A2RH86_LACLM Transcription-repair-co...       mfd
#
#                                      Protein name
# 2  Chromosomal replication initiator protein DnaA
# 3       ATP-dependent helicase/nuclease subunit A
# 4                    Ribosome-binding ATPase YchF
# 5                         Peptidyl-tRNA hydrolase
# 6            Transcription-repair-coupling factor
#
# [5 rows x 69 columns]

# %%
# Set index
preprocessed_data.set_index('Majority protein IDs', inplace=True)
preprocessed_data.head()
# Out:
#                      LFQ intensity BvO325_ccpa_MG1363_1  \
# Majority protein IDs
# A2RH74                                 7.10085296630859
# A2RH77                                 6.71917390823364
# A2RH80                                 8.33607959747314
# A2RH85                                 6.60785150527954
# A2RH86                                 6.63816976547241
#
#                      LFQ intensity BvO326_ccpa_MG1363_2  \
# Majority protein IDs
# A2RH74                                 7.24870872497559
# A2RH77                                 6.74067831039429
# A2RH80                                 8.33189296722412
# A2RH85                                  6.4954195022583
# A2RH86                                 6.88871288299561
#
#                      LFQ intensity BvO327_ccpa_MG1363_3  \
# Majority protein IDs
# A2RH74                                 7.14429378509521
# A2RH77                                 6.78864192962646
# A2RH80                                 8.33817768096924
# A2RH85                                 6.38399457931519
# A2RH86                                  6.7448091506958
#
#                      LFQ intensity BvO328_ccpa_MG1363_4  \
# Majority protein IDs
# A2RH74                                 7.12968969345093
# A2RH77                                  6.8233437538147
# A2RH80                                 8.37763404846191
# A2RH85                                 6.56883525848389
# A2RH86                                  6.7226505279541
#
#                      LFQ intensity BvO329_wt_MG1363_1  \
# Majority protein IDs
# A2RH74                               7.30323934555054
# A2RH77                               6.82106113433838
# A2RH80                               8.35715293884277
# A2RH85                               6.69289064407349
# A2RH86                               7.00509452819824
#
#                      LFQ intensity BvO330_wt_MG1363_2  \
# Majority protein IDs
# A2RH74                               7.25556182861328
# A2RH77                               6.78719806671143
# A2RH80                               8.41195583343506
# A2RH85                               6.35147190093994
# A2RH86                               6.90873146057129
#
#                      LFQ intensity BvO331_wt_MG1363_3  \
# Majority protein IDs
# A2RH74                               7.28990077972412
# A2RH77                                6.7553334236145
# A2RH80                               8.30541610717773
# A2RH85                               6.39392614364624
# A2RH86                               6.65474414825439
#
#                      LFQ intensity BvO332_wt_MG1363_4 Only identified by site  \
# Majority protein IDs
# A2RH74                               7.30323934555054
# A2RH77                               6.92593574523926
# A2RH80                               8.27216625213623
# A2RH85                               6.67344856262207
# A2RH86                                6.8839225769043
#
#                      Reverse  ... Student's T-test q-value ccpa mutant_wt  \
# Majority protein IDs          ...
# A2RH74                        ...                       0.264639498432602
# A2RH77                        ...                       0.511242174629325
# A2RH80                        ...                       0.912046948356808
# A2RH85                        ...                       0.880636695018226
# A2RH86                        ...                       0.290902564102564
#
#                      Student's T-test Difference ccpa mutant_wt  \
# Majority protein IDs
# A2RH74                                       -0.132099032402039
# A2RH77                                      -0.0544226169586182
# A2RH80                                      0.00927329063415527
# A2RH85                                      -0.0139091014862061
# A2RH86                                       -0.114537596702576
#
#                      Student's T-test Test statistic ccpa mutant_wt  \
# Majority protein IDs
# A2RH74                                           -0.127738180903135
# A2RH77                                          -0.0521362373986605
# A2RH80                                          0.00898240805177244
# A2RH85                                          -0.0126137867152507
# A2RH86                                           -0.105017935810577
#
#                      Sequence length_ Average molecular mass  \
# Majority protein IDs
# A2RH74                            454       51316.8790799999
# A2RH77                           1203       138945.496780001
# A2RH80                            371            41241.89178
# A2RH85                            188            20963.15308
# A2RH86                           1180       135511.065780001
#
#                      Number of theoretical peptides (trypsin/P, 7-30)  \
# Majority protein IDs
# A2RH74                                                             27
# A2RH77                                                             74
# A2RH80                                                             21
# A2RH85                                                             12
# A2RH86                                                             63
#
#                      Protein IDs  \
# Majority protein IDs
# A2RH74                    A2RH74
# A2RH77                    A2RH77
# A2RH80                    A2RH80
# A2RH85                    A2RH85
# A2RH86                    A2RH86
#
#                                                           Fasta headers  \
# Majority protein IDs
# A2RH74                sw|A2RH74|DNAA_LACLM Chromosomal replication i...
# A2RH77                sw|A2RH77|ADDA_LACLM ATP-dependent helicase/nu...
# A2RH80                tr|A2RH80|A2RH80_LACLM Ribosome-binding ATPase...
# A2RH85                sw|A2RH85|PTH_LACLM Peptidyl-tRNA hydrolase OS...
# A2RH86                tr|A2RH86|A2RH86_LACLM Transcription-repair-co...
#
#                      Gene name                                    Protein name
# Majority protein IDs
# A2RH74                    dnaA  Chromosomal replication initiator protein DnaA
# A2RH77                    addA       ATP-dependent helicase/nuclease subunit A
# A2RH80                    ychF                    Ribosome-binding ATPase YchF
# A2RH85                     pth                         Peptidyl-tRNA hydrolase
# A2RH86                     mfd            Transcription-repair-coupling factor
#
# [5 rows x 68 columns]

# %%
# put info first gene
preprocessed_data["Gene names  (ordered locus )"]["A2RH74"]="llmg_0001"
preprocessed_data["Mass"]["A2RH74"]="51,317"

# %%
# Rename very long Majority protein ID which is not in annotations to shorter one
preprocessed_data.rename(index={'A2RJ63_LACLMDNA-invertase/resolvaseOS=Lactococcuslactissubsp.cremoris(strainMG1363)GN=tnpRPE=4SV=1^Atr;A0A1B1H1X6':'A2RJ63'},inplace=True)
preprocessed_data.loc['A2RJ63']
# Out:
# LFQ intensity BvO325_ccpa_MG1363_1                                                    6.2943115234375
# LFQ intensity BvO326_ccpa_MG1363_2                                                   6.30193042755127
# LFQ intensity BvO327_ccpa_MG1363_3                                                   6.51220464706421
# LFQ intensity BvO328_ccpa_MG1363_4                                                   6.04752779006958
# LFQ intensity BvO329_wt_MG1363_1                                                      6.4896068572998
# LFQ intensity BvO330_wt_MG1363_2                                                     6.32504320144653
# LFQ intensity BvO331_wt_MG1363_3                                                     6.29616022109985
# LFQ intensity BvO332_wt_MG1363_4                                                     6.47475528717041
# Only identified by site
# Reverse
# Potential contaminant
# FilteredRows
# Protein names                                                                    Resolvase/intergrase
# Gene names                                                                                   pSH74_09
# Gene names  (primary )
# Gene names  (ordered locus )                                                                 pSH74_09
# Intramembrane                                                                                       0
# Transmembrane                                                                                       0
# Student's T-test Significant ccpa mutant_wt
# Student's T-test significant
# Length                                                                                            184
# EC number
# Gene names  (primary )_
# Gene names  (ordered locus )_                                                                pSH74_09
# Mass                                                                                           20,778
# Gene ontology (biological process)
# Gene ontology (molecular function)                  DNA binding [GO:0003677];recombinase activity ...
# Gene ontology (cellular component)
# Intramembrane_                                                                                      0
# Subcellular location [CC]                                                                           0
#                                                                           ...
# id                                                                                                339
# Number of proteins                                                                                  2
# Peptides                                                                                            2
# Unique peptides                                                                                     2
# Sequence coverage                                                                                13.6
# Mol  weight  kDa                                                                               20.819
# Sequence length                                                                                   184
# Q value                                                                                     0.0097431
# Score                                                                                          1.8001
# Intensity                                                                                     6665700
# iBAQ                                                                                           605970
# iBAQ BvO325_ccpa_MG1363_1                                                                           0
# iBAQ BvO326_ccpa_MG1363_2                                                                           0
# iBAQ BvO327_ccpa_MG1363_3                                                                           0
# iBAQ BvO328_ccpa_MG1363_4                                                                           0
# iBAQ BvO329_wt_MG1363_1                                                                        168190
# iBAQ BvO330_wt_MG1363_2                                                                        141040
# iBAQ BvO331_wt_MG1363_3                                                                        165950
# iBAQ BvO332_wt_MG1363_4                                                                        130800
# -Log Student's T-test p-value ccpa mutant_wt                                        0.448886681919643
# Student's T-test q-value ccpa mutant_wt                                             0.306244604316547
# Student's T-test Difference ccpa mutant_wt                                         -0.107397794723511
# Student's T-test Test statistic ccpa mutant_wt                                    -0.0969862066483383
# Sequence length_                                                                                  184
# Average molecular mass                                                                    20777.70328
# Number of theoretical peptides (trypsin/P, 7-30)                                                   11
# Protein IDs                                         A2RJ63_LACLMDNA-invertase/resolvaseOS=Lactococ...
# Fasta headers                                       tr|A2RJ63|A2RJ63_LACLM DNA-invertase/resolvase...
# Gene name                                                                                    pSH74_09
# Protein name                                                                     Resolvase/intergrase
# Name: A2RJ63, Length: 68, dtype: object

# %%
# Remove these non-lactis proteins:
preprocessed_data.drop(
    ['CON__sp|P00760|TRY1_BOVIN', 'CON__sp|P04264|K2C1_HUMAN', 'CON__sp|P35527|K1C9_HUMAN', 'CON__sp|P35908|K22E_HUMAN'],
    axis=0, inplace=True)

# %%
preprocessed_data['Mass'] = preprocessed_data['Mass'].str.replace(',','.')
preprocessed_data['Mass']
# Out:
# Majority protein IDs
# A2RH74               51.317
# A2RH77              138.945
# A2RH80               41.242
# A2RH85               20.963
# A2RH86              135.511
# A2RH92               20.607
# A2RH93               75.511
# A2RH94               64.139
# A2RH95               74.550
# A2RH96               15.914
# A2RH97               43.946
# A2RHD7               43.220
# A2RHE1               49.866
# A2RHE2               56.331
# A2RHE3               35.165
# A2RHE4               41.352
# A2RHE5               37.783
# A2RHE9               38.119
# A2RHF3               34.749
# A2RHF4               30.331
# A2RHF5               61.519
# A2RHG2               46.279
# A2RHG3               30.822
# A2RHG4               16.597
# A2RHG9                5.997
# A2RHH6               17.857
# A2RHH7               58.305
# A2RHI1               34.818
# A2RHI2               27.740
# A2RHI3               35.512
#                      ...
# P43905               45.804
# P43909               31.030
# P50924               26.169
# P50926               23.231
# P54322               32.930
# P56968               28.660
# P60376               15.030
# P96789               52.460
# pNZ712_21;A2RJ09     10.433
# Q48677               38.324
# Q59491               43.827
# Q7BPI7               36.792
# Q8GJP4               40.261
# Q8GJP6               45.849
# Q9AEP7               57.197
# Q9AEP8               10.199
# Q9AQE3               23.263
# Q9K575               39.468
# Q9K576               45.981
# Q9L4N5               39.637
# Q9L4N6               34.558
# Q9L4N8               19.812
# Q9L6G1               22.461
# Q9RAT9               15.585
# Q9RAU1               32.000
# Q9S5Z2               83.206
# Q9Z5K8               25.677
# Q9Z6H4               56.888
# Q9ZAB0               22.052
# Q9ZAI9               21.938
# Name: Mass, Length: 906, dtype: object

# %%
# Convert mass to float. Take average if two masses noted, because of two locus tags
for i in preprocessed_data[pd.to_numeric(preprocessed_data['Mass'], errors='coerce').isnull()==True]["Mass"].index:
    print i
    print preprocessed_data["Mass"][i].split(";")
    a = [float(j) for j in preprocessed_data["Mass"][i].split(";")]
    preprocessed_data["Mass"][i] = sum(a)/len(a)
    
preprocessed_data["Mass"] = pd.to_numeric(preprocessed_data['Mass'], errors='coerce')
# Out:
# A2RIU1
# ['75.343', '75.544']
# A2RLU6
# ['74.148', '76.438']
# A2RN23
# ['14.052', '18.478']
# A2RN40
# ['3.556', '42.973']

# %%
# Load unimputed LFQ data
LFQ_data = pd.read_csv(os.path.join(workbookDir, "data", "CcpA_chemostat", "20200921_perseus_notimputedLFQ.txt"), 
                                sep='\t',
                                na_filter = False)
# Filter first rows
LFQ_data.drop([0,1],axis=0, inplace=True)

# Set index
LFQ_data.set_index('Majority protein IDs', inplace=True)
LFQ_data.head()

# Put info first gene
LFQ_data["Gene names  (ordered locus )"]["A2RH74"]="llmg_0001"

# Rename very long Majority protein ID which is not in annotations to shorter one
LFQ_data.rename(index={'A2RJ63_LACLMDNA-invertase/resolvaseOS=Lactococcuslactissubsp.cremoris(strainMG1363)GN=tnpRPE=4SV=1^Atr;A0A1B1H1X6':'A2RJ63'},inplace=True)
LFQ_data.loc['A2RJ63']

# Remove these non-lactis proteins:
LFQ_data.drop(
    ['CON__sp|P00760|TRY1_BOVIN', 'CON__sp|P04264|K2C1_HUMAN', 'CON__sp|P35527|K1C9_HUMAN', 'CON__sp|P35908|K22E_HUMAN'],
    axis=0, inplace=True)


LFQ_data.head()
# Out:
#                      LFQ intensity BvO325_ccpa_MG1363_1  \
# Majority protein IDs
# A2RH74                                 7.10085296630859
# A2RH77                                 6.71917390823364
# A2RH80                                 8.33607959747314
# A2RH85                                 6.60785150527954
# A2RH86                                 6.63816976547241
#
#                      LFQ intensity BvO326_ccpa_MG1363_2  \
# Majority protein IDs
# A2RH74                                 7.24870872497559
# A2RH77                                 6.74067831039429
# A2RH80                                 8.33189296722412
# A2RH85                                  6.4954195022583
# A2RH86                                 6.88871288299561
#
#                      LFQ intensity BvO327_ccpa_MG1363_3  \
# Majority protein IDs
# A2RH74                                 7.14429378509521
# A2RH77                                 6.78864192962646
# A2RH80                                 8.33817768096924
# A2RH85                                 6.38399457931519
# A2RH86                                  6.7448091506958
#
#                      LFQ intensity BvO328_ccpa_MG1363_4  \
# Majority protein IDs
# A2RH74                                 7.12968969345093
# A2RH77                                  6.8233437538147
# A2RH80                                 8.37763404846191
# A2RH85                                 6.56883525848389
# A2RH86                                  6.7226505279541
#
#                      LFQ intensity BvO329_wt_MG1363_1  \
# Majority protein IDs
# A2RH74                               7.30323934555054
# A2RH77                               6.82106113433838
# A2RH80                               8.35715293884277
# A2RH85                                            NaN
# A2RH86                               7.00509452819824
#
#                      LFQ intensity BvO330_wt_MG1363_2  \
# Majority protein IDs
# A2RH74                               7.25556182861328
# A2RH77                               6.78719806671143
# A2RH80                               8.41195583343506
# A2RH85                                            NaN
# A2RH86                               6.90873146057129
#
#                      LFQ intensity BvO331_wt_MG1363_3  \
# Majority protein IDs
# A2RH74                               7.28990077972412
# A2RH77                                6.7553334236145
# A2RH80                               8.30541610717773
# A2RH85                               6.39392614364624
# A2RH86                               6.65474414825439
#
#                      LFQ intensity BvO332_wt_MG1363_4 Only identified by site  \
# Majority protein IDs
# A2RH74                               7.30323934555054
# A2RH77                               6.92593574523926
# A2RH80                               8.27216625213623
# A2RH85                                            NaN
# A2RH86                                6.8839225769043
#
#                      Reverse  ... iBAQ BvO325_ccpa_MG1363_1  \
# Majority protein IDs          ...
# A2RH74                        ...                    503550
# A2RH77                        ...                     73609
# A2RH80                        ...                  10535000
# A2RH85                        ...                    315730
# A2RH86                        ...                     85130
#
#                      iBAQ BvO326_ccpa_MG1363_2 iBAQ BvO327_ccpa_MG1363_3  \
# Majority protein IDs
# A2RH74                                  469990                    453810
# A2RH77                                   65513                     68963
# A2RH80                                 7618300                   8036300
# A2RH85                                  212990                    157770
# A2RH86                                   89672                     79897
#
#                      iBAQ BvO328_ccpa_MG1363_4 iBAQ BvO329_wt_MG1363_1  \
# Majority protein IDs
# A2RH74                                  328480                  411060
# A2RH77                                   58480                   42696
# A2RH80                                 7450500                 6227100
# A2RH85                                  179990                  219450
# A2RH86                                   62034                   71645
#
#                      iBAQ BvO330_wt_MG1363_2 iBAQ BvO331_wt_MG1363_3  \
# Majority protein IDs
# A2RH74                                449770                  567280
# A2RH77                                 50434                   82229
# A2RH80                               8327900                 9681700
# A2RH85                                261200                  187040
# A2RH86                                 69212                   73502
#
#                      iBAQ BvO332_wt_MG1363_4 Protein IDs  \
# Majority protein IDs
# A2RH74                                396980      A2RH74
# A2RH77                                 49539      A2RH77
# A2RH80                               5032400      A2RH80
# A2RH85                                 52196      A2RH85
# A2RH86                                 67588      A2RH86
#
#                                                           Fasta headers
# Majority protein IDs
# A2RH74                sw|A2RH74|DNAA_LACLM Chromosomal replication i...
# A2RH77                sw|A2RH77|ADDA_LACLM ATP-dependent helicase/nu...
# A2RH80                tr|A2RH80|A2RH80_LACLM Ribosome-binding ATPase...
# A2RH85                sw|A2RH85|PTH_LACLM Peptidyl-tRNA hydrolase OS...
# A2RH86                tr|A2RH86|A2RH86_LACLM Transcription-repair-co...
#
# [5 rows x 39 columns]

# %% [markdown]
# <a id='mappers'></a>

# %% [markdown]
# ## 3. Create mappers from uniprotID to locus_tag and vice versa

# %%
# Create uniprotID2locustag dict from proteomics entry (uniprot identifier) to locus tag (=llmg code)
uniprotID2locustag = preprocessed_data["Gene names  (ordered locus )"]
uniprotID2locustag = uniprotID2locustag.transpose().to_dict()

# Prevent pNZ712_38 from not being added to new uniprotID2locustag
uniprotID2locustag["pNZ712_38"] = "pNZ712_38"
uniprotID2locustag
# Out:
# {'A2RH74': 'llmg_0001',
#  'A2RH77': 'llmg_0004',
#  'A2RH80': 'llmg_0007',
#  'A2RH85': 'llmg_0012',
#  'A2RH86': 'llmg_0013',
#  'A2RH92': 'llmg_0020',
#  'A2RH93': 'llmg_0021',
#  'A2RH94': 'llmg_0022',
#  'A2RH95': 'llmg_0023',
#  'A2RH96': 'llmg_0024',
#  'A2RH97': 'llmg_0025',
#  'A2RHD7': 'llmg_0066',
#  'A2RHE1': 'llmg_0071',
#  'A2RHE2': 'llmg_0072',
#  'A2RHE3': 'llmg_0073',
#  'A2RHE4': 'llmg_0074',
#  'A2RHE5': 'llmg_0075',
#  'A2RHE9': 'llmg_0079',
#  'A2RHF3': 'llmg_0083',
#  'A2RHF4': 'llmg_0084',
#  'A2RHF5': 'llmg_0085',
#  'A2RHG2': 'llmg_0091',
#  'A2RHG3': 'llmg_0092',
#  'A2RHG4': 'llmg_0093',
#  'A2RHG9': 'llmg_0098',
#  'A2RHH6': 'llmg_0105',
#  'A2RHH7': 'llmg_0106',
#  'A2RHI1': 'llmg_0110',
#  'A2RHI2': 'llmg_0111',
#  'A2RHI3': 'llmg_0112',
#  'A2RHI4': 'llmg_0113',
#  'A2RHI5': 'llmg_0114',
#  'A2RHI9': 'llmg_0118',
#  'A2RHJ0': 'llmg_0119',
#  'A2RHJ5': 'llmg_0124',
#  'A2RHJ6': 'llmg_0125',
#  'A2RHJ7': 'llmg_0126',
#  'A2RHJ8': 'llmg_0127',
#  'A2RHJ9': 'llmg_0128',
#  'A2RHL0': 'llmg_0139',
#  'A2RHL3': 'llmg_0142',
#  'A2RHL4': 'llmg_0143',
#  'A2RHL5': 'llmg_0144',
#  'A2RHL7': 'llmg_0146',
#  'A2RHM1': 'llmg_0150',
#  'A2RHN5': 'llmg_0164',
#  'A2RHN7': 'llmg_0167',
#  'A2RHN8': 'llmg_0168',
#  'A2RHP0': 'llmg_0170',
#  'A2RHP1': 'llmg_0171',
#  'A2RHP2': 'llmg_0172',
#  'A2RHP4': 'llmg_0174',
#  'A2RHP5': 'llmg_0175',
#  'A2RHP6': 'llmg_0176',
#  'A2RHP7': 'llmg_0177',
#  'A2RHP9': 'llmg_0180',
#  'A2RHQ4': 'llmg_0185',
#  'A2RHQ7': 'llmg_0188',
#  'A2RHR0': 'llmg_0191',
#  'A2RHR1': 'llmg_0192',
#  'A2RHR2': 'llmg_0193',
#  'A2RHR3': 'llmg_0194',
#  'A2RHR4': 'llmg_0195',
#  'A2RHR5': 'llmg_0196',
#  'A2RHS0': 'llmg_0201',
#  'A2RHS1': 'llmg_0202',
#  'A2RHS3': 'llmg_0204',
#  'A2RHS4': 'llmg_0205',
#  'A2RHS5': 'llmg_0206',
#  'A2RHS6': 'llmg_0207',
#  'A2RHS8': 'llmg_0209',
#  'A2RHS9': 'llmg_0210',
#  'A2RHT0': 'llmg_0211',
#  'A2RHT1': 'llmg_0212',
#  'A2RHT3': 'llmg_0214',
#  'A2RHT5': 'llmg_0216',
#  'A2RHT6': 'llmg_0217',
#  'A2RHT7': 'llmg_0218',
#  'A2RHT8': 'llmg_0219',
#  'A2RHT9': 'llmg_0220',
#  'A2RHU0': 'llmg_0221',
#  'A2RHU1': 'llmg_0222',
#  'A2RHU2': 'llmg_0223',
#  'A2RHU3': 'llmg_0224',
#  'A2RHU5': 'llmg_0226',
#  'A2RHU8': 'llmg_0229',
#  'A2RHU9': 'llmg_0230',
#  'A2RHV0': 'llmg_0231',
#  'A2RHV2': 'llmg_0233',
#  'A2RHV4': 'llmg_0235',
#  'A2RHW1': 'llmg_0242',
#  'A2RHW2': 'llmg_0244',
#  'A2RHW9': 'llmg_0251',
#  'A2RHX1': 'llmg_0253',
#  'A2RHX6': 'llmg_0260',
#  'A2RHX8': 'llmg_0263',
#  'A2RHY0': 'llmg_0265',
#  'A2RHY6': 'llmg_0271',
#  'A2RHY8': 'llmg_0273',
#  'A2RHZ1': 'llmg_0276',
#  'A2RHZ2': 'llmg_0277',
#  'A2RHZ5': 'llmg_0280',
#  'A2RHZ6': 'llmg_0281',
#  'A2RI02': 'llmg_0288',
#  'A2RI05': 'llmg_0291',
#  'A2RI06': 'llmg_0292',
#  'A2RI08': 'llmg_0294',
#  'A2RI10': 'llmg_0296',
#  'A2RI11': 'llmg_0297',
#  'A2RI13': 'llmg_0299',
#  'A2RI16': 'llmg_0302',
#  'A2RI19': 'llmg_0306',
#  'A2RI22': 'llmg_0309',
#  'A2RI24': 'llmg_0311',
#  'A2RI25': 'llmg_0312',
#  'A2RI26': 'llmg_0313',
#  'A2RI29': 'llmg_0316',
#  'A2RI31': 'llmg_0318',
#  'A2RI32': 'llmg_0319',
#  'A2RI37': 'llmg_0324',
#  'A2RI38': 'llmg_0325',
#  'A2RI39': 'llmg_0326',
#  'A2RI46': 'llmg_0333',
#  'A2RI48': 'llmg_0335',
#  'A2RI49': 'llmg_0336',
#  'A2RI56': 'llmg_0344',
#  'A2RI62': 'llmg_0350',
#  'A2RI67': 'llmg_0355',
#  'A2RI68': 'llmg_0356',
#  'A2RI69': 'llmg_0357',
#  'A2RI70': 'llmg_0358',
#  'A2RI72': 'llmg_0360',
#  'A2RI73': 'llmg_0361',
#  'A2RI79': 'llmg_0368',
#  'A2RI80': 'llmg_0369',
#  'A2RI83': 'llmg_0372',
#  'A2RI84': 'llmg_0373',
#  'A2RI85': 'llmg_0374',
#  'A2RI86': 'llmg_0375',
#  'A2RI91': 'llmg_0380',
#  'A2RI93': 'llmg_0382',
#  'A2RI94': 'llmg_0383',
#  'A2RI96': 'llmg_0385',
#  'A2RI97': 'llmg_0386',
#  'A2RIA0': 'llmg_0389',
#  'A2RIA6': 'llmg_0395',
#  'A2RIA7': 'llmg_0397',
#  'A2RIB0': 'llmg_0400',
#  'A2RIB1': 'llmg_0401',
#  'A2RIB2': 'llmg_0402',
#  'A2RIB5': 'llmg_0406',
#  'A2RIB6': 'llmg_0407',
#  'A2RIB7': 'llmg_0408',
#  'A2RIC3': 'llmg_0414',
#  'A2RIC4': 'llmg_0415',
#  'A2RIC5': 'llmg_0416',
#  'A2RIC8': 'llmg_0419',
#  'A2RID4': 'llmg_0425',
#  'A2RID5': 'llmg_0426',
#  'A2RIE2': 'llmg_0433',
#  'A2RIE6': 'llmg_0437',
#  'A2RIE7': 'llmg_0438',
#  'A2RIF3': 'llmg_0444',
#  'A2RIF4': 'llmg_0445',
#  'A2RIF5': 'llmg_0446',
#  'A2RIF6': 'llmg_0447',
#  'A2RIF7': 'llmg_0448',
#  'A2RIG0': 'llmg_0451',
#  'A2RIG2': 'llmg_0453',
#  'A2RIG4': 'llmg_0455',
#  'A2RIG5': 'llmg_0456',
#  'A2RIH0': 'llmg_0461',
#  'A2RIH1': 'llmg_0462',
#  'A2RIH4': 'llmg_0465',
#  'A2RIH5': 'llmg_0466',
#  'A2RII5': 'llmg_0476',
#  'A2RIJ0': 'llmg_0481',
#  'A2RIJ1': 'llmg_0482',
#  'A2RIJ2': 'llmg_0483',
#  'A2RIK1': 'llmg_0492',
#  'A2RIK2': 'llmg_0493',
#  'A2RIK5': 'llmg_0496',
#  'A2RIL4': 'llmg_0505',
#  'A2RIL6': 'llmg_0507',
#  'A2RIL7': 'llmg_0508',
#  'A2RIM0': 'llmg_0511',
#  'A2RIM6': 'llmg_0517',
#  'A2RIM8': 'llmg_0519',
#  'A2RIM9': 'llmg_0520',
#  'A2RIN0': 'llmg_0521',
#  'A2RIN9': 'llmg_0530',
#  'A2RIP1': 'llmg_0532',
#  'A2RIP3': 'llmg_0534',
#  'A2RIP4': 'llmg_0535',
#  'A2RIP5': 'llmg_0536',
#  'A2RIP6': 'llmg_0538',
#  'A2RIP7': 'llmg_0539',
#  'A2RIP8': 'llmg_0540',
#  'A2RIP9': 'llmg_0541',
#  'A2RIQ1': 'llmg_0543',
#  'A2RIQ2': 'llmg_0544',
#  'A2RIQ4': 'llmg_0547',
#  'A2RIQ9': 'llmg_0552',
#  'A2RIR4': 'llmg_0557',
#  'A2RIR7': 'llmg_0560',
#  'A2RIR9': 'llmg_0562',
#  'A2RIS0': 'llmg_0563',
#  'A2RIS2': 'llmg_0565',
#  'A2RIS3': 'llmg_0566',
#  'A2RIS6': 'llmg_0570',
#  'A2RIT2': 'llmg_0577',
#  'A2RIT6': 'llmg_0582',
#  'A2RIT8': 'llmg_0584',
#  'A2RIT9': 'llmg_0585',
#  'A2RIU1': 'llmg_0587;llmg_0588',
#  'A2RIU2': 'llmg_0589',
#  'A2RIU5': 'llmg_0592',
#  'A2RIU6': 'llmg_0593',
#  'A2RIV5': 'llmg_0602',
#  'A2RIV7': 'llmg_0604',
#  'A2RIW0': 'llmg_0607',
#  'A2RIW1': 'llmg_0608',
#  'A2RIW2': 'llmg_0609',
#  'A2RIW3': 'llmg_0610',
#  'A2RIW9': 'llmg_0615',
#  'A2RIX0': 'llmg_0616',
#  'A2RIX1': 'llmg_0617',
#  'A2RIX9': 'llmg_0625',
#  'A2RIY1': 'llmg_0627',
#  'A2RIY2': 'llmg_0628',
#  'A2RIY4': 'llmg_0630',
#  'A2RIY7': 'llmg_0633',
#  'A2RIY8': 'llmg_0634',
#  'A2RIZ0': 'llmg_0636',
#  'A2RIZ3': 'llmg_0639',
#  'A2RIZ7': 'llmg_0643',
#  'A2RJ11': 'llmg_0658',
#  'A2RJ14': 'llmg_0661',
#  'A2RJ24': 'llmg_0673',
#  'A2RJ49': 'llmg_0697',
#  'A2RJ50': 'llmg_0698',
#  'A2RJ51': 'llmg_0699',
#  'A2RJ53': 'llmg_0701',
#  'A2RJ54': 'llmg_0702',
#  'A2RJ63': 'pSH74_09',
#  'A2RJ76': 'llmg_0722',
#  'A2RJ77': 'llmg_0724',
#  'A2RJ79': 'llmg_0726',
#  'A2RJ80': 'llmg_0727',
#  'A2RJ82': 'llmg_0729',
#  'A2RJ85': 'llmg_0732',
#  'A2RJ86': 'llmg_0733',
#  'A2RJ89': 'llmg_0737',
#  'A2RJ90': 'llmg_0738',
#  'A2RJ91': 'llmg_0739',
#  'A2RJ92': 'llmg_0740',
#  'A2RJ93': 'llmg_0741',
#  'A2RJ94': 'llmg_0742',
#  'A2RJ96': 'llmg_0744',
#  'A2RJ97': 'llmg_0745',
#  'A2RJ98': 'llmg_0746',
#  'A2RJ99': 'llmg_0747',
#  'A2RJA1': 'llmg_0749',
#  'A2RJA3': 'llmg_0751',
#  'A2RJA4': 'llmg_0752',
#  'A2RJA5': 'llmg_0753',
#  'A2RJB3': 'llmg_0761',
#  'A2RJB4': 'llmg_0762',
#  'A2RJB5': 'llmg_0763',
#  'A2RJB7': 'llmg_0765',
#  'A2RJB8': 'llmg_0766',
#  'A2RJC0': 'llmg_0768',
#  'A2RJC1': 'llmg_0769',
#  'A2RJC2': 'llmg_0771',
#  'A2RJC3': 'llmg_0772',
#  'A2RJC4': 'llmg_0774',
#  'A2RJC5': 'llmg_0775',
#  'A2RJC8': 'llmg_0778',
#  'A2RJC9': 'llmg_0779',
#  'A2RJD1': 'llmg_0782',
#  'A2RJD2': 'llmg_0783',
#  'A2RJE2': 'llmg_0793',
#  'A2RJH8': 'llmg_0834',
#  'A2RJJ5': 'llmg_0852',
#  'A2RJL0': 'llmg_0868',
#  'A2RJL2': 'llmg_0870',
#  'A2RJL3': 'llmg_0871',
#  'A2RJL4': 'llmg_0872',
#  'A2RJL5': 'llmg_0873',
#  'A2RJL6': 'llmg_0874',
#  'A2RJL8': 'llmg_0876',
#  'A2RJM0': 'llmg_0878',
#  'A2RJM2': 'llmg_0880',
#  'A2RJM6': 'llmg_0884',
#  'A2RJM7': 'llmg_0885',
#  'A2RJM8': 'llmg_0886',
#  'A2RJN3': 'llmg_0891',
#  'A2RJP7': 'llmg_0906',
#  'A2RJP9': 'llmg_0908',
#  'A2RJQ2': 'llmg_0911',
#  'A2RJQ3': 'llmg_0912',
#  'A2RJQ4': 'llmg_0913',
#  'A2RJQ6': 'llmg_0915',
#  'A2RJR5': 'llmg_0926',
#  'A2RJR7': 'llmg_0928',
#  'A2RJR8': 'llmg_0929',
#  'A2RJR9': 'llmg_0930',
#  'A2RJS0': 'llmg_0931',
#  'A2RJS1': 'llmg_0932',
#  'A2RJS2': 'llmg_0933',
#  'A2RJS4': 'llmg_0935',
#  'A2RJS5': 'llmg_0936',
#  'A2RJS6': 'llmg_0937',
#  'A2RJS9': 'llmg_0940',
#  'A2RJT2': 'llmg_0943',
#  'A2RJT4': 'llmg_0945',
#  'A2RJT5': 'llmg_0947',
#  'A2RJT6': 'llmg_0948',
#  'A2RJT9': 'llmg_0952',
#  'A2RJU2': 'llmg_0955',
#  'A2RJV1': 'llmg_0964',
#  'A2RJW0': 'llmg_0973',
#  'A2RJW1': 'llmg_0974',
#  'A2RJW2': 'llmg_0975',
#  'A2RJW3': 'llmg_0976',
#  'A2RJW4': 'llmg_0977',
#  'A2RJX5': 'llmg_0988',
#  'A2RJX6': 'llmg_0989',
#  'A2RJX9': 'llmg_0993',
#  'A2RJY0': 'llmg_0994',
#  'A2RJY1': 'llmg_0995',
#  'A2RJY4': 'llmg_0997',
#  'A2RJY6': 'llmg_0999',
#  'A2RJY7': 'llmg_1000',
#  'A2RK04': 'llmg_1017',
#  'A2RK13': 'llmg_1028',
#  'A2RK24': 'llmg_1041',
#  'A2RK30': 'llmg_1047',
#  'A2RK31': 'llmg_1048',
#  'A2RK32': 'llmg_1049',
#  'A2RK34': 'llmg_1051',
#  'A2RK41': 'llmg_1058',
#  'A2RK43': 'llmg_1060',
#  'A2RK45': 'llmg_1062',
#  'A2RK47': 'llmg_1064',
#  'A2RK48': 'llmg_1065',
#  'A2RK50': 'llmg_1067',
#  'A2RK64': 'llmg_1080',
#  'A2RK70': 'llmg_1086',
#  'A2RK83': 'llmg_1099',
#  'A2RK87': 'llmg_1103',
#  'A2RK93': 'llmg_1109',
#  'A2RK97': 'llmg_1113',
#  'A2RK98': 'llmg_1114',
#  'A2RK99': 'llmg_1115',
#  'A2RKA0': 'llmg_1116',
#  'A2RKA1': 'llmg_1117',
#  'A2RKA2': 'llmg_1118',
#  'A2RKA3': 'llmg_1119',
#  'A2RKA4': 'llmg_1120',
#  'A2RKA6': 'llmg_1122',
#  'A2RKA7': 'llmg_1123',
#  'A2RKA9': 'llmg_1125',
#  'A2RKB5': 'llmg_1131',
#  'A2RKB7': 'llmg_1133',
#  'A2RKB9': 'llmg_1135',
#  'A2RKF4': 'llmg_1171',
#  'A2RKF8': 'llmg_1175',
#  'A2RKG4': 'llmg_1181',
#  'A2RKG6': 'llmg_1183',
#  'A2RKG7': 'llmg_1184',
#  'A2RKG8': 'llmg_1185',
#  'A2RKG9': 'llmg_1186',
#  'A2RKH0': 'llmg_1187',
#  'A2RKH1': 'llmg_1188',
#  'A2RKH2': 'llmg_1189',
#  'A2RKH7': 'llmg_1194',
#  'A2RKI4': 'llmg_1202',
#  'A2RKI5': 'llmg_1203',
#  'A2RKI6': 'llmg_1204',
#  'A2RKI8': 'llmg_1207',
#  'A2RKI9': 'llmg_1208',
#  'A2RKJ8': 'llmg_1219',
#  'A2RKK4': 'llmg_1225',
#  'A2RKK6': 'llmg_1227',
#  'A2RKN1': 'llmg_1252',
#  'A2RKN2': 'llmg_1253',
#  'A2RKN7': 'llmg_1258',
#  'A2RKQ0': 'llmg_1271',
#  'A2RKQ1': 'llmg_1272',
#  'A2RKQ5': 'llmg_1276',
#  'A2RKQ6': 'llmg_1277',
#  'A2RKQ9': 'llmg_1280',
#  'A2RKS2': 'llmg_1295',
#  'A2RKS5': 'llmg_1298',
#  'A2RKT1': 'llmg_1304',
#  'A2RKT5': 'llmg_1309',
#  'A2RKT6': 'llmg_1310',
#  'A2RKT7': 'llmg_1311',
#  'A2RKT9': 'llmg_1314',
#  'A2RKU0': 'llmg_1315',
#  'A2RKU2': 'llmg_1317',
#  'A2RKV0': 'llmg_1325',
#  'A2RKV3': 'llmg_1328',
#  'A2RKV4': 'llmg_1329',
#  'A2RKV5': 'llmg_1330',
#  'A2RKV6': 'llmg_1331',
#  'A2RKV7': 'llmg_1332',
#  'A2RKV9': 'llmg_1334',
#  'A2RKW1': 'llmg_1336',
#  'A2RKW6': 'llmg_1342',
#  'A2RKX0': 'llmg_1346',
#  'A2RKX1': 'llmg_1347 llmg_1359',
#  'A2RKX2': 'llmg_1348 llmg_1360',
#  'A2RKX4': 'llmg_1350',
#  'A2RKX5': 'llmg_1351',
#  'A2RKX6': 'llmg_1352',
#  'A2RKX7': 'llmg_1353',
#  'A2RKX8': 'llmg_1354',
#  'A2RKX9': 'llmg_1355',
#  'A2RKY0': 'llmg_1356',
#  'A2RKY1': 'llmg_1357',
#  'A2RKY2': 'llmg_1358',
#  'A2RL19': 'llmg_1399',
#  'A2RL29': 'llmg_1412',
#  'A2RL31': 'llmg_1414',
#  'A2RL32': 'llmg_1415',
#  'A2RL35': 'llmg_1418',
#  'A2RL40': 'llmg_1424',
#  'A2RL41': 'llmg_1425',
#  'A2RL42': 'llmg_1426',
#  'A2RL45': 'llmg_1429',
#  'A2RL46': 'llmg_1430',
#  'A2RL48': 'llmg_1432',
#  'A2RL55': 'llmg_1441',
#  'A2RL56': 'llmg_1442',
#  'A2RL58': 'llmg_1445',
#  'A2RL61': 'llmg_1448',
#  'A2RL63': 'llmg_1450',
#  'A2RL64': 'llmg_1451',
#  'A2RL66': 'llmg_1453',
#  'A2RL76': 'llmg_1463',
#  'A2RL77': 'llmg_1464',
#  'A2RL78': 'llmg_1465',
#  'A2RL79': 'llmg_1466',
#  'A2RL81': 'llmg_1468',
#  'A2RL82': 'llmg_1470',
#  'A2RL83': 'llmg_1471',
#  'A2RL84': 'llmg_1472',
#  'A2RL87': 'llmg_1475',
#  'A2RL88': 'llmg_1477',
#  'A2RL89': 'llmg_1478',
#  'A2RL98': 'llmg_1487',
#  'A2RLA0': 'llmg_1489',
#  'A2RLA2': 'llmg_1491',
#  'A2RLA4': 'llmg_1493',
#  'A2RLA7': 'llmg_1496',
#  'A2RLA8': 'llmg_1497',
#  'A2RLA9': 'llmg_1498',
#  'A2RLB0': 'llmg_1499',
#  'A2RLB3': 'llmg_1502',
#  'A2RLB9': 'llmg_1508',
#  'A2RLC0': 'llmg_1509',
#  'A2RLC1': 'llmg_1512',
#  'A2RLC3': 'llmg_1514',
#  'A2RLC5': 'llmg_1516',
#  'A2RLD3': 'llmg_1524',
#  'A2RLD8': 'llmg_1529',
#  'A2RLD9': 'llmg_1530',
#  'A2RLE0': 'llmg_1531',
#  'A2RLE1': 'llmg_1532',
#  'A2RLE3': 'llmg_1534',
#  'A2RLE4': 'llmg_1536',
#  'A2RLE5': 'llmg_1537',
#  'A2RLE7': 'llmg_1539',
#  'A2RLF1': 'llmg_1543',
#  'A2RLF2': 'llmg_1544',
#  'A2RLF3': 'llmg_1545',
#  'A2RLF4': 'llmg_1546',
#  'A2RLF5': 'llmg_1547',
#  'A2RLF8': 'llmg_1550',
#  'A2RLG2': 'llmg_1554',
#  'A2RLG4': 'llmg_1556',
#  'A2RLG5': 'llmg_1557',
#  'A2RLG7': 'llmg_1559',
#  'A2RLH5': 'llmg_1568',
#  'A2RLI6': 'llmg_1579',
#  'A2RLI7': 'llmg_1580',
#  'A2RLI8': 'llmg_1581',
#  'A2RLI9': 'llmg_1582',
#  'A2RLJ5': 'llmg_1588',
#  'A2RLJ7': 'llmg_1590',
#  'A2RLJ9': 'llmg_1593',
#  'A2RLK1': 'llmg_1595',
#  'A2RLK2': 'llmg_1596',
#  'A2RLK3': 'llmg_1597',
#  'A2RLN1': 'llmg_1627',
#  'A2RLN4': 'llmg_1630',
#  'A2RLN5': 'llmg_1631',
#  'A2RLP5': 'llmg_1641',
#  'A2RLP9': 'llmg_1645',
#  'A2RLQ0': 'llmg_1646',
#  'A2RLQ1': 'llmg_1647',
#  'A2RLR6': 'llmg_1662',
#  'A2RLS5': 'llmg_1671',
#  'A2RLS8': 'llmg_1675',
#  'A2RLS9': 'llmg_1676',
#  'A2RLT2': 'llmg_1679',
#  'A2RLT4': 'llmg_1681',
#  'A2RLT8': 'llmg_1685',
#  'A2RLT9': 'llmg_1686',
#  'A2RLU3': 'llmg_1691',
#  'A2RLU4': 'llmg_1692',
#  'A2RLU5': 'llmg_1693',
#  'A2RLU6': 'llmg_1694;pNZ712_23',
#  'A2RLV0': 'llmg_1700',
#  'A2RLV2': 'llmg_1702',
#  'A2RLV6': 'llmg_1706',
#  'A2RLW8': 'llmg_1720',
#  'A2RLX0': 'llmg_1724',
#  'A2RLX1': 'llmg_1725',
#  'A2RLX8': 'llmg_1732',
#  'A2RLY0': 'llmg_1734',
#  'A2RLY1': 'llmg_1735',
#  'A2RLY6': 'llmg_1741',
#  'A2RLY8': 'llmg_1743',
#  'A2RLY9': 'llmg_1744',
#  'A2RLZ1': 'llmg_1746',
#  'A2RLZ6': 'llmg_1751',
#  'A2RLZ7': 'llmg_1752',
#  'A2RLZ8': 'llmg_1753',
#  'A2RM04': 'llmg_1759',
#  'A2RM07': 'llmg_1762',
#  'A2RM08': 'llmg_1763',
#  'A2RM09': 'llmg_1764',
#  'A2RM10': 'llmg_1765',
#  'A2RM13': 'llmg_1768',
#  'A2RM15': 'llmg_1770',
#  'A2RM18': 'llmg_1773',
#  'A2RM22': 'llmg_1777',
#  'A2RM23': 'llmg_1778',
#  'A2RM24': 'llmg_1779',
#  'A2RM26': 'llmg_1781',
#  'A2RM27': 'llmg_1782',
#  'A2RM28': 'llmg_1783',
#  'A2RM29': 'llmg_1784',
#  'A2RM30': 'llmg_1785',
#  'A2RM31': 'llmg_1786',
#  'A2RM32': 'llmg_1787',
#  'A2RM34': 'llmg_1789',
#  'A2RM36': 'llmg_1791',
#  'A2RM37': 'llmg_1792',
#  'A2RM38': 'llmg_1793',
#  'A2RM39': 'llmg_1794',
#  'A2RM40': 'llmg_1796',
#  'A2RM41': 'llmg_1797',
#  'A2RM49': 'llmg_1805',
#  'A2RM51': 'llmg_1807',
#  'A2RM52': 'llmg_1808',
#  'A2RM53': 'llmg_1809',
#  'A2RM54': 'llmg_1810',
#  'A2RM55': 'llmg_1811',
#  'A2RM56': 'llmg_1812',
#  'A2RM57': 'llmg_1813',
#  'A2RM58': 'llmg_1814',
#  'A2RM59': 'llmg_1815',
#  'A2RM60': 'llmg_1816',
#  'A2RM61': 'llmg_1817',
#  'A2RM63': 'llmg_1819',
#  'A2RM64': 'llmg_1820',
#  'A2RM66': 'llmg_1822',
#  'A2RM67': 'llmg_1823',
#  'A2RM69': 'llmg_1825',
#  'A2RM70': 'llmg_1826',
#  'A2RM73': 'llmg_1829',
#  'A2RM75': 'llmg_1831',
#  'A2RM89': 'llmg_1845',
#  'A2RM93': 'llmg_1849',
#  'A2RM97': 'llmg_1853',
#  'A2RMA4': 'llmg_1861',
#  'A2RMA5': 'llmg_1862',
#  'A2RMB2': 'llmg_1869',
#  'A2RMB4': 'llmg_1871',
#  'A2RMC0': 'llmg_1878',
#  'A2RMC1': 'llmg_1879',
#  'A2RMC2': 'llmg_1880',
#  'A2RMC3': 'llmg_1881',
#  'A2RMC4': 'llmg_1882',
#  'A2RMD5': 'llmg_1895',
#  'A2RMD6': 'llmg_1896',
#  'A2RMD7': 'llmg_1897',
#  'A2RMD8': 'llmg_1898',
#  'A2RME0': 'llmg_1900',
#  'A2RME6': 'llmg_1906',
#  'A2RME7': 'llmg_1907',
#  'A2RME8': 'llmg_1908',
#  'A2RME9': 'llmg_1909',
#  'A2RMF2': 'llmg_1913',
#  'A2RMF3': 'llmg_1914',
#  'A2RMF4': 'llmg_1915',
#  'A2RMF5': 'llmg_1916',
#  'A2RMF6': 'llmg_1917',
#  'A2RMG0': 'llmg_1921',
#  'A2RMG1': 'llmg_1922',
#  'A2RMG7': 'llmg_1928',
#  'A2RMG8': 'llmg_1929',
#  'A2RMH2': 'llmg_1934',
#  'A2RMH5': 'llmg_1938',
#  'A2RMH6': 'llmg_1939',
#  'A2RMH8': 'llmg_1942',
#  'A2RMH9': 'llmg_1943',
#  'A2RMI2': 'llmg_1946',
#  'A2RMI4': 'llmg_1948',
#  'A2RMI5': 'llmg_1949',
#  'A2RMI9': 'llmg_1953',
#  'A2RMJ1': 'llmg_1956',
#  'A2RMJ2': 'llmg_1957',
#  'A2RMJ4': 'llmg_1959',
#  'A2RMK5': 'llmg_1969',
#  'A2RMK6': 'llmg_1970',
#  'A2RMK9': 'llmg_1973',
#  'A2RML0': 'llmg_1974',
#  'A2RML4': 'llmg_1977',
#  'A2RML5': 'llmg_1978',
#  'A2RML6': 'llmg_1979',
#  'A2RML8': 'llmg_1981',
#  'A2RML9': 'llmg_1982',
#  'A2RMM2': 'llmg_1985',
#  'A2RMM4': 'llmg_1988',
#  'A2RMM5': 'llmg_1989',
#  'A2RMN0': 'llmg_1994',
#  'A2RMN2': 'llmg_1996',
#  'A2RMN3': 'llmg_1997',
#  'A2RMN4': 'llmg_1999',
#  'A2RMN8': 'llmg_2004',
#  'A2RMP2': 'llmg_2008',
#  'A2RMP5': 'llmg_2011',
#  'A2RMP6': 'llmg_2012',
#  'A2RMQ1': 'llmg_2017',
#  'A2RMQ2': 'llmg_2018',
#  'A2RMQ3': 'llmg_2019',
#  'A2RMQ4': 'llmg_2020',
#  'A2RMQ5': 'llmg_2021',
#  'A2RMQ7': 'llmg_2023',
#  'A2RMR1': 'llmg_2029',
#  'A2RMR2': 'llmg_2030',
#  'A2RMR3': 'llmg_2031',
#  'A2RMS1': 'llmg_2040',
#  'A2RMS4': 'llmg_2043',
#  'A2RMS5': 'llmg_2044',
#  'A2RMS6': 'llmg_2045',
#  'A2RMS7': 'llmg_2046',
#  'A2RMS8': 'llmg_2047',
#  'A2RMT0': 'llmg_2049',
#  'A2RMT1': 'llmg_2050',
#  'A2RMT2': 'llmg_2051',
#  'A2RMT4': 'llmg_2053',
#  'A2RMT6': 'llmg_2055',
#  'A2RMU0': 'llmg_2059',
#  'A2RMU1': 'llmg_2060',
#  'A2RMU2': 'llmg_2061',
#  'A2RMU3': 'llmg_2062',
#  'A2RMU4': 'llmg_2063',
#  'A2RMV0': 'llmg_2069',
#  'A2RMV4': 'llmg_2073',
#  'A2RMV6': 'llmg_2075',
#  'A2RMV7': 'llmg_2076',
#  'A2RMV8': 'llmg_2077',
#  'A2RMV9': 'llmg_2078',
#  'A2RMW0': 'llmg_2079',
#  'A2RMW1': 'llmg_2080',
#  'A2RMW2': 'llmg_2081',
#  'A2RN16': 'llmg_2136',
#  'A2RN19': 'llmg_2139',
#  'A2RN23': 'llmg_1263;llmg_2143',
#  'A2RN27': 'llmg_2147',
#  'A2RN33': 'llmg_2153',
#  'A2RN34': 'llmg_2154',
#  'A2RN35': 'llmg_2155',
#  'A2RN36': 'llmg_2156',
#  'A2RN37': 'llmg_2157',
#  'A2RN40': 'llmg_2159;llmg_2160',
#  'A2RN41': 'llmg_2161',
#  'A2RN42': 'llmg_2162',
#  'A2RN43': 'llmg_2163',
#  'A2RN44': 'llmg_2164',
#  'A2RN45': 'llmg_2165',
#  'A2RN46': 'llmg_2167',
#  'A2RN48': 'llmg_2169',
#  'A2RN49': 'llmg_2170',
#  'A2RN51': 'llmg_2172',
#  'A2RN62': 'llmg_2183',
#  'A2RN64': 'llmg_2185',
#  'A2RN65': 'llmg_2186',
#  'A2RN66': 'llmg_2187',
#  'A2RN69': 'llmg_2190',
#  'A2RN72': 'llmg_2193',
#  'A2RN73': 'llmg_2194',
#  'A2RN74': 'llmg_2195',
#  'A2RN75': 'llmg_2196',
#  'A2RN77': 'llmg_2198',
#  'A2RN80': 'llmg_2201',
#  'A2RN83': 'llmg_2204',
#  'A2RN88': 'llmg_2209',
#  'A2RN90': 'llmg_2211',
#  'A2RN91': 'llmg_2212',
#  'A2RN94': 'llmg_2215',
#  'A2RN96': 'llmg_2217',
#  'A2RNA4': 'llmg_2225',
#  'A2RNA7': 'llmg_2228',
#  'A2RNB1': 'llmg_2232',
#  'A2RNB2': 'llmg_2233',
#  'A2RNB8': 'llmg_2241',
#  'A2RNB9': 'llmg_2242',
#  'A2RNC0': 'llmg_2243',
#  'A2RNC1': 'llmg_2244',
#  'A2RNC5': 'llmg_2248',
#  'A2RND9': 'llmg_2262',
#  'A2RNE6': 'llmg_2269',
#  'A2RNE8': 'llmg_2271',
#  'A2RNE9': 'llmg_2272',
#  'A2RNF0': 'llmg_2273',
#  'A2RNF1': 'llmg_2274',
#  'A2RNF3': 'llmg_2276',
#  'A2RNF4': 'llmg_2277',
#  'A2RNF6': 'llmg_2279',
#  'A2RNF8': 'llmg_2281',
#  'A2RNF9': 'llmg_2282',
#  'A2RNG1': 'llmg_2284',
#  'A2RNG4': 'llmg_2288',
#  'A2RNG5': 'llmg_2289',
#  'A2RNG8': 'llmg_2292',
#  'A2RNH4': 'llmg_2299',
#  'A2RNH5': 'llmg_2300',
#  'A2RNH7': 'llmg_2302',
#  'A2RNI2': 'llmg_2308',
#  'A2RNI3': 'llmg_2309',
#  'A2RNI4': 'llmg_2310',
#  'A2RNI8': 'llmg_2314',
#  'A2RNI9': 'llmg_2315',
#  'A2RNJ0': 'llmg_2316',
#  'A2RNJ1': 'llmg_2318',
#  'A2RNJ2': 'llmg_2319',
#  'A2RNJ5': 'llmg_2322',
#  'A2RNJ6': 'llmg_2323',
#  'A2RNJ8': 'llmg_2325',
#  'A2RNK0': 'llmg_2327',
#  'A2RNK1': 'llmg_2328',
#  'A2RNK2': 'llmg_2329',
#  'A2RNK3': 'llmg_2330',
#  'A2RNK4': 'llmg_2331',
#  'A2RNK5': 'llmg_2332',
#  'A2RNK6': 'llmg_2333',
#  'A2RNK9': 'llmg_2336',
#  'A2RNL4': 'llmg_2341',
#  'A2RNL6': 'llmg_2343',
#  'A2RNM6': 'llmg_2353',
#  'A2RNM7': 'llmg_2354',
#  'A2RNM8': 'llmg_2355',
#  'A2RNM9': 'llmg_2356',
#  'A2RNN0': 'llmg_2357',
#  'A2RNN1': 'llmg_2358',
#  'A2RNN2': 'llmg_2359',
#  'A2RNN3': 'llmg_2361',
#  'A2RNN4': 'llmg_2362',
#  'A2RNN5': 'llmg_2363',
#  'A2RNN6': 'llmg_2364',
#  'A2RNN7': 'llmg_2365',
#  'A2RNN8': 'llmg_2366',
#  'A2RNN9': 'llmg_2367',
#  'A2RNP2': 'llmg_2370',
#  'A2RNP3': 'llmg_2371',
#  'A2RNP4': 'llmg_2372',
#  'A2RNP5': 'llmg_2373',
#  'A2RNP6': 'llmg_2374',
#  'A2RNP7': 'llmg_2375',
#  'A2RNP8': 'llmg_2376',
#  'A2RNP9': 'llmg_2377',
#  'A2RNQ0': 'llmg_2378',
#  'A2RNQ1': 'llmg_2379',
#  'A2RNQ2': 'llmg_2380',
#  'A2RNQ3': 'llmg_2381',
#  'A2RNQ4': 'llmg_2382',
#  'A2RNQ5': 'llmg_2383',
#  'A2RNQ6': 'llmg_2384',
#  'A2RNQ9': 'llmg_2387',
#  'A2RNR0': 'llmg_2388',
#  'A2RNR3': 'llmg_2391',
#  'A2RNR4': 'llmg_2392',
#  'A2RNS1': 'llmg_2400',
#  'A2RNT0': 'llmg_2409',
#  'A2RNT2': 'llmg_2412',
#  'A2RNT3': 'llmg_2413',
#  'A2RNT5': 'llmg_2415',
#  'A2RNT6': 'llmg_2416',
#  'A2RNT9': 'llmg_2419',
#  'A2RNU0': 'llmg_2420',
#  'A2RNU1': 'llmg_2421',
#  'A2RNU2': 'llmg_2422',
#  'A2RNU8': 'llmg_2428',
#  'A2RNU9': 'llmg_2429',
#  'A2RNV0': 'llmg_2430',
#  'A2RNV2': 'llmg_2432',
#  'A2RNW1': 'llmg_2442',
#  'A2RNW8': 'llmg_2448',
#  'A2RNX5': 'llmg_2455',
#  'A2RNY0': 'llmg_2460',
#  'A2RNY2': 'llmg_2463',
#  'A2RNY3': 'llmg_2464',
#  'A2RNY5': 'llmg_2466',
#  'A2RNY7': 'llmg_2468',
#  'A2RNZ2': 'llmg_2473',
#  'A2RNZ3': 'llmg_2474',
#  'A2RNZ4': 'llmg_2475',
#  'A2RNZ7': 'llmg_2478',
#  'A2RNZ8': 'llmg_2479',
#  'A2RP00': 'llmg_2481',
#  'A2RP01': 'llmg_2482',
#  'A2RP03': 'llmg_2484',
#  'A2RP04': 'llmg_2485',
#  'A2RP06': 'llmg_2487',
#  'A2RP08': 'llmg_2489',
#  'A2RP09': 'llmg_2490',
#  'A2RP10': 'llmg_2491',
#  'A2RP13': 'llmg_2494',
#  'A2RP17': 'llmg_2498',
#  'A2RP18': 'llmg_2499',
#  'A2RP20': 'llmg_2502',
#  'A2RP21': 'llmg_2504',
#  'A2RP22': 'llmg_2505',
#  'A2RP23': 'llmg_2506',
#  'A2RP26': 'llmg_2509',
#  'A2RP28': 'llmg_2511',
#  'A2RP29': 'llmg_2512',
#  'A2RP33': 'llmg_2516',
#  'A2RP34': 'llmg_2517',
#  'A2RP35': 'llmg_2518',
#  'A2RP36': 'llmg_2520',
#  'A2RP37': 'llmg_2521',
#  'A2RP39': 'llmg_2523',
#  'A2RP42': 'llmg_2526',
#  'A2RP55': 'llmg_2539',
#  'A2RP56': 'llmg_2540',
#  'A2RP61': 'llmg_2545',
#  'A2RP62': 'llmg_2546',
#  'A2RP63': 'llmg_2547',
#  'A2RP64': 'llmg_2548',
#  'A2RP66': 'llmg_2550',
#  'A2RP72': 'llmg_2556',
#  'A2RP73': 'llmg_2557',
#  'A2RP74': 'llmg_2558',
#  'A2RP76': 'llmg_2560',
#  'O30415': 'llmg_1176',
#  'O30418': 'llmg_1179',
#  'O32770': 'llmg_1088',
#  'O32771': 'llmg_1089',
#  'O32799': 'llmg_0629',
#  'O32801': 'llmg_2425',
#  'O32806': 'llmg_2035',
#  'O32808': 'llmg_1601',
#  'O32810': 'llmg_1599',
#  'O54376': 'llmg_0002',
#  'O68185': 'llmg_0986',
#  'O68186': 'llmg_0987',
#  'O86281': 'llmg_2431',
#  'O87761': 'llmg_0467',
#  'P0A2Z1': 'llmg_1950',
#  'P0A3C2': 'llmg_0371',
#  'P0A3J1': 'llmg_1574',
#  'P0A400': 'llmg_2551',
#  'P0A4J2': 'llmg_0429',
#  'P0CI33': 'llmg_0341',
#  'P22865': 'llmg_2507',
#  'P42369': 'llmg_1575',
#  'P42370': 'llmg_1576',
#  'P43901': 'llmg_1927',
#  'P43905': 'llmg_1926',
#  'P43909': 'llmg_1924',
#  'P50924': 'llmg_1107',
#  'P50926': 'llmg_2176',
#  'P54322': 'llmg_1106',
#  'P56968': 'llmg_1105',
#  'P60376': 'llmg_0640',
#  'P96789': 'llmg_0586',
#  'Q48677': 'llmg_0403',
#  'Q59491': 'llmg_0138',
#  'Q7BPI7': 'llmg_1649',
#  'Q8GJP4': 'llmg_1337',
#  'Q8GJP6': 'llmg_1340',
#  'Q9AEP7': 'llmg_0411',
#  'Q9AEP8': 'llmg_0410',
#  'Q9AQE3': 'llmg_1648',
#  'Q9K575': 'llmg_2312',
#  'Q9K576': 'llmg_2313',
#  'Q9L4N5': 'llmg_0894',
#  'Q9L4N6': 'llmg_0893',
#  'Q9L4N8': 'llmg_0890',
#  'Q9L6G1': 'llmg_1339',
#  'Q9RAT9': 'llmg_1945',
#  'Q9RAU1': 'llmg_1947',
#  'Q9S5Z2': 'llmg_0528',
#  'Q9Z5K8': 'llmg_2285',
#  'Q9Z6H4': 'llmg_1008',
#  'Q9ZAB0': 'llmg_0638',
#  'Q9ZAI9': 'llmg_2058',
#  'pNZ712_21;A2RJ09': 'llmg_0655;pNZ712_21',
#  'pNZ712_38': 'pNZ712_38'}

# %%
# Create dict from locus tag (=llmg code) to proteomics entry (uniprot identifier)
llmg_to_uniprotID = {}
exception_list = []
for uniprotID in preprocessed_data.index:
    if ';' in preprocessed_data["Gene names  (ordered locus )"][uniprotID]:
        print uniprotID, preprocessed_data["Gene names  (ordered locus )"][uniprotID]
        exception_list.append(uniprotID)
    if ' ' in preprocessed_data["Gene names  (ordered locus )"][uniprotID]:
        print uniprotID, preprocessed_data["Gene names  (ordered locus )"][uniprotID]
        exception_list.append(uniprotID)
    else:
        llmg_to_uniprotID[preprocessed_data["Gene names  (ordered locus )"][uniprotID]] = uniprotID
    
llmg_to_uniprotID
# Out:
# A2RIU1 llmg_0587;llmg_0588
# A2RKX1 llmg_1347 llmg_1359
# A2RKX2 llmg_1348 llmg_1360
# A2RLU6 llmg_1694;pNZ712_23
# A2RN23 llmg_1263;llmg_2143
# A2RN40 llmg_2159;llmg_2160
# pNZ712_21;A2RJ09 llmg_0655;pNZ712_21
# {'llmg_0001': 'A2RH74',
#  'llmg_0002': 'O54376',
#  'llmg_0004': 'A2RH77',
#  'llmg_0007': 'A2RH80',
#  'llmg_0012': 'A2RH85',
#  'llmg_0013': 'A2RH86',
#  'llmg_0020': 'A2RH92',
#  'llmg_0021': 'A2RH93',
#  'llmg_0022': 'A2RH94',
#  'llmg_0023': 'A2RH95',
#  'llmg_0024': 'A2RH96',
#  'llmg_0025': 'A2RH97',
#  'llmg_0066': 'A2RHD7',
#  'llmg_0071': 'A2RHE1',
#  'llmg_0072': 'A2RHE2',
#  'llmg_0073': 'A2RHE3',
#  'llmg_0074': 'A2RHE4',
#  'llmg_0075': 'A2RHE5',
#  'llmg_0079': 'A2RHE9',
#  'llmg_0083': 'A2RHF3',
#  'llmg_0084': 'A2RHF4',
#  'llmg_0085': 'A2RHF5',
#  'llmg_0091': 'A2RHG2',
#  'llmg_0092': 'A2RHG3',
#  'llmg_0093': 'A2RHG4',
#  'llmg_0098': 'A2RHG9',
#  'llmg_0105': 'A2RHH6',
#  'llmg_0106': 'A2RHH7',
#  'llmg_0110': 'A2RHI1',
#  'llmg_0111': 'A2RHI2',
#  'llmg_0112': 'A2RHI3',
#  'llmg_0113': 'A2RHI4',
#  'llmg_0114': 'A2RHI5',
#  'llmg_0118': 'A2RHI9',
#  'llmg_0119': 'A2RHJ0',
#  'llmg_0124': 'A2RHJ5',
#  'llmg_0125': 'A2RHJ6',
#  'llmg_0126': 'A2RHJ7',
#  'llmg_0127': 'A2RHJ8',
#  'llmg_0128': 'A2RHJ9',
#  'llmg_0138': 'Q59491',
#  'llmg_0139': 'A2RHL0',
#  'llmg_0142': 'A2RHL3',
#  'llmg_0143': 'A2RHL4',
#  'llmg_0144': 'A2RHL5',
#  'llmg_0146': 'A2RHL7',
#  'llmg_0150': 'A2RHM1',
#  'llmg_0164': 'A2RHN5',
#  'llmg_0167': 'A2RHN7',
#  'llmg_0168': 'A2RHN8',
#  'llmg_0170': 'A2RHP0',
#  'llmg_0171': 'A2RHP1',
#  'llmg_0172': 'A2RHP2',
#  'llmg_0174': 'A2RHP4',
#  'llmg_0175': 'A2RHP5',
#  'llmg_0176': 'A2RHP6',
#  'llmg_0177': 'A2RHP7',
#  'llmg_0180': 'A2RHP9',
#  'llmg_0185': 'A2RHQ4',
#  'llmg_0188': 'A2RHQ7',
#  'llmg_0191': 'A2RHR0',
#  'llmg_0192': 'A2RHR1',
#  'llmg_0193': 'A2RHR2',
#  'llmg_0194': 'A2RHR3',
#  'llmg_0195': 'A2RHR4',
#  'llmg_0196': 'A2RHR5',
#  'llmg_0201': 'A2RHS0',
#  'llmg_0202': 'A2RHS1',
#  'llmg_0204': 'A2RHS3',
#  'llmg_0205': 'A2RHS4',
#  'llmg_0206': 'A2RHS5',
#  'llmg_0207': 'A2RHS6',
#  'llmg_0209': 'A2RHS8',
#  'llmg_0210': 'A2RHS9',
#  'llmg_0211': 'A2RHT0',
#  'llmg_0212': 'A2RHT1',
#  'llmg_0214': 'A2RHT3',
#  'llmg_0216': 'A2RHT5',
#  'llmg_0217': 'A2RHT6',
#  'llmg_0218': 'A2RHT7',
#  'llmg_0219': 'A2RHT8',
#  'llmg_0220': 'A2RHT9',
#  'llmg_0221': 'A2RHU0',
#  'llmg_0222': 'A2RHU1',
#  'llmg_0223': 'A2RHU2',
#  'llmg_0224': 'A2RHU3',
#  'llmg_0226': 'A2RHU5',
#  'llmg_0229': 'A2RHU8',
#  'llmg_0230': 'A2RHU9',
#  'llmg_0231': 'A2RHV0',
#  'llmg_0233': 'A2RHV2',
#  'llmg_0235': 'A2RHV4',
#  'llmg_0242': 'A2RHW1',
#  'llmg_0244': 'A2RHW2',
#  'llmg_0251': 'A2RHW9',
#  'llmg_0253': 'A2RHX1',
#  'llmg_0260': 'A2RHX6',
#  'llmg_0263': 'A2RHX8',
#  'llmg_0265': 'A2RHY0',
#  'llmg_0271': 'A2RHY6',
#  'llmg_0273': 'A2RHY8',
#  'llmg_0276': 'A2RHZ1',
#  'llmg_0277': 'A2RHZ2',
#  'llmg_0280': 'A2RHZ5',
#  'llmg_0281': 'A2RHZ6',
#  'llmg_0288': 'A2RI02',
#  'llmg_0291': 'A2RI05',
#  'llmg_0292': 'A2RI06',
#  'llmg_0294': 'A2RI08',
#  'llmg_0296': 'A2RI10',
#  'llmg_0297': 'A2RI11',
#  'llmg_0299': 'A2RI13',
#  'llmg_0302': 'A2RI16',
#  'llmg_0306': 'A2RI19',
#  'llmg_0309': 'A2RI22',
#  'llmg_0311': 'A2RI24',
#  'llmg_0312': 'A2RI25',
#  'llmg_0313': 'A2RI26',
#  'llmg_0316': 'A2RI29',
#  'llmg_0318': 'A2RI31',
#  'llmg_0319': 'A2RI32',
#  'llmg_0324': 'A2RI37',
#  'llmg_0325': 'A2RI38',
#  'llmg_0326': 'A2RI39',
#  'llmg_0333': 'A2RI46',
#  'llmg_0335': 'A2RI48',
#  'llmg_0336': 'A2RI49',
#  'llmg_0341': 'P0CI33',
#  'llmg_0344': 'A2RI56',
#  'llmg_0350': 'A2RI62',
#  'llmg_0355': 'A2RI67',
#  'llmg_0356': 'A2RI68',
#  'llmg_0357': 'A2RI69',
#  'llmg_0358': 'A2RI70',
#  'llmg_0360': 'A2RI72',
#  'llmg_0361': 'A2RI73',
#  'llmg_0368': 'A2RI79',
#  'llmg_0369': 'A2RI80',
#  'llmg_0371': 'P0A3C2',
#  'llmg_0372': 'A2RI83',
#  'llmg_0373': 'A2RI84',
#  'llmg_0374': 'A2RI85',
#  'llmg_0375': 'A2RI86',
#  'llmg_0380': 'A2RI91',
#  'llmg_0382': 'A2RI93',
#  'llmg_0383': 'A2RI94',
#  'llmg_0385': 'A2RI96',
#  'llmg_0386': 'A2RI97',
#  'llmg_0389': 'A2RIA0',
#  'llmg_0395': 'A2RIA6',
#  'llmg_0397': 'A2RIA7',
#  'llmg_0400': 'A2RIB0',
#  'llmg_0401': 'A2RIB1',
#  'llmg_0402': 'A2RIB2',
#  'llmg_0403': 'Q48677',
#  'llmg_0406': 'A2RIB5',
#  'llmg_0407': 'A2RIB6',
#  'llmg_0408': 'A2RIB7',
#  'llmg_0410': 'Q9AEP8',
#  'llmg_0411': 'Q9AEP7',
#  'llmg_0414': 'A2RIC3',
#  'llmg_0415': 'A2RIC4',
#  'llmg_0416': 'A2RIC5',
#  'llmg_0419': 'A2RIC8',
#  'llmg_0425': 'A2RID4',
#  'llmg_0426': 'A2RID5',
#  'llmg_0429': 'P0A4J2',
#  'llmg_0433': 'A2RIE2',
#  'llmg_0437': 'A2RIE6',
#  'llmg_0438': 'A2RIE7',
#  'llmg_0444': 'A2RIF3',
#  'llmg_0445': 'A2RIF4',
#  'llmg_0446': 'A2RIF5',
#  'llmg_0447': 'A2RIF6',
#  'llmg_0448': 'A2RIF7',
#  'llmg_0451': 'A2RIG0',
#  'llmg_0453': 'A2RIG2',
#  'llmg_0455': 'A2RIG4',
#  'llmg_0456': 'A2RIG5',
#  'llmg_0461': 'A2RIH0',
#  'llmg_0462': 'A2RIH1',
#  'llmg_0465': 'A2RIH4',
#  'llmg_0466': 'A2RIH5',
#  'llmg_0467': 'O87761',
#  'llmg_0476': 'A2RII5',
#  'llmg_0481': 'A2RIJ0',
#  'llmg_0482': 'A2RIJ1',
#  'llmg_0483': 'A2RIJ2',
#  'llmg_0492': 'A2RIK1',
#  'llmg_0493': 'A2RIK2',
#  'llmg_0496': 'A2RIK5',
#  'llmg_0505': 'A2RIL4',
#  'llmg_0507': 'A2RIL6',
#  'llmg_0508': 'A2RIL7',
#  'llmg_0511': 'A2RIM0',
#  'llmg_0517': 'A2RIM6',
#  'llmg_0519': 'A2RIM8',
#  'llmg_0520': 'A2RIM9',
#  'llmg_0521': 'A2RIN0',
#  'llmg_0528': 'Q9S5Z2',
#  'llmg_0530': 'A2RIN9',
#  'llmg_0532': 'A2RIP1',
#  'llmg_0534': 'A2RIP3',
#  'llmg_0535': 'A2RIP4',
#  'llmg_0536': 'A2RIP5',
#  'llmg_0538': 'A2RIP6',
#  'llmg_0539': 'A2RIP7',
#  'llmg_0540': 'A2RIP8',
#  'llmg_0541': 'A2RIP9',
#  'llmg_0543': 'A2RIQ1',
#  'llmg_0544': 'A2RIQ2',
#  'llmg_0547': 'A2RIQ4',
#  'llmg_0552': 'A2RIQ9',
#  'llmg_0557': 'A2RIR4',
#  'llmg_0560': 'A2RIR7',
#  'llmg_0562': 'A2RIR9',
#  'llmg_0563': 'A2RIS0',
#  'llmg_0565': 'A2RIS2',
#  'llmg_0566': 'A2RIS3',
#  'llmg_0570': 'A2RIS6',
#  'llmg_0577': 'A2RIT2',
#  'llmg_0582': 'A2RIT6',
#  'llmg_0584': 'A2RIT8',
#  'llmg_0585': 'A2RIT9',
#  'llmg_0586': 'P96789',
#  'llmg_0587;llmg_0588': 'A2RIU1',
#  'llmg_0589': 'A2RIU2',
#  'llmg_0592': 'A2RIU5',
#  'llmg_0593': 'A2RIU6',
#  'llmg_0602': 'A2RIV5',
#  'llmg_0604': 'A2RIV7',
#  'llmg_0607': 'A2RIW0',
#  'llmg_0608': 'A2RIW1',
#  'llmg_0609': 'A2RIW2',
#  'llmg_0610': 'A2RIW3',
#  'llmg_0615': 'A2RIW9',
#  'llmg_0616': 'A2RIX0',
#  'llmg_0617': 'A2RIX1',
#  'llmg_0625': 'A2RIX9',
#  'llmg_0627': 'A2RIY1',
#  'llmg_0628': 'A2RIY2',
#  'llmg_0629': 'O32799',
#  'llmg_0630': 'A2RIY4',
#  'llmg_0633': 'A2RIY7',
#  'llmg_0634': 'A2RIY8',
#  'llmg_0636': 'A2RIZ0',
#  'llmg_0638': 'Q9ZAB0',
#  'llmg_0639': 'A2RIZ3',
#  'llmg_0640': 'P60376',
#  'llmg_0643': 'A2RIZ7',
#  'llmg_0655;pNZ712_21': 'pNZ712_21;A2RJ09',
#  'llmg_0658': 'A2RJ11',
#  'llmg_0661': 'A2RJ14',
#  'llmg_0673': 'A2RJ24',
#  'llmg_0697': 'A2RJ49',
#  'llmg_0698': 'A2RJ50',
#  'llmg_0699': 'A2RJ51',
#  'llmg_0701': 'A2RJ53',
#  'llmg_0702': 'A2RJ54',
#  'llmg_0722': 'A2RJ76',
#  'llmg_0724': 'A2RJ77',
#  'llmg_0726': 'A2RJ79',
#  'llmg_0727': 'A2RJ80',
#  'llmg_0729': 'A2RJ82',
#  'llmg_0732': 'A2RJ85',
#  'llmg_0733': 'A2RJ86',
#  'llmg_0737': 'A2RJ89',
#  'llmg_0738': 'A2RJ90',
#  'llmg_0739': 'A2RJ91',
#  'llmg_0740': 'A2RJ92',
#  'llmg_0741': 'A2RJ93',
#  'llmg_0742': 'A2RJ94',
#  'llmg_0744': 'A2RJ96',
#  'llmg_0745': 'A2RJ97',
#  'llmg_0746': 'A2RJ98',
#  'llmg_0747': 'A2RJ99',
#  'llmg_0749': 'A2RJA1',
#  'llmg_0751': 'A2RJA3',
#  'llmg_0752': 'A2RJA4',
#  'llmg_0753': 'A2RJA5',
#  'llmg_0761': 'A2RJB3',
#  'llmg_0762': 'A2RJB4',
#  'llmg_0763': 'A2RJB5',
#  'llmg_0765': 'A2RJB7',
#  'llmg_0766': 'A2RJB8',
#  'llmg_0768': 'A2RJC0',
#  'llmg_0769': 'A2RJC1',
#  'llmg_0771': 'A2RJC2',
#  'llmg_0772': 'A2RJC3',
#  'llmg_0774': 'A2RJC4',
#  'llmg_0775': 'A2RJC5',
#  'llmg_0778': 'A2RJC8',
#  'llmg_0779': 'A2RJC9',
#  'llmg_0782': 'A2RJD1',
#  'llmg_0783': 'A2RJD2',
#  'llmg_0793': 'A2RJE2',
#  'llmg_0834': 'A2RJH8',
#  'llmg_0852': 'A2RJJ5',
#  'llmg_0868': 'A2RJL0',
#  'llmg_0870': 'A2RJL2',
#  'llmg_0871': 'A2RJL3',
#  'llmg_0872': 'A2RJL4',
#  'llmg_0873': 'A2RJL5',
#  'llmg_0874': 'A2RJL6',
#  'llmg_0876': 'A2RJL8',
#  'llmg_0878': 'A2RJM0',
#  'llmg_0880': 'A2RJM2',
#  'llmg_0884': 'A2RJM6',
#  'llmg_0885': 'A2RJM7',
#  'llmg_0886': 'A2RJM8',
#  'llmg_0890': 'Q9L4N8',
#  'llmg_0891': 'A2RJN3',
#  'llmg_0893': 'Q9L4N6',
#  'llmg_0894': 'Q9L4N5',
#  'llmg_0906': 'A2RJP7',
#  'llmg_0908': 'A2RJP9',
#  'llmg_0911': 'A2RJQ2',
#  'llmg_0912': 'A2RJQ3',
#  'llmg_0913': 'A2RJQ4',
#  'llmg_0915': 'A2RJQ6',
#  'llmg_0926': 'A2RJR5',
#  'llmg_0928': 'A2RJR7',
#  'llmg_0929': 'A2RJR8',
#  'llmg_0930': 'A2RJR9',
#  'llmg_0931': 'A2RJS0',
#  'llmg_0932': 'A2RJS1',
#  'llmg_0933': 'A2RJS2',
#  'llmg_0935': 'A2RJS4',
#  'llmg_0936': 'A2RJS5',
#  'llmg_0937': 'A2RJS6',
#  'llmg_0940': 'A2RJS9',
#  'llmg_0943': 'A2RJT2',
#  'llmg_0945': 'A2RJT4',
#  'llmg_0947': 'A2RJT5',
#  'llmg_0948': 'A2RJT6',
#  'llmg_0952': 'A2RJT9',
#  'llmg_0955': 'A2RJU2',
#  'llmg_0964': 'A2RJV1',
#  'llmg_0973': 'A2RJW0',
#  'llmg_0974': 'A2RJW1',
#  'llmg_0975': 'A2RJW2',
#  'llmg_0976': 'A2RJW3',
#  'llmg_0977': 'A2RJW4',
#  'llmg_0986': 'O68185',
#  'llmg_0987': 'O68186',
#  'llmg_0988': 'A2RJX5',
#  'llmg_0989': 'A2RJX6',
#  'llmg_0993': 'A2RJX9',
#  'llmg_0994': 'A2RJY0',
#  'llmg_0995': 'A2RJY1',
#  'llmg_0997': 'A2RJY4',
#  'llmg_0999': 'A2RJY6',
#  'llmg_1000': 'A2RJY7',
#  'llmg_1008': 'Q9Z6H4',
#  'llmg_1017': 'A2RK04',
#  'llmg_1028': 'A2RK13',
#  'llmg_1041': 'A2RK24',
#  'llmg_1047': 'A2RK30',
#  'llmg_1048': 'A2RK31',
#  'llmg_1049': 'A2RK32',
#  'llmg_1051': 'A2RK34',
#  'llmg_1058': 'A2RK41',
#  'llmg_1060': 'A2RK43',
#  'llmg_1062': 'A2RK45',
#  'llmg_1064': 'A2RK47',
#  'llmg_1065': 'A2RK48',
#  'llmg_1067': 'A2RK50',
#  'llmg_1080': 'A2RK64',
#  'llmg_1086': 'A2RK70',
#  'llmg_1088': 'O32770',
#  'llmg_1089': 'O32771',
#  'llmg_1099': 'A2RK83',
#  'llmg_1103': 'A2RK87',
#  'llmg_1105': 'P56968',
#  'llmg_1106': 'P54322',
#  'llmg_1107': 'P50924',
#  'llmg_1109': 'A2RK93',
#  'llmg_1113': 'A2RK97',
#  'llmg_1114': 'A2RK98',
#  'llmg_1115': 'A2RK99',
#  'llmg_1116': 'A2RKA0',
#  'llmg_1117': 'A2RKA1',
#  'llmg_1118': 'A2RKA2',
#  'llmg_1119': 'A2RKA3',
#  'llmg_1120': 'A2RKA4',
#  'llmg_1122': 'A2RKA6',
#  'llmg_1123': 'A2RKA7',
#  'llmg_1125': 'A2RKA9',
#  'llmg_1131': 'A2RKB5',
#  'llmg_1133': 'A2RKB7',
#  'llmg_1135': 'A2RKB9',
#  'llmg_1171': 'A2RKF4',
#  'llmg_1175': 'A2RKF8',
#  'llmg_1176': 'O30415',
#  'llmg_1179': 'O30418',
#  'llmg_1181': 'A2RKG4',
#  'llmg_1183': 'A2RKG6',
#  'llmg_1184': 'A2RKG7',
#  'llmg_1185': 'A2RKG8',
#  'llmg_1186': 'A2RKG9',
#  'llmg_1187': 'A2RKH0',
#  'llmg_1188': 'A2RKH1',
#  'llmg_1189': 'A2RKH2',
#  'llmg_1194': 'A2RKH7',
#  'llmg_1202': 'A2RKI4',
#  'llmg_1203': 'A2RKI5',
#  'llmg_1204': 'A2RKI6',
#  'llmg_1207': 'A2RKI8',
#  'llmg_1208': 'A2RKI9',
#  'llmg_1219': 'A2RKJ8',
#  'llmg_1225': 'A2RKK4',
#  'llmg_1227': 'A2RKK6',
#  'llmg_1252': 'A2RKN1',
#  'llmg_1253': 'A2RKN2',
#  'llmg_1258': 'A2RKN7',
#  'llmg_1263;llmg_2143': 'A2RN23',
#  'llmg_1271': 'A2RKQ0',
#  'llmg_1272': 'A2RKQ1',
#  'llmg_1276': 'A2RKQ5',
#  'llmg_1277': 'A2RKQ6',
#  'llmg_1280': 'A2RKQ9',
#  'llmg_1295': 'A2RKS2',
#  'llmg_1298': 'A2RKS5',
#  'llmg_1304': 'A2RKT1',
#  'llmg_1309': 'A2RKT5',
#  'llmg_1310': 'A2RKT6',
#  'llmg_1311': 'A2RKT7',
#  'llmg_1314': 'A2RKT9',
#  'llmg_1315': 'A2RKU0',
#  'llmg_1317': 'A2RKU2',
#  'llmg_1325': 'A2RKV0',
#  'llmg_1328': 'A2RKV3',
#  'llmg_1329': 'A2RKV4',
#  'llmg_1330': 'A2RKV5',
#  'llmg_1331': 'A2RKV6',
#  'llmg_1332': 'A2RKV7',
#  'llmg_1334': 'A2RKV9',
#  'llmg_1336': 'A2RKW1',
#  'llmg_1337': 'Q8GJP4',
#  'llmg_1339': 'Q9L6G1',
#  'llmg_1340': 'Q8GJP6',
#  'llmg_1342': 'A2RKW6',
#  'llmg_1346': 'A2RKX0',
#  'llmg_1350': 'A2RKX4',
#  'llmg_1351': 'A2RKX5',
#  'llmg_1352': 'A2RKX6',
#  'llmg_1353': 'A2RKX7',
#  'llmg_1354': 'A2RKX8',
#  'llmg_1355': 'A2RKX9',
#  'llmg_1356': 'A2RKY0',
#  'llmg_1357': 'A2RKY1',
#  'llmg_1358': 'A2RKY2',
#  'llmg_1399': 'A2RL19',
#  'llmg_1412': 'A2RL29',
#  'llmg_1414': 'A2RL31',
#  'llmg_1415': 'A2RL32',
#  'llmg_1418': 'A2RL35',
#  'llmg_1424': 'A2RL40',
#  'llmg_1425': 'A2RL41',
#  'llmg_1426': 'A2RL42',
#  'llmg_1429': 'A2RL45',
#  'llmg_1430': 'A2RL46',
#  'llmg_1432': 'A2RL48',
#  'llmg_1441': 'A2RL55',
#  'llmg_1442': 'A2RL56',
#  'llmg_1445': 'A2RL58',
#  'llmg_1448': 'A2RL61',
#  'llmg_1450': 'A2RL63',
#  'llmg_1451': 'A2RL64',
#  'llmg_1453': 'A2RL66',
#  'llmg_1463': 'A2RL76',
#  'llmg_1464': 'A2RL77',
#  'llmg_1465': 'A2RL78',
#  'llmg_1466': 'A2RL79',
#  'llmg_1468': 'A2RL81',
#  'llmg_1470': 'A2RL82',
#  'llmg_1471': 'A2RL83',
#  'llmg_1472': 'A2RL84',
#  'llmg_1475': 'A2RL87',
#  'llmg_1477': 'A2RL88',
#  'llmg_1478': 'A2RL89',
#  'llmg_1487': 'A2RL98',
#  'llmg_1489': 'A2RLA0',
#  'llmg_1491': 'A2RLA2',
#  'llmg_1493': 'A2RLA4',
#  'llmg_1496': 'A2RLA7',
#  'llmg_1497': 'A2RLA8',
#  'llmg_1498': 'A2RLA9',
#  'llmg_1499': 'A2RLB0',
#  'llmg_1502': 'A2RLB3',
#  'llmg_1508': 'A2RLB9',
#  'llmg_1509': 'A2RLC0',
#  'llmg_1512': 'A2RLC1',
#  'llmg_1514': 'A2RLC3',
#  'llmg_1516': 'A2RLC5',
#  'llmg_1524': 'A2RLD3',
#  'llmg_1529': 'A2RLD8',
#  'llmg_1530': 'A2RLD9',
#  'llmg_1531': 'A2RLE0',
#  'llmg_1532': 'A2RLE1',
#  'llmg_1534': 'A2RLE3',
#  'llmg_1536': 'A2RLE4',
#  'llmg_1537': 'A2RLE5',
#  'llmg_1539': 'A2RLE7',
#  'llmg_1543': 'A2RLF1',
#  'llmg_1544': 'A2RLF2',
#  'llmg_1545': 'A2RLF3',
#  'llmg_1546': 'A2RLF4',
#  'llmg_1547': 'A2RLF5',
#  'llmg_1550': 'A2RLF8',
#  'llmg_1554': 'A2RLG2',
#  'llmg_1556': 'A2RLG4',
#  'llmg_1557': 'A2RLG5',
#  'llmg_1559': 'A2RLG7',
#  'llmg_1568': 'A2RLH5',
#  'llmg_1574': 'P0A3J1',
#  'llmg_1575': 'P42369',
#  'llmg_1576': 'P42370',
#  'llmg_1579': 'A2RLI6',
#  'llmg_1580': 'A2RLI7',
#  'llmg_1581': 'A2RLI8',
#  'llmg_1582': 'A2RLI9',
#  'llmg_1588': 'A2RLJ5',
#  'llmg_1590': 'A2RLJ7',
#  'llmg_1593': 'A2RLJ9',
#  'llmg_1595': 'A2RLK1',
#  'llmg_1596': 'A2RLK2',
#  'llmg_1597': 'A2RLK3',
#  'llmg_1599': 'O32810',
#  'llmg_1601': 'O32808',
#  'llmg_1627': 'A2RLN1',
#  'llmg_1630': 'A2RLN4',
#  'llmg_1631': 'A2RLN5',
#  'llmg_1641': 'A2RLP5',
#  'llmg_1645': 'A2RLP9',
#  'llmg_1646': 'A2RLQ0',
#  'llmg_1647': 'A2RLQ1',
#  'llmg_1648': 'Q9AQE3',
#  'llmg_1649': 'Q7BPI7',
#  'llmg_1662': 'A2RLR6',
#  'llmg_1671': 'A2RLS5',
#  'llmg_1675': 'A2RLS8',
#  'llmg_1676': 'A2RLS9',
#  'llmg_1679': 'A2RLT2',
#  'llmg_1681': 'A2RLT4',
#  'llmg_1685': 'A2RLT8',
#  'llmg_1686': 'A2RLT9',
#  'llmg_1691': 'A2RLU3',
#  'llmg_1692': 'A2RLU4',
#  'llmg_1693': 'A2RLU5',
#  'llmg_1694;pNZ712_23': 'A2RLU6',
#  'llmg_1700': 'A2RLV0',
#  'llmg_1702': 'A2RLV2',
#  'llmg_1706': 'A2RLV6',
#  'llmg_1720': 'A2RLW8',
#  'llmg_1724': 'A2RLX0',
#  'llmg_1725': 'A2RLX1',
#  'llmg_1732': 'A2RLX8',
#  'llmg_1734': 'A2RLY0',
#  'llmg_1735': 'A2RLY1',
#  'llmg_1741': 'A2RLY6',
#  'llmg_1743': 'A2RLY8',
#  'llmg_1744': 'A2RLY9',
#  'llmg_1746': 'A2RLZ1',
#  'llmg_1751': 'A2RLZ6',
#  'llmg_1752': 'A2RLZ7',
#  'llmg_1753': 'A2RLZ8',
#  'llmg_1759': 'A2RM04',
#  'llmg_1762': 'A2RM07',
#  'llmg_1763': 'A2RM08',
#  'llmg_1764': 'A2RM09',
#  'llmg_1765': 'A2RM10',
#  'llmg_1768': 'A2RM13',
#  'llmg_1770': 'A2RM15',
#  'llmg_1773': 'A2RM18',
#  'llmg_1777': 'A2RM22',
#  'llmg_1778': 'A2RM23',
#  'llmg_1779': 'A2RM24',
#  'llmg_1781': 'A2RM26',
#  'llmg_1782': 'A2RM27',
#  'llmg_1783': 'A2RM28',
#  'llmg_1784': 'A2RM29',
#  'llmg_1785': 'A2RM30',
#  'llmg_1786': 'A2RM31',
#  'llmg_1787': 'A2RM32',
#  'llmg_1789': 'A2RM34',
#  'llmg_1791': 'A2RM36',
#  'llmg_1792': 'A2RM37',
#  'llmg_1793': 'A2RM38',
#  'llmg_1794': 'A2RM39',
#  'llmg_1796': 'A2RM40',
#  'llmg_1797': 'A2RM41',
#  'llmg_1805': 'A2RM49',
#  'llmg_1807': 'A2RM51',
#  'llmg_1808': 'A2RM52',
#  'llmg_1809': 'A2RM53',
#  'llmg_1810': 'A2RM54',
#  'llmg_1811': 'A2RM55',
#  'llmg_1812': 'A2RM56',
#  'llmg_1813': 'A2RM57',
#  'llmg_1814': 'A2RM58',
#  'llmg_1815': 'A2RM59',
#  'llmg_1816': 'A2RM60',
#  'llmg_1817': 'A2RM61',
#  'llmg_1819': 'A2RM63',
#  'llmg_1820': 'A2RM64',
#  'llmg_1822': 'A2RM66',
#  'llmg_1823': 'A2RM67',
#  'llmg_1825': 'A2RM69',
#  'llmg_1826': 'A2RM70',
#  'llmg_1829': 'A2RM73',
#  'llmg_1831': 'A2RM75',
#  'llmg_1845': 'A2RM89',
#  'llmg_1849': 'A2RM93',
#  'llmg_1853': 'A2RM97',
#  'llmg_1861': 'A2RMA4',
#  'llmg_1862': 'A2RMA5',
#  'llmg_1869': 'A2RMB2',
#  'llmg_1871': 'A2RMB4',
#  'llmg_1878': 'A2RMC0',
#  'llmg_1879': 'A2RMC1',
#  'llmg_1880': 'A2RMC2',
#  'llmg_1881': 'A2RMC3',
#  'llmg_1882': 'A2RMC4',
#  'llmg_1895': 'A2RMD5',
#  'llmg_1896': 'A2RMD6',
#  'llmg_1897': 'A2RMD7',
#  'llmg_1898': 'A2RMD8',
#  'llmg_1900': 'A2RME0',
#  'llmg_1906': 'A2RME6',
#  'llmg_1907': 'A2RME7',
#  'llmg_1908': 'A2RME8',
#  'llmg_1909': 'A2RME9',
#  'llmg_1913': 'A2RMF2',
#  'llmg_1914': 'A2RMF3',
#  'llmg_1915': 'A2RMF4',
#  'llmg_1916': 'A2RMF5',
#  'llmg_1917': 'A2RMF6',
#  'llmg_1921': 'A2RMG0',
#  'llmg_1922': 'A2RMG1',
#  'llmg_1924': 'P43909',
#  'llmg_1926': 'P43905',
#  'llmg_1927': 'P43901',
#  'llmg_1928': 'A2RMG7',
#  'llmg_1929': 'A2RMG8',
#  'llmg_1934': 'A2RMH2',
#  'llmg_1938': 'A2RMH5',
#  'llmg_1939': 'A2RMH6',
#  'llmg_1942': 'A2RMH8',
#  'llmg_1943': 'A2RMH9',
#  'llmg_1945': 'Q9RAT9',
#  'llmg_1946': 'A2RMI2',
#  'llmg_1947': 'Q9RAU1',
#  'llmg_1948': 'A2RMI4',
#  'llmg_1949': 'A2RMI5',
#  'llmg_1950': 'P0A2Z1',
#  'llmg_1953': 'A2RMI9',
#  'llmg_1956': 'A2RMJ1',
#  'llmg_1957': 'A2RMJ2',
#  'llmg_1959': 'A2RMJ4',
#  'llmg_1969': 'A2RMK5',
#  'llmg_1970': 'A2RMK6',
#  'llmg_1973': 'A2RMK9',
#  'llmg_1974': 'A2RML0',
#  'llmg_1977': 'A2RML4',
#  'llmg_1978': 'A2RML5',
#  'llmg_1979': 'A2RML6',
#  'llmg_1981': 'A2RML8',
#  'llmg_1982': 'A2RML9',
#  'llmg_1985': 'A2RMM2',
#  'llmg_1988': 'A2RMM4',
#  'llmg_1989': 'A2RMM5',
#  'llmg_1994': 'A2RMN0',
#  'llmg_1996': 'A2RMN2',
#  'llmg_1997': 'A2RMN3',
#  'llmg_1999': 'A2RMN4',
#  'llmg_2004': 'A2RMN8',
#  'llmg_2008': 'A2RMP2',
#  'llmg_2011': 'A2RMP5',
#  'llmg_2012': 'A2RMP6',
#  'llmg_2017': 'A2RMQ1',
#  'llmg_2018': 'A2RMQ2',
#  'llmg_2019': 'A2RMQ3',
#  'llmg_2020': 'A2RMQ4',
#  'llmg_2021': 'A2RMQ5',
#  'llmg_2023': 'A2RMQ7',
#  'llmg_2029': 'A2RMR1',
#  'llmg_2030': 'A2RMR2',
#  'llmg_2031': 'A2RMR3',
#  'llmg_2035': 'O32806',
#  'llmg_2040': 'A2RMS1',
#  'llmg_2043': 'A2RMS4',
#  'llmg_2044': 'A2RMS5',
#  'llmg_2045': 'A2RMS6',
#  'llmg_2046': 'A2RMS7',
#  'llmg_2047': 'A2RMS8',
#  'llmg_2049': 'A2RMT0',
#  'llmg_2050': 'A2RMT1',
#  'llmg_2051': 'A2RMT2',
#  'llmg_2053': 'A2RMT4',
#  'llmg_2055': 'A2RMT6',
#  'llmg_2058': 'Q9ZAI9',
#  'llmg_2059': 'A2RMU0',
#  'llmg_2060': 'A2RMU1',
#  'llmg_2061': 'A2RMU2',
#  'llmg_2062': 'A2RMU3',
#  'llmg_2063': 'A2RMU4',
#  'llmg_2069': 'A2RMV0',
#  'llmg_2073': 'A2RMV4',
#  'llmg_2075': 'A2RMV6',
#  'llmg_2076': 'A2RMV7',
#  'llmg_2077': 'A2RMV8',
#  'llmg_2078': 'A2RMV9',
#  'llmg_2079': 'A2RMW0',
#  'llmg_2080': 'A2RMW1',
#  'llmg_2081': 'A2RMW2',
#  'llmg_2136': 'A2RN16',
#  'llmg_2139': 'A2RN19',
#  'llmg_2147': 'A2RN27',
#  'llmg_2153': 'A2RN33',
#  'llmg_2154': 'A2RN34',
#  'llmg_2155': 'A2RN35',
#  'llmg_2156': 'A2RN36',
#  'llmg_2157': 'A2RN37',
#  'llmg_2159;llmg_2160': 'A2RN40',
#  'llmg_2161': 'A2RN41',
#  'llmg_2162': 'A2RN42',
#  'llmg_2163': 'A2RN43',
#  'llmg_2164': 'A2RN44',
#  'llmg_2165': 'A2RN45',
#  'llmg_2167': 'A2RN46',
#  'llmg_2169': 'A2RN48',
#  'llmg_2170': 'A2RN49',
#  'llmg_2172': 'A2RN51',
#  'llmg_2176': 'P50926',
#  'llmg_2183': 'A2RN62',
#  'llmg_2185': 'A2RN64',
#  'llmg_2186': 'A2RN65',
#  'llmg_2187': 'A2RN66',
#  'llmg_2190': 'A2RN69',
#  'llmg_2193': 'A2RN72',
#  'llmg_2194': 'A2RN73',
#  'llmg_2195': 'A2RN74',
#  'llmg_2196': 'A2RN75',
#  'llmg_2198': 'A2RN77',
#  'llmg_2201': 'A2RN80',
#  'llmg_2204': 'A2RN83',
#  'llmg_2209': 'A2RN88',
#  'llmg_2211': 'A2RN90',
#  'llmg_2212': 'A2RN91',
#  'llmg_2215': 'A2RN94',
#  'llmg_2217': 'A2RN96',
#  'llmg_2225': 'A2RNA4',
#  'llmg_2228': 'A2RNA7',
#  'llmg_2232': 'A2RNB1',
#  'llmg_2233': 'A2RNB2',
#  'llmg_2241': 'A2RNB8',
#  'llmg_2242': 'A2RNB9',
#  'llmg_2243': 'A2RNC0',
#  'llmg_2244': 'A2RNC1',
#  'llmg_2248': 'A2RNC5',
#  'llmg_2262': 'A2RND9',
#  'llmg_2269': 'A2RNE6',
#  'llmg_2271': 'A2RNE8',
#  'llmg_2272': 'A2RNE9',
#  'llmg_2273': 'A2RNF0',
#  'llmg_2274': 'A2RNF1',
#  'llmg_2276': 'A2RNF3',
#  'llmg_2277': 'A2RNF4',
#  'llmg_2279': 'A2RNF6',
#  'llmg_2281': 'A2RNF8',
#  'llmg_2282': 'A2RNF9',
#  'llmg_2284': 'A2RNG1',
#  'llmg_2285': 'Q9Z5K8',
#  'llmg_2288': 'A2RNG4',
#  'llmg_2289': 'A2RNG5',
#  'llmg_2292': 'A2RNG8',
#  'llmg_2299': 'A2RNH4',
#  'llmg_2300': 'A2RNH5',
#  'llmg_2302': 'A2RNH7',
#  'llmg_2308': 'A2RNI2',
#  'llmg_2309': 'A2RNI3',
#  'llmg_2310': 'A2RNI4',
#  'llmg_2312': 'Q9K575',
#  'llmg_2313': 'Q9K576',
#  'llmg_2314': 'A2RNI8',
#  'llmg_2315': 'A2RNI9',
#  'llmg_2316': 'A2RNJ0',
#  'llmg_2318': 'A2RNJ1',
#  'llmg_2319': 'A2RNJ2',
#  'llmg_2322': 'A2RNJ5',
#  'llmg_2323': 'A2RNJ6',
#  'llmg_2325': 'A2RNJ8',
#  'llmg_2327': 'A2RNK0',
#  'llmg_2328': 'A2RNK1',
#  'llmg_2329': 'A2RNK2',
#  'llmg_2330': 'A2RNK3',
#  'llmg_2331': 'A2RNK4',
#  'llmg_2332': 'A2RNK5',
#  'llmg_2333': 'A2RNK6',
#  'llmg_2336': 'A2RNK9',
#  'llmg_2341': 'A2RNL4',
#  'llmg_2343': 'A2RNL6',
#  'llmg_2353': 'A2RNM6',
#  'llmg_2354': 'A2RNM7',
#  'llmg_2355': 'A2RNM8',
#  'llmg_2356': 'A2RNM9',
#  'llmg_2357': 'A2RNN0',
#  'llmg_2358': 'A2RNN1',
#  'llmg_2359': 'A2RNN2',
#  'llmg_2361': 'A2RNN3',
#  'llmg_2362': 'A2RNN4',
#  'llmg_2363': 'A2RNN5',
#  'llmg_2364': 'A2RNN6',
#  'llmg_2365': 'A2RNN7',
#  'llmg_2366': 'A2RNN8',
#  'llmg_2367': 'A2RNN9',
#  'llmg_2370': 'A2RNP2',
#  'llmg_2371': 'A2RNP3',
#  'llmg_2372': 'A2RNP4',
#  'llmg_2373': 'A2RNP5',
#  'llmg_2374': 'A2RNP6',
#  'llmg_2375': 'A2RNP7',
#  'llmg_2376': 'A2RNP8',
#  'llmg_2377': 'A2RNP9',
#  'llmg_2378': 'A2RNQ0',
#  'llmg_2379': 'A2RNQ1',
#  'llmg_2380': 'A2RNQ2',
#  'llmg_2381': 'A2RNQ3',
#  'llmg_2382': 'A2RNQ4',
#  'llmg_2383': 'A2RNQ5',
#  'llmg_2384': 'A2RNQ6',
#  'llmg_2387': 'A2RNQ9',
#  'llmg_2388': 'A2RNR0',
#  'llmg_2391': 'A2RNR3',
#  'llmg_2392': 'A2RNR4',
#  'llmg_2400': 'A2RNS1',
#  'llmg_2409': 'A2RNT0',
#  'llmg_2412': 'A2RNT2',
#  'llmg_2413': 'A2RNT3',
#  'llmg_2415': 'A2RNT5',
#  'llmg_2416': 'A2RNT6',
#  'llmg_2419': 'A2RNT9',
#  'llmg_2420': 'A2RNU0',
#  'llmg_2421': 'A2RNU1',
#  'llmg_2422': 'A2RNU2',
#  'llmg_2425': 'O32801',
#  'llmg_2428': 'A2RNU8',
#  'llmg_2429': 'A2RNU9',
#  'llmg_2430': 'A2RNV0',
#  'llmg_2431': 'O86281',
#  'llmg_2432': 'A2RNV2',
#  'llmg_2442': 'A2RNW1',
#  'llmg_2448': 'A2RNW8',
#  'llmg_2455': 'A2RNX5',
#  'llmg_2460': 'A2RNY0',
#  'llmg_2463': 'A2RNY2',
#  'llmg_2464': 'A2RNY3',
#  'llmg_2466': 'A2RNY5',
#  'llmg_2468': 'A2RNY7',
#  'llmg_2473': 'A2RNZ2',
#  'llmg_2474': 'A2RNZ3',
#  'llmg_2475': 'A2RNZ4',
#  'llmg_2478': 'A2RNZ7',
#  'llmg_2479': 'A2RNZ8',
#  'llmg_2481': 'A2RP00',
#  'llmg_2482': 'A2RP01',
#  'llmg_2484': 'A2RP03',
#  'llmg_2485': 'A2RP04',
#  'llmg_2487': 'A2RP06',
#  'llmg_2489': 'A2RP08',
#  'llmg_2490': 'A2RP09',
#  'llmg_2491': 'A2RP10',
#  'llmg_2494': 'A2RP13',
#  'llmg_2498': 'A2RP17',
#  'llmg_2499': 'A2RP18',
#  'llmg_2502': 'A2RP20',
#  'llmg_2504': 'A2RP21',
#  'llmg_2505': 'A2RP22',
#  'llmg_2506': 'A2RP23',
#  'llmg_2507': 'P22865',
#  'llmg_2509': 'A2RP26',
#  'llmg_2511': 'A2RP28',
#  'llmg_2512': 'A2RP29',
#  'llmg_2516': 'A2RP33',
#  'llmg_2517': 'A2RP34',
#  'llmg_2518': 'A2RP35',
#  'llmg_2520': 'A2RP36',
#  'llmg_2521': 'A2RP37',
#  'llmg_2523': 'A2RP39',
#  'llmg_2526': 'A2RP42',
#  'llmg_2539': 'A2RP55',
#  'llmg_2540': 'A2RP56',
#  'llmg_2545': 'A2RP61',
#  'llmg_2546': 'A2RP62',
#  'llmg_2547': 'A2RP63',
#  'llmg_2548': 'A2RP64',
#  'llmg_2550': 'A2RP66',
#  'llmg_2551': 'P0A400',
#  'llmg_2556': 'A2RP72',
#  'llmg_2557': 'A2RP73',
#  'llmg_2558': 'A2RP74',
#  'llmg_2560': 'A2RP76',
#  'pSH74_09': 'A2RJ63'}

# %%
# Handle the exceptions to the llmg_to_uniprotID dict
llmg_to_uniprotID['llmg_0587'] = 'A2RIU1'
llmg_to_uniprotID['llmg_0588'] = 'A2RIU1'
llmg_to_uniprotID['llmg_1694'] = 'A2RLU6'
llmg_to_uniprotID['pNZ712_23'] = 'A2RLU6'
llmg_to_uniprotID['llmg_1263'] = 'A2RN23'
llmg_to_uniprotID['llmg_2143'] = 'A2RN23'
llmg_to_uniprotID['llmg_2159'] = 'A2RN40'
llmg_to_uniprotID['llmg_2160'] = 'A2RN40'
llmg_to_uniprotID['llmg_0655'] = 'A2RJ09'
llmg_to_uniprotID['pNZ712_21'] = 'A2RJ09'

llmg_to_uniprotID['llmg_1347'] = 'A2RKX1'
llmg_to_uniprotID['llmg_1359'] = 'A2RKX1'
llmg_to_uniprotID['llmg_1348'] = 'A2RKX2'
llmg_to_uniprotID['llmg_1360'] = 'A2RKX2'

# %% [markdown]
# <a id='data_selection'></a>

# %% [markdown]
# ## 4. Data selection

# %% [markdown]
# <a id='statistics'></a>

# %% [markdown]
# ### 4.1 Select fold changes and statistical data

# %%
# get the q-values from the imported data, preprocessed with perseus software.
lfq_stats = pd.concat([preprocessed_data["Gene names  (ordered locus )"],
                       pd.to_numeric(preprocessed_data["Student's T-test Difference ccpa mutant_wt"]), #log10 FC
                       pd.to_numeric(preprocessed_data["Student's T-test q-value ccpa mutant_wt"]),
                       pd.to_numeric(preprocessed_data["-Log Student's T-test p-value ccpa mutant_wt"]),
                       pd.DataFrame(index=preprocessed_data.index.copy(), columns=['ss'])], axis=1)
lfq_stats.columns=['locus_tag', 'fc', 'q', '-log p', 'ss']
lfq_stats
# Out:
#                                 locus_tag        fc         q    -log p   ss
# Majority protein IDs
# A2RH74                          llmg_0001 -0.132099  0.264639  2.082433  NaN
# A2RH77                          llmg_0004 -0.054423  0.511242  0.583484  NaN
# A2RH80                          llmg_0007  0.009273  0.912047  0.105554  NaN
# A2RH85                          llmg_0012 -0.013909  0.880637  0.047358  NaN
# A2RH86                          llmg_0013 -0.114538  0.290903  0.596419  NaN
# A2RH92                          llmg_0020 -0.073949  0.412994  0.500007  NaN
# A2RH93                          llmg_0021 -0.109214  0.292193  1.227080  NaN
# A2RH94                          llmg_0022 -0.245764  0.158097  2.085083  NaN
# A2RH95                          llmg_0023 -0.235218  0.161725  2.700304  NaN
# A2RH96                          llmg_0024 -0.344938  0.078714  4.083619  NaN
# A2RH97                          llmg_0025 -0.806220  0.005474  3.057232  NaN
# A2RHD7                          llmg_0066  0.112976  0.282889  1.816027  NaN
# A2RHE1                          llmg_0071 -0.010701  0.899896  0.074590  NaN
# A2RHE2                          llmg_0072 -0.066987  0.427725  2.012107  NaN
# A2RHE3                          llmg_0073 -0.067204  0.428919  1.439412  NaN
# A2RHE4                          llmg_0074  0.022312  0.785283  0.294001  NaN
# A2RHE5                          llmg_0075  0.142508  0.259776  2.289136  NaN
# A2RHE9                          llmg_0079  0.009129  0.911412  0.569705  NaN
# A2RHF3                          llmg_0083  0.078834  0.396667  0.489759  NaN
# A2RHF4                          llmg_0084 -0.128049  0.265030  1.503208  NaN
# A2RHF5                          llmg_0085 -0.035295  0.656554  0.640241  NaN
# A2RHG2                          llmg_0091  0.028738  0.720551  0.257286  NaN
# A2RHG3                          llmg_0092 -0.005198  0.956325  0.062407  NaN
# A2RHG4                          llmg_0093  0.046964  0.561966  0.515008  NaN
# A2RHG9                          llmg_0098  0.085546  0.365845  0.475749  NaN
# A2RHH6                          llmg_0105  0.102208  0.323455  0.400370  NaN
# A2RHH7                          llmg_0106 -0.019451  0.822441  0.176390  NaN
# A2RHI1                          llmg_0110  0.004893  0.961552  0.021554  NaN
# A2RHI2                          llmg_0111 -0.024597  0.764575  0.286802  NaN
# A2RHI3                          llmg_0112 -0.194049  0.225360  1.077999  NaN
# ...                                   ...       ...       ...       ...  ...
# P43905                          llmg_1926 -0.159935  0.250135  1.615064  NaN
# P43909                          llmg_1924  0.017653  0.837455  0.190078  NaN
# P50924                          llmg_1107  0.260724  0.142748  2.505528  NaN
# P50926                          llmg_2176  0.128842  0.265697  1.324321  NaN
# P54322                          llmg_1106  0.160252  0.257986  0.423743  NaN
# P56968                          llmg_1105  0.312241  0.098367  3.190497  NaN
# P60376                          llmg_0640  0.393322  0.073394  4.949282  NaN
# P96789                          llmg_0586 -0.055046  0.496654  1.600703  NaN
# pNZ712_21;A2RJ09      llmg_0655;pNZ712_21  0.031742  0.696859  0.172508  NaN
# Q48677                          llmg_0403  0.139232  0.261889  1.318764  NaN
# Q59491                          llmg_0138  1.403396  0.000000  4.355223  NaN
# Q7BPI7                          llmg_1649 -0.067805  0.434066  0.697660  NaN
# Q8GJP4                          llmg_1337  0.040438  0.613982  0.784587  NaN
# Q8GJP6                          llmg_1340  0.072589  0.407969  1.231378  NaN
# Q9AEP7                          llmg_0411 -0.088459  0.338705  2.475170  NaN
# Q9AEP8                          llmg_0410  0.007841  0.926183  0.039171  NaN
# Q9AQE3                          llmg_1648 -0.156392  0.253773  1.217148  NaN
# Q9K575                          llmg_2312  0.548657  0.041053  6.428737  NaN
# Q9K576                          llmg_2313  0.572353  0.042588  5.599484  NaN
# Q9L4N5                          llmg_0894  0.235934  0.165923  1.962319  NaN
# Q9L4N6                          llmg_0893  0.223817  0.174410  3.001809  NaN
# Q9L4N8                          llmg_0890  0.244768  0.157397  2.186185  NaN
# Q9L6G1                          llmg_1339  0.011420  0.893648  0.080212  NaN
# Q9RAT9                          llmg_1945  0.372891  0.119009  0.465582  NaN
# Q9RAU1                          llmg_1947  0.013510  0.879612  0.203606  NaN
# Q9S5Z2                          llmg_0528  0.043074  0.602600  0.346720  NaN
# Q9Z5K8                          llmg_2285 -0.122483  0.268356  2.575521  NaN
# Q9Z6H4                          llmg_1008 -0.013999  0.872000  0.216307  NaN
# Q9ZAB0                          llmg_0638  0.408584  0.073250  3.846373  NaN
# Q9ZAI9                          llmg_2058 -0.000258  0.997294  0.001408  NaN
#
# [906 rows x 5 columns]

# %%
# Define factor for statistical significance 
# (to highlight the statistical significantly changed genes in the visualization step)
# If q < 0.05 than statistical significant = True
for locus_tag in lfq_stats.index:
    if lfq_stats['q'][locus_tag] < 0.05:
        lfq_stats.at[locus_tag,'ss'] = True
    elif lfq_stats['q'][locus_tag] == 0.05:
        print locus_tag
        lfq_stats.at[locus_tag,'ss'] = False
    else:
        lfq_stats.at[locus_tag,'ss'] = False

# %%
lfq_stats.head()
# Out:
#                       locus_tag        fc         q    -log p     ss
# Majority protein IDs
# A2RH74                llmg_0001 -0.132099  0.264639  2.082433  False
# A2RH77                llmg_0004 -0.054423  0.511242  0.583484  False
# A2RH80                llmg_0007  0.009273  0.912047  0.105554  False
# A2RH85                llmg_0012 -0.013909  0.880637  0.047358  False
# A2RH86                llmg_0013 -0.114538  0.290903  0.596419  False

# %%
# Create dataframe with locus tags as index
lfq_stats_llmg = lfq_stats.copy()
lfq_stats_llmg.set_index("locus_tag", inplace=True)
lfq_stats_llmg.head()
# Out:
#                  fc         q    -log p     ss
# locus_tag
# llmg_0001 -0.132099  0.264639  2.082433  False
# llmg_0004 -0.054423  0.511242  0.583484  False
# llmg_0007  0.009273  0.912047  0.105554  False
# llmg_0012 -0.013909  0.880637  0.047358  False
# llmg_0013 -0.114538  0.290903  0.596419  False

# %%
## REMOVE?
#pd.DataFrame(10**lfq_stats_llmg["fc"]).to_csv("ccpa_fc.txt", sep="\t")

# %% [markdown]
# #### Focus on significantly changed proteins: the "interesting" ones

# %%
interesting = lfq_stats_llmg[lfq_stats_llmg["ss"]==True]
for gid in interesting.index:
    #print gid
    print lfq_stats_llmg.loc[gid]
    if gid in cmod.getGeneIds():
        print cmod.getGene(gid).getName()
        print cmod.getAllProteinGeneAssociations()[gid]
# Out:
# fc          -0.80622
# q         0.00547368
# -log p       3.05723
# ss              True
# Name: llmg_0025, dtype: object
# mtlD
# ['R_M1PD']
# fc        1.38761
# q               0
# -log p    3.38786
# ss           True
# Name: llmg_0139, dtype: object
# argH
# ['R_ARGSL']
# fc        0.669125
# q             0.04
# -log p     1.31144
# ss            True
# Name: llmg_0219, dtype: object
# fc       -0.470252
# q          0.04616
# -log p     7.68311
# ss            True
# Name: llmg_0280, dtype: object
# fc          1.15174
# q         0.0369091
# -log p     0.724629
# ss             True
# Name: llmg_0294, dtype: object
# fc        -0.534889
# q         0.0450909
# -log p      3.48921
# ss             True
# Name: llmg_0313, dtype: object
# phnC
# ['R_AEPabc']
# fc           1.17743
# q         0.00577778
# -log p      0.953367
# ss              True
# Name: llmg_0336, dtype: object
# plpB
# ['R_METabc', 'R_METDabc']
# fc        0.738449
# q         0.031619
# -log p     3.23736
# ss            True
# Name: llmg_0481, dtype: object
# fc        1.07589
# q               0
# -log p    3.61417
# ss           True
# Name: llmg_0535, dtype: object
# gltS
# ['R_ARGabc']
# fc         0.946347
# q         0.0482857
# -log p     0.742096
# ss             True
# Name: llmg_0658, dtype: object
# fc         0.605545
# q         0.0421622
# -log p      2.51135
# ss             True
# Name: llmg_0673, dtype: object
# fc       -2.01161
# q               0
# -log p    4.37565
# ss           True
# Name: llmg_0697, dtype: object
# fc        -1.6182
# q               0
# -log p    3.08328
# ss           True
# Name: llmg_0698, dtype: object
# fc        -0.763803
# q         0.0456667
# -log p      1.78779
# ss             True
# Name: llmg_0699, dtype: object
# oppB
# ['R_DIPEPabc15', 'R_DIPEPabc5', 'R_DIPEPabc12', 'R_DIPEPabc9', 'R_DIPEPabc14', 'R_DIPEPabc11', 'R_DIPEPabc10', 'R_DIPEPabc3', 'R_DIPEPabc2', 'R_DIPEPabc13', 'R_DIPEPabc6', 'R_DIPEPabc4', 'R_DIPEPabc7', 'R_DIPEPabc8', 'R_DIPEPabc1']
# fc       -3.40321
# q               0
# -log p    7.80682
# ss           True
# Name: llmg_0701, dtype: object
# oppA
# ['R_DIPEPabc15', 'R_DIPEPabc5', 'R_DIPEPabc12', 'R_DIPEPabc9', 'R_DIPEPabc14', 'R_DIPEPabc11', 'R_DIPEPabc10', 'R_DIPEPabc3', 'R_DIPEPabc2', 'R_DIPEPabc13', 'R_DIPEPabc6', 'R_DIPEPabc4', 'R_DIPEPabc7', 'R_DIPEPabc8', 'R_DIPEPabc1']
# fc       -1.23633
# q               0
# -log p    5.62638
# ss           True
# Name: llmg_0702, dtype: object
# fc         0.488017
# q         0.0451429
# -log p      4.71061
# ss             True
# Name: llmg_0733, dtype: object
# fc        -0.478398
# q         0.0462745
# -log p      4.76885
# ss             True
# Name: llmg_0874, dtype: object
# dapA
# ['R_DHDPS']
# fc         0.578434
# q         0.0431304
# -log p      1.68039
# ss             True
# Name: llmg_0891, dtype: object
# pyrP
# ['R_XANt', 'R_URAt', 'R_URAt2']
# fc         -0.79354
# q         0.0466207
# -log p      1.14183
# ss             True
# Name: llmg_0935, dtype: object
# fc        -0.703295
# q         0.0461538
# -log p       2.1501
# ss             True
# Name: llmg_0989, dtype: object
# llmg_0989
# ['R_LIPAabcpp']
# fc       -1.12457
# q               0
# -log p    4.70442
# ss           True
# Name: llmg_1099, dtype: object
# glpK
# ['R_GLYK']
# fc        -0.672934
# q         0.0426341
# -log p      1.17155
# ss             True
# Name: llmg_1330, dtype: object
# fc        -1.6157
# q               0
# -log p    5.60132
# ss           True
# Name: llmg_1350, dtype: object
# fc         -1.552
# q               0
# -log p    5.70849
# ss           True
# Name: llmg_1351, dtype: object
# fc       -2.30306
# q               0
# -log p    7.49843
# ss           True
# Name: llmg_1352, dtype: object
# fc       -1.75561
# q               0
# -log p    2.62642
# ss           True
# Name: llmg_1353, dtype: object
# fc       -1.08589
# q               0
# -log p     4.9113
# ss           True
# Name: llmg_1354, dtype: object
# fc       -1.04541
# q               0
# -log p    6.86156
# ss           True
# Name: llmg_1355, dtype: object
# fc       -1.24436
# q               0
# -log p    3.77342
# ss           True
# Name: llmg_1356, dtype: object
# fc       -0.640428
# q            0.048
# -log p     4.21662
# ss            True
# Name: llmg_1357, dtype: object
# fc       -1.22915
# q               0
# -log p    5.79199
# ss           True
# Name: llmg_1358, dtype: object
# fc        1.34491
# q               0
# -log p      5.156
# ss           True
# Name: llmg_1399, dtype: object
# fc         -0.50931
# q         0.0440889
# -log p      5.55115
# ss             True
# Name: llmg_1595, dtype: object
# fhs
# ['R_FTHFLi']
# fc         -0.58478
# q         0.0438788
# -log p      4.37091
# ss             True
# Name: llmg_1676, dtype: object
# fc        -0.537952
# q         0.0440952
# -log p      4.03787
# ss             True
# Name: llmg_1734, dtype: object
# noxB
# ['R_NADH4']
# fc         0.673784
# q         0.0413714
# -log p      1.57453
# ss             True
# Name: llmg_1786, dtype: object
# acpP
# ['R_ACPS1']
# fc       -0.736794
# q           0.0216
# -log p     3.65723
# ss            True
# Name: llmg_1915, dtype: object
# llmg_1915
# ['R_L_LACD2', 'R_L_LACD3']
# fc       -0.58154
# q         0.04525
# -log p    5.27848
# ss           True
# Name: llmg_1916, dtype: object
# llmg_1916
# ['R_L_LACD2', 'R_L_LACD3']
# fc        -0.536862
# q         0.0443333
# -log p      2.06122
# ss             True
# Name: llmg_1917, dtype: object
# llmg_1917
# ['R_L_LACD2', 'R_L_LACD3']
# fc         0.580204
# q         0.0433333
# -log p      3.61082
# ss             True
# Name: llmg_1979, dtype: object
# gltP
# ['R_GLUabc', 'R_ARGabc']
# fc         0.523236
# q         0.0462308
# -log p      1.85309
# ss             True
# Name: llmg_2004, dtype: object
# fc        -0.847441
# q         0.0389565
# -log p       1.3598
# ss             True
# Name: llmg_2045, dtype: object
# fc        0.543716
# q           0.0415
# -log p     4.53615
# ss            True
# Name: llmg_2308, dtype: object
# fc         0.586694
# q         0.0467097
# -log p      5.22325
# ss             True
# Name: llmg_2309, dtype: object
# arcC2
# ['R_CBMKr']
# fc         0.601298
# q         0.0466667
# -log p      4.43276
# ss             True
# Name: llmg_2310, dtype: object
# arcC1
# ['R_CBMKr']
# fc          0.59264
# q         0.0422128
# -log p      1.39302
# ss             True
# Name: llmg_2323, dtype: object
# fc        -0.515022
# q         0.0461395
# -log p      5.93368
# ss             True
# Name: llmg_2431, dtype: object
# llmg_2431
# ['R_PGL']
# fc         1.4034
# q               0
# -log p    4.35522
# ss           True
# Name: llmg_0138, dtype: object
# argG
# ['R_ARGSS']
# fc         0.548657
# q         0.0410526
# -log p      6.42874
# ss             True
# Name: llmg_2312, dtype: object
# arcB
# ['R_OCBT']
# fc         0.572353
# q         0.0425882
# -log p      5.59948
# ss             True
# Name: llmg_2313, dtype: object
# arcA
# ['R_ARGDI']

# %%
interesting_plus_annot = lfq_stats[lfq_stats["ss"]==True].copy()


interesting_plus_annot['LFQ intensity BvO325_ccpa_MG1363_1'] = pd.to_numeric(LFQ_data['LFQ intensity BvO325_ccpa_MG1363_1'], errors='coerce')
interesting_plus_annot['LFQ intensity BvO326_ccpa_MG1363_2'] = pd.to_numeric(LFQ_data['LFQ intensity BvO326_ccpa_MG1363_2'], errors='coerce')
interesting_plus_annot['LFQ intensity BvO327_ccpa_MG1363_3'] = pd.to_numeric(LFQ_data['LFQ intensity BvO327_ccpa_MG1363_3'], errors='coerce')
interesting_plus_annot['LFQ intensity BvO328_ccpa_MG1363_4'] = pd.to_numeric(LFQ_data['LFQ intensity BvO328_ccpa_MG1363_4'], errors='coerce')
interesting_plus_annot['LFQ intensity BvO329_wt_MG1363_1'] = pd.to_numeric(LFQ_data['LFQ intensity BvO329_wt_MG1363_1'], errors='coerce')
interesting_plus_annot['LFQ intensity BvO330_wt_MG1363_2'] = pd.to_numeric(LFQ_data['LFQ intensity BvO330_wt_MG1363_2'], errors='coerce')
interesting_plus_annot['LFQ intensity BvO331_wt_MG1363_3'] = pd.to_numeric(LFQ_data['LFQ intensity BvO331_wt_MG1363_3'], errors='coerce')
interesting_plus_annot['LFQ intensity BvO332_wt_MG1363_4'] = pd.to_numeric(LFQ_data['LFQ intensity BvO332_wt_MG1363_4'], errors='coerce')


interesting_plus_annot["Gene names  (primary )"] = preprocessed_data["Gene names  (primary )"]
interesting_plus_annot["Gene names"] = preprocessed_data["Gene names"]
interesting_plus_annot['Protein name'] = preprocessed_data['Protein name']
interesting_plus_annot['New name'] = preprocessed_data['Protein name']

for i in interesting_plus_annot.index:
    interesting_plus_annot['New name'][i] = interesting_plus_annot['Protein name'][i] + " " + preprocessed_data["Gene names"][i]

interesting_plus_annot['EC number'] = preprocessed_data['EC number']
interesting_plus_annot['Mass'] = preprocessed_data['Mass']
interesting_plus_annot['Mol  weight  kDa '] = preprocessed_data['Mol  weight  kDa ']
interesting_plus_annot['Sequence length'] = preprocessed_data['Sequence length']
interesting_plus_annot['Average molecular mass'] = preprocessed_data['Average molecular mass']
interesting_plus_annot['Transmembrane'] = preprocessed_data['Transmembrane']
interesting_plus_annot['Gene ontology (biological process)'] = preprocessed_data['Gene ontology (biological process)']
interesting_plus_annot['Gene ontology (molecular function)'] = preprocessed_data['Gene ontology (molecular function)']
interesting_plus_annot['Gene ontology (cellular component)'] = preprocessed_data['Gene ontology (cellular component)']
interesting_plus_annot['COGcatcombined'] = preprocessed_data['COGcatcombined']
interesting_plus_annot['Subcellular location [CC]'] = preprocessed_data['Subcellular location [CC]']
interesting_plus_annot['Topological domain'] = preprocessed_data['Topological domain']

interesting_plus_annot
# Out:
# C:\Anaconda2\envs\cbmviz1994\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                       locus_tag        fc         q    -log p    ss  \
# Majority protein IDs
# A2RH97                llmg_0025 -0.806220  0.005474  3.057232  True
# A2RHL0                llmg_0139  1.387614  0.000000  3.387863  True
# A2RHT8                llmg_0219  0.669125  0.040000  1.311441  True
# A2RHZ5                llmg_0280 -0.470252  0.046160  7.683109  True
# A2RI08                llmg_0294  1.151736  0.036909  0.724629  True
# A2RI26                llmg_0313 -0.534889  0.045091  3.489213  True
# A2RI49                llmg_0336  1.177432  0.005778  0.953367  True
# A2RIJ0                llmg_0481  0.738449  0.031619  3.237356  True
# A2RIP4                llmg_0535  1.075886  0.000000  3.614167  True
# A2RJ11                llmg_0658  0.946347  0.048286  0.742096  True
# A2RJ24                llmg_0673  0.605545  0.042162  2.511346  True
# A2RJ49                llmg_0697 -2.011611  0.000000  4.375649  True
# A2RJ50                llmg_0698 -1.618199  0.000000  3.083284  True
# A2RJ51                llmg_0699 -0.763803  0.045667  1.787789  True
# A2RJ53                llmg_0701 -3.403207  0.000000  7.806819  True
# A2RJ54                llmg_0702 -1.236334  0.000000  5.626375  True
# A2RJ86                llmg_0733  0.488017  0.045143  4.710612  True
# A2RJL6                llmg_0874 -0.478398  0.046275  4.768852  True
# A2RJN3                llmg_0891  0.578434  0.043130  1.680385  True
# A2RJS4                llmg_0935 -0.793540  0.046621  1.141826  True
# A2RJX6                llmg_0989 -0.703295  0.046154  2.150098  True
# A2RK83                llmg_1099 -1.124565  0.000000  4.704418  True
# A2RKV5                llmg_1330 -0.672934  0.042634  1.171553  True
# A2RKX4                llmg_1350 -1.615702  0.000000  5.601322  True
# A2RKX5                llmg_1351 -1.551999  0.000000  5.708490  True
# A2RKX6                llmg_1352 -2.303057  0.000000  7.498432  True
# A2RKX7                llmg_1353 -1.755610  0.000000  2.626420  True
# A2RKX8                llmg_1354 -1.085891  0.000000  4.911304  True
# A2RKX9                llmg_1355 -1.045414  0.000000  6.861562  True
# A2RKY0                llmg_1356 -1.244362  0.000000  3.773418  True
# A2RKY1                llmg_1357 -0.640428  0.048000  4.216618  True
# A2RKY2                llmg_1358 -1.229152  0.000000  5.791990  True
# A2RL19                llmg_1399  1.344913  0.000000  5.155998  True
# A2RLK1                llmg_1595 -0.509310  0.044089  5.551146  True
# A2RLS9                llmg_1676 -0.584780  0.043879  4.370905  True
# A2RLY0                llmg_1734 -0.537952  0.044095  4.037868  True
# A2RM31                llmg_1786  0.673784  0.041371  1.574528  True
# A2RMF4                llmg_1915 -0.736794  0.021600  3.657225  True
# A2RMF5                llmg_1916 -0.581540  0.045250  5.278479  True
# A2RMF6                llmg_1917 -0.536862  0.044333  2.061220  True
# A2RML6                llmg_1979  0.580204  0.043333  3.610821  True
# A2RMN8                llmg_2004  0.523236  0.046231  1.853090  True
# A2RMS6                llmg_2045 -0.847441  0.038957  1.359798  True
# A2RNI2                llmg_2308  0.543716  0.041500  4.536148  True
# A2RNI3                llmg_2309  0.586694  0.046710  5.223252  True
# A2RNI4                llmg_2310  0.601298  0.046667  4.432757  True
# A2RNJ6                llmg_2323  0.592640  0.042213  1.393019  True
# O86281                llmg_2431 -0.515022  0.046140  5.933679  True
# Q59491                llmg_0138  1.403396  0.000000  4.355223  True
# Q9K575                llmg_2312  0.548657  0.041053  6.428737  True
# Q9K576                llmg_2313  0.572353  0.042588  5.599484  True
#
#                       LFQ intensity BvO325_ccpa_MG1363_1  \
# Majority protein IDs
# A2RH97                                               NaN
# A2RHL0                                          7.278021
# A2RHT8                                          7.576790
# A2RHZ5                                          7.606317
# A2RI08                                          8.637030
# A2RI26                                          7.377779
# A2RI49                                          8.262309
# A2RIJ0                                          6.810918
# A2RIP4                                          7.679700
# A2RJ11                                          8.222013
# A2RJ24                                          6.836792
# A2RJ49                                          6.293628
# A2RJ50                                               NaN
# A2RJ51                                               NaN
# A2RJ53                                          6.064046
# A2RJ54                                          7.750817
# A2RJ86                                          7.393400
# A2RJL6                                          7.784111
# A2RJN3                                          7.127397
# A2RJS4                                          7.445153
# A2RJX6                                               NaN
# A2RK83                                               NaN
# A2RKV5                                               NaN
# A2RKX4                                               NaN
# A2RKX5                                               NaN
# A2RKX6                                               NaN
# A2RKX7                                          6.531696
# A2RKX8                                               NaN
# A2RKX9                                               NaN
# A2RKY0                                               NaN
# A2RKY1                                               NaN
# A2RKY2                                               NaN
# A2RL19                                          7.637670
# A2RLK1                                          7.965743
# A2RLS9                                          7.042654
# A2RLY0                                          8.350093
# A2RM31                                          7.693815
# A2RMF4                                          7.113074
# A2RMF5                                          7.596190
# A2RMF6                                          6.834592
# A2RML6                                          6.818411
# A2RMN8                                          6.941636
# A2RMS6                                          7.536710
# A2RNI2                                          7.890645
# A2RNI3                                          9.146996
# A2RNI4                                          8.245981
# A2RNJ6                                          7.209863
# O86281                                          8.005567
# Q59491                                          7.931931
# Q9K575                                          9.634125
# Q9K576                                          9.425990
#
#                       LFQ intensity BvO326_ccpa_MG1363_2  \
# Majority protein IDs
# A2RH97                                               NaN
# A2RHL0                                          8.144823
# A2RHT8                                          7.690409
# A2RHZ5                                          7.646070
# A2RI08                                          8.214817
# A2RI26                                          7.543534
# A2RI49                                          8.393768
# A2RIJ0                                          6.982312
# A2RIP4                                          8.162952
# A2RJ11                                          8.380428
# A2RJ24                                          6.885491
# A2RJ49                                               NaN
# A2RJ50                                          7.192735
# A2RJ51                                               NaN
# A2RJ53                                          6.032176
# A2RJ54                                          7.638579
# A2RJ86                                          7.503586
# A2RJL6                                          7.644616
# A2RJN3                                          7.122936
# A2RJS4                                          7.477526
# A2RJX6                                               NaN
# A2RK83                                               NaN
# A2RKV5                                          6.888668
# A2RKX4                                               NaN
# A2RKX5                                               NaN
# A2RKX6                                               NaN
# A2RKX7                                               NaN
# A2RKX8                                               NaN
# A2RKX9                                               NaN
# A2RKY0                                               NaN
# A2RKY1                                               NaN
# A2RKY2                                               NaN
# A2RL19                                          7.722971
# A2RLK1                                          7.934826
# A2RLS9                                          7.226342
# A2RLY0                                          8.227115
# A2RM31                                          7.725291
# A2RMF4                                          7.207661
# A2RMF5                                          7.670728
# A2RMF6                                          7.017200
# A2RML6                                          6.670561
# A2RMN8                                          7.078856
# A2RMS6                                               NaN
# A2RNI2                                          8.060736
# A2RNI3                                          9.227089
# A2RNI4                                          8.365712
# A2RNJ6                                          7.148664
# O86281                                          8.038779
# Q59491                                          7.929460
# Q9K575                                          9.647598
# Q9K576                                          9.545022
#
#                       LFQ intensity BvO327_ccpa_MG1363_3  \
# Majority protein IDs
# A2RH97                                               NaN
# A2RHL0                                          7.921000
# A2RHT8                                          7.506992
# A2RHZ5                                          7.611989
# A2RI08                                               NaN
# A2RI26                                          7.617755
# A2RI49                                          8.394189
# A2RIJ0                                          6.895666
# A2RIP4                                          7.788819
# A2RJ11                                          8.381422
# A2RJ24                                          7.265596
# A2RJ49                                               NaN
# A2RJ50                                               NaN
# A2RJ51                                               NaN
# A2RJ53                                          5.896091
# A2RJ54                                          7.813914
# A2RJ86                                          7.541542
# A2RJL6                                          7.691541
# A2RJN3                                          7.079434
# A2RJS4                                               NaN
# A2RJX6                                               NaN
# A2RK83                                               NaN
# A2RKV5                                               NaN
# A2RKX4                                               NaN
# A2RKX5                                               NaN
# A2RKX6                                               NaN
# A2RKX7                                          7.063821
# A2RKX8                                               NaN
# A2RKX9                                               NaN
# A2RKY0                                               NaN
# A2RKY1                                               NaN
# A2RKY2                                               NaN
# A2RL19                                          7.578547
# A2RLK1                                          7.974857
# A2RLS9                                          7.105067
# A2RLY0                                          8.207500
# A2RM31                                          7.568026
# A2RMF4                                          7.227218
# A2RMF5                                          7.620729
# A2RMF6                                          6.924377
# A2RML6                                          6.989819
# A2RMN8                                          6.927273
# A2RMS6                                          7.499536
# A2RNI2                                          8.066922
# A2RNI3                                          9.295765
# A2RNI4                                          8.379415
# A2RNJ6                                          7.279256
# O86281                                          7.967286
# Q59491                                          7.894825
# Q9K575                                          9.701568
# Q9K576                                          9.480841
#
#                       LFQ intensity BvO328_ccpa_MG1363_4  \
# Majority protein IDs
# A2RH97                                               NaN
# A2RHL0                                          7.898610
# A2RHT8                                          7.473823
# A2RHZ5                                          7.627223
# A2RI08                                          8.753507
# A2RI26                                          7.612847
# A2RI49                                          8.465130
# A2RIJ0                                          6.852565
# A2RIP4                                          8.110657
# A2RJ11                                          8.258206
# A2RJ24                                          6.882985
# A2RJ49                                               NaN
# A2RJ50                                               NaN
# A2RJ51                                               NaN
# A2RJ53                                          6.272468
# A2RJ54                                          7.590195
# A2RJ86                                          7.480783
# A2RJL6                                          7.726996
# A2RJN3                                          7.086538
# A2RJS4                                               NaN
# A2RJX6                                               NaN
# A2RK83                                               NaN
# A2RKV5                                               NaN
# A2RKX4                                               NaN
# A2RKX5                                               NaN
# A2RKX6                                               NaN
# A2RKX7                                          7.496570
# A2RKX8                                               NaN
# A2RKX9                                               NaN
# A2RKY0                                               NaN
# A2RKY1                                               NaN
# A2RKY2                                               NaN
# A2RL19                                          7.536217
# A2RLK1                                          7.866264
# A2RLS9                                          7.129690
# A2RLY0                                          8.094995
# A2RM31                                          7.592998
# A2RMF4                                          7.440563
# A2RMF5                                          7.631779
# A2RMF6                                          7.420748
# A2RML6                                          6.689122
# A2RMN8                                          6.792483
# A2RMS6                                               NaN
# A2RNI2                                          8.095971
# A2RNI3                                          9.232615
# A2RNI4                                          8.358373
# A2RNJ6                                          7.229759
# O86281                                          8.045949
# Q59491                                          8.204690
# Q9K575                                          9.714020
# Q9K576                                          9.485792
#
#                       LFQ intensity BvO329_wt_MG1363_1  ...  \
# Majority protein IDs                                    ...
# A2RH97                                        7.219296  ...
# A2RHL0                                        6.425616  ...
# A2RHT8                                             NaN  ...
# A2RHZ5                                        8.074158  ...
# A2RI08                                             NaN  ...
# A2RI26                                        8.024363  ...
# A2RI49                                             NaN  ...
# A2RIJ0                                             NaN  ...
# A2RIP4                                        6.816666  ...
# A2RJ11                                        8.474697  ...
# A2RJ24                                             NaN  ...
# A2RJ49                                        7.998229  ...
# A2RJ50                                        8.096736  ...
# A2RJ51                                        7.293694  ...
# A2RJ53                                        9.531594  ...
# A2RJ54                                        9.053232  ...
# A2RJ86                                        7.013806  ...
# A2RJL6                                        8.147893  ...
# A2RJN3                                             NaN  ...
# A2RJS4                                        7.736500  ...
# A2RJX6                                        7.110623  ...
# A2RK83                                        7.406046  ...
# A2RKV5                                        7.367002  ...
# A2RKX4                                        7.724063  ...
# A2RKX5                                        7.895555  ...
# A2RKX6                                        8.588641  ...
# A2RKX7                                        8.232819  ...
# A2RKX8                                        7.580925  ...
# A2RKX9                                        7.394994  ...
# A2RKY0                                        7.453670  ...
# A2RKY1                                        6.962009  ...
# A2RKY2                                        7.274850  ...
# A2RL19                                             NaN  ...
# A2RLK1                                        8.462338  ...
# A2RLS9                                        7.752740  ...
# A2RLY0                                        8.715326  ...
# A2RM31                                             NaN  ...
# A2RMF4                                        7.989098  ...
# A2RMF5                                        8.201697  ...
# A2RMF6                                        7.594193  ...
# A2RML6                                        6.192288  ...
# A2RMN8                                        6.552668  ...
# A2RMS6                                        7.728208  ...
# A2RNI2                                        7.490549  ...
# A2RNI3                                        8.573127  ...
# A2RNI4                                        7.824165  ...
# A2RNJ6                                        7.211868  ...
# O86281                                        8.563612  ...
# Q59491                                             NaN  ...
# Q9K575                                        9.112068  ...
# Q9K576                                        8.961298  ...
#
#                       Mol  weight  kDa   Sequence length  \
# Majority protein IDs
# A2RH97                           43.946              388
# A2RHL0                           51.866              459
# A2RHT8                           13.294              117
# A2RHZ5                           46.563              437
# A2RI08                           3.9986               35
# A2RI26                           27.468              246
# A2RI49                           31.036              286
# A2RIJ0                           38.617              344
# A2RIP4                           28.976              273
# A2RJ11                           123.03             1058
# A2RJ24                           24.382              205
# A2RJ49                           37.371              338
# A2RJ50                           35.976              319
# A2RJ51                           35.961              319
# A2RJ53                            65.84              600
# A2RJ54                           71.531              627
# A2RJ86                           52.163              463
# A2RJL6                            32.32              297
# A2RJN3                           45.223              430
# A2RJS4                           31.705              281
# A2RJX6                           61.941              548
# A2RK83                           55.679              505
# A2RKV5                            24.64              222
# A2RKX4                           21.591              191
# A2RKX5                           21.141              191
# A2RKX6                           23.129              207
# A2RKX7                           40.682              365
# A2RKX8                           62.373              534
# A2RKX9                           30.745              273
# A2RKY0                           41.907              368
# A2RKY1                           45.399              398
# A2RKY2                           46.742              408
# A2RL19                           36.927              340
# A2RLK1                           59.515              555
# A2RLS9                           52.463              505
# A2RLY0                           74.093              667
# A2RM31                           8.4012               73
# A2RMF4                           28.422              256
# A2RMF5                           54.221              490
# A2RMF6                            25.08              227
# A2RML6                           25.033              228
# A2RMN8                           17.203              150
# A2RMS6                           39.713              381
# A2RNI2                           42.638              376
# A2RNI3                           34.077              314
# A2RNI4                           33.782              314
# A2RNJ6                           29.183              259
# O86281                           37.264              341
# Q59491                           43.827              397
# Q9K575                           39.468              354
# Q9K576                           45.981              410
#
#                       Average molecular mass  \
# Majority protein IDs
# A2RH97                      43946.2539799999
# A2RHL0                      51866.4412799999
# A2RHT8                           13294.25428
# A2RHZ5                           46564.05948
# A2RI08                            3998.66808
# A2RI26                           27468.81918
# A2RI49                           31036.57038
# A2RIJ0                           38617.95258
# A2RIP4                           28976.11848
# A2RJ11                      123033.806980001
# A2RJ24                           24382.17918
# A2RJ49                           37371.04438
# A2RJ50                           35976.18768
# A2RJ51                           35961.62908
# A2RJ53                      65841.1650799999
# A2RJ54                           71531.74078
# A2RJ86                           52163.78898
# A2RJL6                           32320.16158
# A2RJN3                      45223.3448799999
# A2RJS4                           31705.86608
# A2RJX6                      61941.7580799998
# A2RK83                      55679.7983799999
# A2RKV5                           24639.97808
# A2RKX4                           21591.04588
# A2RKX5                           21141.32848
# A2RKX6                           23129.12298
# A2RKX7                           40682.39178
# A2RKX8                      62374.1753799998
# A2RKX9                           30745.32298
# A2RKY0                      41908.0331799999
# A2RKY1                           45399.21998
# A2RKY2                      46742.2073799999
# A2RL19                           36927.83488
# A2RLK1                      59515.8214799998
# A2RLS9                      52463.4905799999
# A2RLY0                      74093.8964800001
# A2RM31                            8401.26708
# A2RMF4                           28421.87988
# A2RMF5                      54221.7550799999
# A2RMF6                           25080.59368
# A2RML6                           25033.05648
# A2RMN8                           17203.66218
# A2RMS6                           39713.39038
# A2RNI2                      42638.8302799999
# A2RNI3                           34077.15738
# A2RNI4                           33782.51578
# A2RNJ6                           29183.17718
# O86281                           37264.88928
# Q59491                      43827.4208799999
# Q9K575                           39468.06258
# Q9K576                      45981.0974799999
#
#                                                           Transmembrane  \
# Majority protein IDs
# A2RH97                                                                0
# A2RHL0                                                                0
# A2RHT8                TRANSMEM 37 63 Helical. {ECO:0000256|SAM:Phobi...
# A2RHZ5                                                                0
# A2RI08                                                                0
# A2RI26                                                                0
# A2RI49                TRANSMEM 7 27 Helical. {ECO:0000256|SAM:Phobius}.
# A2RIJ0                                                                0
# A2RIP4                                                                0
# A2RJ11                                                                0
# A2RJ24                TRANSMEM 20 38 Helical. {ECO:0000256|SAM:Phobi...
# A2RJ49                                                                0
# A2RJ50                                                                0
# A2RJ51                TRANSMEM 142 163 Helical. {ECO:0000256|RuleBas...
# A2RJ53                                                                0
# A2RJ54                                                                0
# A2RJ86                TRANSMEM 117 140 Helical. {ECO:0000256|SAM:Pho...
# A2RJL6                                                                0
# A2RJN3                TRANSMEM 122 140 Helical. {ECO:0000256|SAM:Pho...
# A2RJS4                                                                0
# A2RJX6                TRANSMEM 151 182 Helical. {ECO:0000256|SAM:Pho...
# A2RK83                                                                0
# A2RKV5                TRANSMEM 101 120 Helical. {ECO:0000255}.;TRANS...
# A2RKX4                                                                0
# A2RKX5                                                                0
# A2RKX6                                                                0
# A2RKX7                                                                0
# A2RKX8                                                                0
# A2RKX9                                                                0
# A2RKY0                                                                0
# A2RKY1                                                                0
# A2RKY2                                                                0
# A2RL19                                                                0
# A2RLK1                                                                0
# A2RLS9                TRANSMEM 20 42 Helical. {ECO:0000256|SAM:Phobi...
# A2RLY0                TRANSMEM 583 608 Helical. {ECO:0000256|SAM:Pho...
# A2RM31                                                                0
# A2RMF4                                                                0
# A2RMF5                                                                0
# A2RMF6                                                                0
# A2RML6                TRANSMEM 16 41 Helical. {ECO:0000256|RuleBase:...
# A2RMN8                                                                0
# A2RMS6                                                                0
# A2RNI2                                                                0
# A2RNI3                                                                0
# A2RNI4                                                                0
# A2RNJ6                                                                0
# O86281                                                                0
# Q59491                                                                0
# Q9K575                                                                0
# Q9K576                                                                0
#
#                                      Gene ontology (biological process)  \
# Majority protein IDs
# A2RH97                          mannitol metabolic process [GO:0019594]
# A2RHL0                arginine biosynthetic process via ornithine [G...
# A2RHT8
# A2RHZ5                cell cycle [GO:0007049];cell division [GO:0051...
# A2RI08
# A2RI26
# A2RI49
# A2RIJ0
# A2RIP4
# A2RJ11                 DNA restriction-modification system [GO:0009307]
# A2RJ24
# A2RJ49                                   peptide transport [GO:0015833]
# A2RJ50                                   peptide transport [GO:0015833]
# A2RJ51                                           transport [GO:0006810]
# A2RJ53                             transmembrane transport [GO:0055085]
# A2RJ54
# A2RJ86
# A2RJL6                diaminopimelate biosynthetic process [GO:00198...
# A2RJN3                             transmembrane transport [GO:0055085]
# A2RJS4
# A2RJX6
# A2RK83                glycerol catabolic process [GO:0019563];glycer...
# A2RKV5
# A2RKX4                                  response to stress [GO:0006950]
# A2RKX5                                  response to stress [GO:0006950]
# A2RKX6                                  response to stress [GO:0006950]
# A2RKX7
# A2RKX8
# A2RKX9
# A2RKY0
# A2RKY1                        nucleoside metabolic process [GO:0009116]
# A2RKY2
# A2RL19
# A2RLK1                folic acid-containing compound biosynthetic pr...
# A2RLS9
# A2RLY0
# A2RM31                     fatty acid biosynthetic process [GO:0006633]
# A2RMF4
# A2RMF5                                   lactate oxidation [GO:0019516]
# A2RMF6
# A2RML6
# A2RMN8
# A2RMS6
# A2RNI2                                biosynthetic process [GO:0009058]
# A2RNI3                          arginine metabolic process [GO:0006525]
# A2RNI4                          arginine metabolic process [GO:0006525]
# A2RNJ6
# O86281
# Q59491                       arginine biosynthetic process [GO:0006526]
# Q9K575                arginine catabolic process to ornithine [GO:00...
# Q9K576                arginine catabolic process to ornithine [GO:00...
#
#                                      Gene ontology (molecular function)  \
# Majority protein IDs
# A2RH97                coenzyme binding [GO:0050662];mannitol-1-phosp...
# A2RHL0                    argininosuccinate lyase activity [GO:0004056]
# A2RHT8
# A2RHZ5                amidase activity [GO:0004040];lysozyme activit...
# A2RI08
# A2RI26                ATP binding [GO:0005524];ATPase-coupled organi...
# A2RI49
# A2RIJ0
# A2RIP4
# A2RJ11                ATP binding [GO:0005524];DNA binding [GO:00036...
# A2RJ24
# A2RJ49                ATP binding [GO:0005524];ATPase activity [GO:0...
# A2RJ50                ATP binding [GO:0005524];ATPase activity [GO:0...
# A2RJ51
# A2RJ53
# A2RJ54                       metalloendopeptidase activity [GO:0004222]
# A2RJ86
# A2RJL6                4-hydroxy-tetrahydrodipicolinate synthase [GO:...
# A2RJN3                                transporter activity [GO:0005215]
# A2RJS4
# A2RJX6                ATP binding [GO:0005524];ATPase activity, coup...
# A2RK83                ATP binding [GO:0005524];glycerol kinase activ...
# A2RKV5                                transporter activity [GO:0005215]
# A2RKX4
# A2RKX5
# A2RKX6
# A2RKX7
# A2RKX8
# A2RKX9
# A2RKY0
# A2RKY1
# A2RKY2                                  catalytic activity [GO:0003824]
# A2RL19
# A2RLK1                ATP binding [GO:0005524];formate-tetrahydrofol...
# A2RLS9
# A2RLY0                         NADH dehydrogenase activity [GO:0003954]
# A2RM31
# A2RMF4
# A2RMF5                         iron-sulfur cluster binding [GO:0051536]
# A2RMF6
# A2RML6                                transporter activity [GO:0005215]
# A2RMN8                        N-acetyltransferase activity [GO:0008080]
# A2RMS6
# A2RNI2                pyridoxal phosphate binding [GO:0030170];trans...
# A2RNI3                           carbamate kinase activity [GO:0008804]
# A2RNI4                           carbamate kinase activity [GO:0008804]
# A2RNJ6
# O86281
# Q59491                argininosuccinate synthase activity [GO:000405...
# Q9K575                amino acid binding [GO:0016597];ornithine carb...
# Q9K576                         arginine deiminase activity [GO:0016990]
#
#                                      Gene ontology (cellular component)  \
# Majority protein IDs
# A2RH97
# A2RHL0                                           cytoplasm [GO:0005737]
# A2RHT8                      integral component of membrane [GO:0016021]
# A2RHZ5                                extracellular region [GO:0005576]
# A2RI08
# A2RI26                                     plasma membrane [GO:0005886]
# A2RI49                      integral component of membrane [GO:0016021]
# A2RIJ0
# A2RIP4
# A2RJ11
# A2RJ24                      integral component of membrane [GO:0016021]
# A2RJ49
# A2RJ50
# A2RJ51                integral component of membrane [GO:0016021];pl...
# A2RJ53                ATP-binding cassette (ABC) transporter complex...
# A2RJ54
# A2RJ86                      integral component of membrane [GO:0016021]
# A2RJL6                                           cytoplasm [GO:0005737]
# A2RJN3                      integral component of membrane [GO:0016021]
# A2RJS4
# A2RJX6                      integral component of membrane [GO:0016021]
# A2RK83
# A2RKV5                integral component of membrane [GO:0016021];pl...
# A2RKX4
# A2RKX5
# A2RKX6
# A2RKX7
# A2RKX8
# A2RKX9
# A2RKY0
# A2RKY1
# A2RKY2
# A2RL19
# A2RLK1
# A2RLS9                integral component of membrane [GO:0016021];pl...
# A2RLY0                      integral component of membrane [GO:0016021]
# A2RM31                                           cytoplasm [GO:0005737]
# A2RMF4
# A2RMF5
# A2RMF6
# A2RML6                integral component of membrane [GO:0016021];pl...
# A2RMN8
# A2RMS6
# A2RNI2
# A2RNI3
# A2RNI4
# A2RNJ6
# O86281
# Q59491                                           cytoplasm [GO:0005737]
# Q9K575                                           cytoplasm [GO:0005737]
# Q9K576                                           cytoplasm [GO:0005737]
#
#                      COGcatcombined  \
# Majority protein IDs
# A2RH97                            G
# A2RHL0                            E
# A2RHT8                            S
# A2RHZ5                            M
# A2RI08                         #N/A
# A2RI26                            P
# A2RI49                            P
# A2RIJ0                            S
# A2RIP4                            E
# A2RJ11                            V
# A2RJ24                         #N/A
# A2RJ49                         E, P
# A2RJ50                            E
# A2RJ51                            P
# A2RJ53                            E
# A2RJ54                            O
# A2RJ86                            K
# A2RJL6                            E
# A2RJN3                            F
# A2RJS4                            I
# A2RJX6                            V
# A2RK83                            C
# A2RKV5                            S
# A2RKX4                            T
# A2RKX5                            T
# A2RKX6                            T
# A2RKX7                            P
# A2RKX8                            S
# A2RKX9                            S
# A2RKY0                            S
# A2RKY1                            S
# A2RKY2                            G
# A2RL19                            S
# A2RLK1                            F
# A2RLS9                            V
# A2RLY0                            C
# A2RM31                            I
# A2RMF4                            C
# A2RMF5                            C
# A2RMF6                            S
# A2RML6                            E
# A2RMN8                            S
# A2RMS6                            S
# A2RNI2                            E
# A2RNI3                            E
# A2RNI4                            E
# A2RNJ6                            S
# O86281                            G
# Q59491                            E
# Q9K575                            E
# Q9K576                            E
#
#                                               Subcellular location [CC]  \
# Majority protein IDs
# A2RH97                                                                0
# A2RHL0                SUBCELLULAR LOCATION: Cytoplasm {ECO:0000255|H...
# A2RHT8                                                                0
# A2RHZ5                    SUBCELLULAR LOCATION: Secreted {ECO:0000250}.
# A2RI08                                                                0
# A2RI26                Peripheral membrane protein {ECO:0000256|HAMAP...
# A2RI49                                                                0
# A2RIJ0                                                                0
# A2RIP4                                                                0
# A2RJ11                                                                0
# A2RJ24                                                                0
# A2RJ49                                                                0
# A2RJ50                                                                0
# A2RJ51                Multi-pass membrane protein {ECO:0000256|RuleB...
# A2RJ53                                                                0
# A2RJ54                                                                0
# A2RJ86                                                                0
# A2RJL6                SUBCELLULAR LOCATION: Cytoplasm {ECO:0000255|H...
# A2RJN3                                                                0
# A2RJS4                                                                0
# A2RJX6                                                                0
# A2RK83                                                                0
# A2RKV5                Multi-pass membrane protein {ECO:0000305|PubMe...
# A2RKX4                                                                0
# A2RKX5                                                                0
# A2RKX6                                                                0
# A2RKX7                                                                0
# A2RKX8                                                                0
# A2RKX9                                                                0
# A2RKY0                                                                0
# A2RKY1                                                                0
# A2RKY2                                                                0
# A2RL19                                                                0
# A2RLK1                                                                0
# A2RLS9                                                                0
# A2RLY0                                                                0
# A2RM31                SUBCELLULAR LOCATION: Cytoplasm {ECO:0000255|H...
# A2RMF4                                                                0
# A2RMF5                                                                0
# A2RMF6                                                                0
# A2RML6                Multi-pass membrane protein {ECO:0000256|RuleB...
# A2RMN8                                                                0
# A2RMS6                                                                0
# A2RNI2                                                                0
# A2RNI3                                                                0
# A2RNI4                                                                0
# A2RNJ6                                                                0
# O86281                                                                0
# Q59491                SUBCELLULAR LOCATION: Cytoplasm {ECO:0000255|H...
# Q9K575                   SUBCELLULAR LOCATION: Cytoplasm {ECO:0000250}.
# Q9K576                SUBCELLULAR LOCATION: Cytoplasm {ECO:0000255|H...
#
#                      Topological domain
# Majority protein IDs
# A2RH97                                0
# A2RHL0                                0
# A2RHT8                                0
# A2RHZ5                                0
# A2RI08                                0
# A2RI26                                0
# A2RI49                                0
# A2RIJ0                                0
# A2RIP4                                0
# A2RJ11                                0
# A2RJ24                                0
# A2RJ49                                0
# A2RJ50                                0
# A2RJ51                                0
# A2RJ53                                0
# A2RJ54                                0
# A2RJ86                                0
# A2RJL6                                0
# A2RJN3                                0
# A2RJS4                                0
# A2RJX6                                0
# A2RK83                                0
# A2RKV5                                0
# A2RKX4                                0
# A2RKX5                                0
# A2RKX6                                0
# A2RKX7                                0
# A2RKX8                                0
# A2RKX9                                0
# A2RKY0                                0
# A2RKY1                                0
# A2RKY2                                0
# A2RL19                                0
# A2RLK1                                0
# A2RLS9                                0
# A2RLY0                                0
# A2RM31                                0
# A2RMF4                                0
# A2RMF5                                0
# A2RMF6                                0
# A2RML6                                0
# A2RMN8                                0
# A2RMS6                                0
# A2RNI2                                0
# A2RNI3                                0
# A2RNI4                                0
# A2RNJ6                                0
# O86281                                0
# Q59491                                0
# Q9K575                                0
# Q9K576                                0
#
# [51 rows x 29 columns]

# %%
LFQ_columns = [i for i in preprocessed_data.columns if "LFQ intensity" in i]
LFQ_columns
# Out:
# ['LFQ intensity BvO325_ccpa_MG1363_1',
#  'LFQ intensity BvO326_ccpa_MG1363_2',
#  'LFQ intensity BvO327_ccpa_MG1363_3',
#  'LFQ intensity BvO328_ccpa_MG1363_4',
#  'LFQ intensity BvO329_wt_MG1363_1',
#  'LFQ intensity BvO330_wt_MG1363_2',
#  'LFQ intensity BvO331_wt_MG1363_3',
#  'LFQ intensity BvO332_wt_MG1363_4']

# %%
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
# Combined figure of significantly changed proteins with LFQ data and fold changes
# Use unimputed LFQ data
fig, ax = plt.subplots(constrained_layout=True,
                  ncols=4, nrows=1,
                       #sharey=True,
                  gridspec_kw = {
                      'width_ratios': [8, 1,3,5]},
                      figsize=(3, 10))
fig.subplots_adjust(wspace=0.01)

# foldchanges
sns.heatmap(pd.DataFrame(np.log2(10**interesting_plus_annot["fc"])), 
                     ax=ax[1],
                     cmap="seismic",
                     vmin=np.log2(10**interesting_plus_annot["fc"]).min(),
                     vmax=-np.log2(10**interesting_plus_annot["fc"]).min(),
                     #linewidths=.01, 
                     xticklabels=["CcpA/WT"], #["CcpA mutant/WT"],
                     yticklabels=[""], #interesting_plus_annot["New name"]#,
                     cbar=None
                    )
ax[1].set(ylabel='')
ax[1].tick_params(rotation=90)

# LFQ data
sns.heatmap(interesting_plus_annot[LFQ_columns], 
                     #linewidths=.01, 
                     ax=ax[0],
                     xticklabels=["CcpA 1", "CcpA 2","CcpA 3","CcpA 4", "WT 1", "WT 2", "WT 3", "WT 4"],
                     yticklabels=interesting_plus_annot["New name"],
                     cbar=None
                    )
ax[0].set(ylabel='')


# Colorbars
divider = make_axes_locatable(ax[2])
cax = divider.append_axes("right", size="50%", pad=.0)
fig.add_axes(cax)
fig.colorbar(ax[0].collections[0], cax=cax, #ax[2],
             fraction=0.8, #pad=0.05, 
             orientation='vertical',
            label='log10 LFQ')#ax[1][0]) 

divider = make_axes_locatable(ax[3])
cax2 = divider.append_axes("right", size="25%", pad=.0)
fig.add_axes(cax2)
fig.colorbar(ax[1].collections[0], cax=cax2, #ax[3],
             #fraction=0.15,
             fraction=0.8,# pad=0.01, 
             orientation='vertical',
            label='log2 fold change CcpA/WT')#ax[1][0]) 
ax[2].axis('off')
ax[3].axis('off')

# Save figure
filename='heatmap_significant_prots_combined'
fig.savefig(os.path.join("Figures", filename+'.pdf'), bbox_inches = 'tight')
fig.savefig(os.path.join("Figures", filename+'.png'), bbox_inches = 'tight')
fig.savefig(os.path.join("Figures", filename+'.svg'), bbox_inches = 'tight')
plt.show()
# Out:
# C:\Anaconda2\envs\cbmviz1994\lib\site-packages\matplotlib\figure.py:2117: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.
#   warnings.warn("This figure was using constrained_layout==True, "
# C:\Anaconda2\envs\cbmviz1994\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
# Combined figure of significantly changed proteins with LFQ data and fold changes
# Use unimputed LFQ data
# Order proteins according to their fold change value.
fig, ax = plt.subplots(constrained_layout=True,
                  ncols=4, nrows=1,
                       #sharey=True,
                  gridspec_kw = {
                      'width_ratios': [8, 1,3,5]},
                      figsize=(3, 10))
fig.subplots_adjust(wspace=0.01)

# foldchanges
sns.heatmap(pd.DataFrame(np.log2(10**interesting_plus_annot.sort_values(by=['fc'])["fc"])), 
                     ax=ax[1],
                     cmap="seismic",
                     vmin=np.log2(10**interesting_plus_annot["fc"]).min(),
                     vmax=-np.log2(10**interesting_plus_annot["fc"]).min(),
                     #linewidths=.01, 
                     xticklabels=["CcpA/WT"], #["CcpA mutant/WT"],
                     yticklabels=[""], #interesting_plus_annot["New name"]#,
                     cbar=None
                    )
ax[1].set(ylabel='')
ax[1].tick_params(rotation=90)

# LFQ data
sns.heatmap(interesting_plus_annot.sort_values(by=['fc'])[LFQ_columns], 
                     #linewidths=.01, 
                     ax=ax[0],
                     xticklabels=["CcpA 1", "CcpA 2","CcpA 3","CcpA 4", "WT 1", "WT 2", "WT 3", "WT 4"],
                     yticklabels=interesting_plus_annot.sort_values(by=['fc'])["New name"],
                     cbar=None
                    )
ax[0].set(ylabel='')


# Colorbars
divider = make_axes_locatable(ax[2])
cax = divider.append_axes("right", size="50%", pad=.0)
fig.add_axes(cax)
fig.colorbar(ax[0].collections[0], cax=cax, #ax[2],
             fraction=0.8, #pad=0.05, 
             orientation='vertical',
            label='log10 LFQ')#ax[1][0]) 

divider = make_axes_locatable(ax[3])
cax2 = divider.append_axes("right", size="25%", pad=.0)
fig.add_axes(cax2)
fig.colorbar(ax[1].collections[0], cax=cax2, #ax[3],
             #fraction=0.15,
             fraction=0.8,# pad=0.01, 
             orientation='vertical',
            label='log2 fold change CcpA/WT')#ax[1][0]) 
ax[2].axis('off')
ax[3].axis('off')

# Save figure
filename='heatmap_significant_prots_combined_ordered_unimputedLFQ'
fig.savefig(os.path.join("Figures", filename+'.pdf'), bbox_inches = 'tight')
fig.savefig(os.path.join("Figures", filename+'.png'), bbox_inches = 'tight')
fig.savefig(os.path.join("Figures", filename+'.svg'), bbox_inches = 'tight')
plt.show()

# %% [markdown]
# <a id='iBAQ'></a>

# %% [markdown]
# ### 4.2 Calculate relative amounts of peptides

# %% [markdown]
# #### iBAQ based
# Protein fraction = iBAQ/sum over all iBAQs
#
# Assumption: all samples have same protein concentration, this is important because of the detection limit of the MS/MS.

# %%
# Create a list of indexes for all iBAQ intensity columns
iBAQ_columns = [column for column in preprocessed_data.columns if 'iBAQ ' in column]
# Create a new dataframe with only the iBAQ intensity columns
data_iBAQ = preprocessed_data.loc[:, iBAQ_columns]
data_iBAQ = data_iBAQ.apply(pd.to_numeric)
data_iBAQ.head()
# Out:
#                       iBAQ BvO325_ccpa_MG1363_1  iBAQ BvO326_ccpa_MG1363_2  \
# Majority protein IDs
# A2RH74                                   503550                   469990.0
# A2RH77                                    73609                    65513.0
# A2RH80                                 10535000                  7618300.0
# A2RH85                                   315730                   212990.0
# A2RH86                                    85130                    89672.0
#
#                       iBAQ BvO327_ccpa_MG1363_3  iBAQ BvO328_ccpa_MG1363_4  \
# Majority protein IDs
# A2RH74                                   453810                   328480.0
# A2RH77                                    68963                    58480.0
# A2RH80                                  8036300                  7450500.0
# A2RH85                                   157770                   179990.0
# A2RH86                                    79897                    62034.0
#
#                       iBAQ BvO329_wt_MG1363_1  iBAQ BvO330_wt_MG1363_2  \
# Majority protein IDs
# A2RH74                                 411060                   449770
# A2RH77                                  42696                    50434
# A2RH80                                6227100                  8327900
# A2RH85                                 219450                   261200
# A2RH86                                  71645                    69212
#
#                       iBAQ BvO331_wt_MG1363_3  iBAQ BvO332_wt_MG1363_4
# Majority protein IDs
# A2RH74                                 567280                 396980.0
# A2RH77                                  82229                  49539.0
# A2RH80                                9681700                5032400.0
# A2RH85                                 187040                  52196.0
# A2RH86                                  73502                  67588.0

# %%
# change index to locus tags
data_iBAQ_llmg = data_iBAQ.copy()
data_iBAQ_llmg["locus_tag"] = preprocessed_data["Gene names  (ordered locus )"]
data_iBAQ_llmg.set_index("locus_tag", inplace=True)
data_iBAQ_llmg.head()
# Out:
#            iBAQ BvO325_ccpa_MG1363_1  iBAQ BvO326_ccpa_MG1363_2  \
# locus_tag
# llmg_0001                     503550                   469990.0
# llmg_0004                      73609                    65513.0
# llmg_0007                   10535000                  7618300.0
# llmg_0012                     315730                   212990.0
# llmg_0013                      85130                    89672.0
#
#            iBAQ BvO327_ccpa_MG1363_3  iBAQ BvO328_ccpa_MG1363_4  \
# locus_tag
# llmg_0001                     453810                   328480.0
# llmg_0004                      68963                    58480.0
# llmg_0007                    8036300                  7450500.0
# llmg_0012                     157770                   179990.0
# llmg_0013                      79897                    62034.0
#
#            iBAQ BvO329_wt_MG1363_1  iBAQ BvO330_wt_MG1363_2  \
# locus_tag
# llmg_0001                   411060                   449770
# llmg_0004                    42696                    50434
# llmg_0007                  6227100                  8327900
# llmg_0012                   219450                   261200
# llmg_0013                    71645                    69212
#
#            iBAQ BvO331_wt_MG1363_3  iBAQ BvO332_wt_MG1363_4
# locus_tag
# llmg_0001                   567280                 396980.0
# llmg_0004                    82229                  49539.0
# llmg_0007                  9681700                5032400.0
# llmg_0012                   187040                  52196.0
# llmg_0013                    73502                  67588.0

# %%
# iBAQ/sum of iBAQs, uniprot ID index
iBAQ_frac = data_iBAQ.divide(data_iBAQ.sum(axis=0), axis=1)
iBAQ_frac.head()
# Out:
#                       iBAQ BvO325_ccpa_MG1363_1  iBAQ BvO326_ccpa_MG1363_2  \
# Majority protein IDs
# A2RH74                                 0.000029                   0.000035
# A2RH77                                 0.000004                   0.000005
# A2RH80                                 0.000600                   0.000574
# A2RH85                                 0.000018                   0.000016
# A2RH86                                 0.000005                   0.000007
#
#                       iBAQ BvO327_ccpa_MG1363_3  iBAQ BvO328_ccpa_MG1363_4  \
# Majority protein IDs
# A2RH74                                 0.000033                   0.000029
# A2RH77                                 0.000005                   0.000005
# A2RH80                                 0.000579                   0.000648
# A2RH85                                 0.000011                   0.000016
# A2RH86                                 0.000006                   0.000005
#
#                       iBAQ BvO329_wt_MG1363_1  iBAQ BvO330_wt_MG1363_2  \
# Majority protein IDs
# A2RH74                               0.000037                 0.000036
# A2RH77                               0.000004                 0.000004
# A2RH80                               0.000567                 0.000676
# A2RH85                               0.000020                 0.000021
# A2RH86                               0.000007                 0.000006
#
#                       iBAQ BvO331_wt_MG1363_3  iBAQ BvO332_wt_MG1363_4
# Majority protein IDs
# A2RH74                               0.000037                 0.000042
# A2RH77                               0.000005                 0.000005
# A2RH80                               0.000629                 0.000530
# A2RH85                               0.000012                 0.000005
# A2RH86                               0.000005                 0.000007

# %%
# iBAQ/sum of iBAQs, llmg index
iBAQ_frac_llmg = data_iBAQ_llmg.divide(data_iBAQ_llmg.sum(axis=0), axis=1)
iBAQ_frac_llmg.head()
# Out:
#            iBAQ BvO325_ccpa_MG1363_1  iBAQ BvO326_ccpa_MG1363_2  \
# locus_tag
# llmg_0001                   0.000029                   0.000035
# llmg_0004                   0.000004                   0.000005
# llmg_0007                   0.000600                   0.000574
# llmg_0012                   0.000018                   0.000016
# llmg_0013                   0.000005                   0.000007
#
#            iBAQ BvO327_ccpa_MG1363_3  iBAQ BvO328_ccpa_MG1363_4  \
# locus_tag
# llmg_0001                   0.000033                   0.000029
# llmg_0004                   0.000005                   0.000005
# llmg_0007                   0.000579                   0.000648
# llmg_0012                   0.000011                   0.000016
# llmg_0013                   0.000006                   0.000005
#
#            iBAQ BvO329_wt_MG1363_1  iBAQ BvO330_wt_MG1363_2  \
# locus_tag
# llmg_0001                 0.000037                 0.000036
# llmg_0004                 0.000004                 0.000004
# llmg_0007                 0.000567                 0.000676
# llmg_0012                 0.000020                 0.000021
# llmg_0013                 0.000007                 0.000006
#
#            iBAQ BvO331_wt_MG1363_3  iBAQ BvO332_wt_MG1363_4
# locus_tag
# llmg_0001                 0.000037                 0.000042
# llmg_0004                 0.000005                 0.000005
# llmg_0007                 0.000629                 0.000530
# llmg_0012                 0.000012                 0.000005
# llmg_0013                 0.000005                 0.000007

# %%
#iBAQ_frac_llmg.to_csv("data/CcpA_chemostat/iBAQ_fractions_ccpawt_llmg.txt")

# %% [markdown]
# ### Define protein groups

# %%
# Find transport proteins in model.
ext_species = cmod.getSpeciesIds("_e")
ext_rid_list = []
transport_prots = []

# create list of transport reactions, not exchange reactions
for sid in ext_species:
    ext_rid_list += [i for i in cmod.getSpecies(sid).isReagentOf() if not "_EX_" in i]

print 'length external rid list', len(ext_rid_list)

# Transport proteins
rid_gene_dict = cmod.getAllGeneProteinAssociations()
for rid in ext_rid_list:
    if rid in rid_gene_dict:
        transport_prots += rid_gene_dict[rid]
transport_prots
# Out:
# length external rid list 303
# ['llmg_0316',
#  'llmg_0316',
#  'llmg_0316',
#  'llmg_0316',
#  'llmg_0315',
#  'llmg_0312',
#  'llmg_0313',
#  'llmg_0314',
#  'llmg_0316',
#  'llmg_0316',
#  'llmg_0316',
#  'llmg_0316',
#  'llmg_0316',
#  'llmg_0316',
#  'llmg_0316',
#  'llmg_0316',
#  'llmg_1178',
#  'llmg_0366',
#  'llmg_0365',
#  'llmg_0364',
#  'llmg_0362',
#  'llmg_0701',
#  'llmg_0700',
#  'llmg_0699',
#  'llmg_1461',
#  'llmg_1458',
#  'llmg_1459',
#  'llmg_2026',
#  'llmg_2024',
#  'llmg_2025',
#  'llmg_0367',
#  'llmg_0367',
#  'llmg_1865',
#  'llmg_1865',
#  'llmg_0127',
#  'llmg_0126',
#  'llmg_1045',
#  'llmg_0127',
#  'llmg_0126',
#  'llmg_0316',
#  'llmg_0366',
#  'llmg_0365',
#  'llmg_0364',
#  'llmg_0362',
#  'llmg_0701',
#  'llmg_0700',
#  'llmg_0699',
#  'llmg_1461',
#  'llmg_1458',
#  'llmg_1459',
#  'llmg_2026',
#  'llmg_2024',
#  'llmg_2025',
#  'llmg_0366',
#  'llmg_0365',
#  'llmg_0364',
#  'llmg_0362',
#  'llmg_0701',
#  'llmg_0700',
#  'llmg_0699',
#  'llmg_1461',
#  'llmg_1458',
#  'llmg_1459',
#  'llmg_2026',
#  'llmg_2024',
#  'llmg_2025',
#  'llmg_0366',
#  'llmg_0365',
#  'llmg_0364',
#  'llmg_0362',
#  'llmg_0701',
#  'llmg_0700',
#  'llmg_0699',
#  'llmg_1461',
#  'llmg_1458',
#  'llmg_1459',
#  'llmg_2026',
#  'llmg_2024',
#  'llmg_2025',
#  'llmg_0366',
#  'llmg_0365',
#  'llmg_0364',
#  'llmg_0362',
#  'llmg_0701',
#  'llmg_0700',
#  'llmg_0699',
#  'llmg_1461',
#  'llmg_1458',
#  'llmg_1459',
#  'llmg_2026',
#  'llmg_2024',
#  'llmg_2025',
#  'llmg_0366',
#  'llmg_0365',
#  'llmg_0364',
#  'llmg_0362',
#  'llmg_0701',
#  'llmg_0700',
#  'llmg_0699',
#  'llmg_1461',
#  'llmg_1458',
#  'llmg_1459',
#  'llmg_2026',
#  'llmg_2024',
#  'llmg_2025',
#  'llmg_0366',
#  'llmg_0365',
#  'llmg_0364',
#  'llmg_0362',
#  'llmg_0701',
#  'llmg_0700',
#  'llmg_0699',
#  'llmg_1461',
#  'llmg_1458',
#  'llmg_1459',
#  'llmg_2026',
#  'llmg_2024',
#  'llmg_2025',
#  'llmg_2560',
#  'llmg_2560',
#  'llmg_0375',
#  'llmg_0376',
#  'llmg_2560',
#  'llmg_2560',
#  'llmg_2560',
#  'llmg_0375',
#  'llmg_0376',
#  'llmg_1979',
#  'llmg_1978',
#  'llmg_0535',
#  'llmg_2307',
#  'llmg_2311',
#  'llmg_1250',
#  'llmg_1248',
#  'llmg_1250',
#  'llmg_1248',
#  'llmg_0287',
#  'llmg_0288',
#  'llmg_0289',
#  'llmg_1964',
#  'llmg_0332',
#  'llmg_1964',
#  'llmg_1086',
#  'llmg_0643',
#  'llmg_0690',
#  'llmg_0690',
#  'llmg_0887',
#  'llmg_1056',
#  'llmg_0322',
#  'llmg_0437',
#  'llmg_0187',
#  'llmg_0126',
#  'llmg_0127',
#  'llmg_0438',
#  'llmg_1244',
#  'llmg_0440',
#  'llmg_0366',
#  'llmg_0365',
#  'llmg_0364',
#  'llmg_0362',
#  'llmg_0701',
#  'llmg_0700',
#  'llmg_0699',
#  'llmg_1461',
#  'llmg_1458',
#  'llmg_1459',
#  'llmg_2026',
#  'llmg_2024',
#  'llmg_2025',
#  'llmg_1700',
#  'llmg_1699',
#  'llmg_1474',
#  'llmg_0758',
#  'llmg_1694',
#  'llmg_1729',
#  'llmg_0316',
#  'llmg_0125',
#  'llmg_1227',
#  'llmg_0868',
#  'llmg_1294',
#  'llmg_1290',
#  'llmg_1292',
#  'llmg_0076',
#  'llmg_2272',
#  'llmg_0955',
#  'llmg_2432',
#  'llmg_0199',
#  'llmg_0349',
#  'llmg_0348',
#  'llmg_0347',
#  'llmg_0346',
#  'llmg_1551',
#  'llmg_0666',
#  'llmg_0127',
#  'llmg_1568',
#  'llmg_0126',
#  'llmg_0727',
#  'llmg_0729',
#  'llmg_0728',
#  'llmg_2237',
#  'llmg_0437',
#  'llmg_0126',
#  'llmg_0127',
#  'llmg_0963',
#  'llmg_0438',
#  'llmg_0727',
#  'llmg_0729',
#  'llmg_0728',
#  'llmg_0127',
#  'llmg_0126',
#  'llmg_0727',
#  'llmg_0126',
#  'llmg_0729',
#  'llmg_0728',
#  'llmg_0437',
#  'llmg_0127',
#  'llmg_0440',
#  'llmg_0438',
#  'llmg_2561',
#  'llmg_2467',
#  'llmg_1942',
#  'llmg_1943',
#  'llmg_1593',
#  'llmg_1591',
#  'llmg_1178',
#  'llmg_1979',
#  'llmg_1978',
#  'llmg_1593',
#  'llmg_1591',
#  'llmg_0366',
#  'llmg_0365',
#  'llmg_0364',
#  'llmg_0362',
#  'llmg_0701',
#  'llmg_0700',
#  'llmg_0699',
#  'llmg_1461',
#  'llmg_1458',
#  'llmg_1459',
#  'llmg_2026',
#  'llmg_2024',
#  'llmg_2025',
#  'llmg_0366',
#  'llmg_0365',
#  'llmg_0364',
#  'llmg_0362',
#  'llmg_0701',
#  'llmg_0700',
#  'llmg_0699',
#  'llmg_1461',
#  'llmg_1458',
#  'llmg_1459',
#  'llmg_2026',
#  'llmg_2024',
#  'llmg_2025',
#  'llmg_0375',
#  'llmg_0376',
#  'llmg_0366',
#  'llmg_0365',
#  'llmg_0364',
#  'llmg_0362',
#  'llmg_0701',
#  'llmg_0700',
#  'llmg_0699',
#  'llmg_1461',
#  'llmg_1458',
#  'llmg_1459',
#  'llmg_2026',
#  'llmg_2024',
#  'llmg_2025',
#  'llmg_0366',
#  'llmg_0365',
#  'llmg_0364',
#  'llmg_0362',
#  'llmg_0701',
#  'llmg_0700',
#  'llmg_0699',
#  'llmg_1461',
#  'llmg_1458',
#  'llmg_1459',
#  'llmg_2026',
#  'llmg_2024',
#  'llmg_2025',
#  'llmg_0366',
#  'llmg_0365',
#  'llmg_0364',
#  'llmg_0362',
#  'llmg_0701',
#  'llmg_0700',
#  'llmg_0699',
#  'llmg_1461',
#  'llmg_1458',
#  'llmg_1459',
#  'llmg_2026',
#  'llmg_2024',
#  'llmg_2025',
#  'llmg_0366',
#  'llmg_0365',
#  'llmg_0364',
#  'llmg_0362',
#  'llmg_0701',
#  'llmg_0700',
#  'llmg_0699',
#  'llmg_1461',
#  'llmg_1458',
#  'llmg_1459',
#  'llmg_2026',
#  'llmg_2024',
#  'llmg_2025',
#  'llmg_1700',
#  'llmg_1699',
#  'llmg_1049',
#  'llmg_1048',
#  'llmg_1457',
#  'llmg_1458',
#  'llmg_1459',
#  'llmg_0523',
#  'llmg_1097',
#  'llmg_2327',
#  'llmg_0870',
#  'llmg_0316',
#  'llmg_1913',
#  'llmg_0316',
#  'llmg_0316',
#  'llmg_2560',
#  'llmg_0316',
#  'llmg_0316',
#  'llmg_2560',
#  'llmg_2560',
#  'llmg_0316',
#  'llmg_0316',
#  'llmg_2560',
#  'llmg_0316',
#  'llmg_0316',
#  'llmg_2560',
#  'llmg_0399',
#  'llmg_0316',
#  'llmg_2477',
#  'llmg_0386',
#  'llmg_1637',
#  'llmg_1016',
#  'llmg_0588',
#  'llmg_1551',
#  'llmg_0399',
#  'llmg_2171',
#  'llmg_1490',
#  'llmg_0063',
#  'llmg_2237',
#  'llmg_0375',
#  'llmg_0376',
#  'llmg_0133',
#  'llmg_1865',
#  'llmg_1248',
#  'llmg_2561',
#  'llmg_1195',
#  'llmg_0375',
#  'llmg_0376',
#  'llmg_0887',
#  'llmg_1056',
#  'llmg_0322',
#  'llmg_0650',
#  'llmg_1948',
#  'llmg_1949',
#  'llmg_1945',
#  'llmg_1946',
#  'llmg_1947',
#  'llmg_1952',
#  'llmg_1951',
#  'llmg_1950',
#  'llmg_0316',
#  'llmg_0891',
#  'llmg_0547',
#  'llmg_1318',
#  'llmg_0316',
#  'llmg_0375',
#  'llmg_0376',
#  'llmg_1345',
#  'llmg_1913',
#  'llmg_0650',
#  'llmg_0881',
#  'llmg_1964',
#  'llmg_1474',
#  'llmg_0758',
#  'llmg_2467',
#  'llmg_0650',
#  'llmg_0881',
#  'llmg_0881',
#  'llmg_1864',
#  'llmg_1863',
#  'llmg_1862',
#  'llmg_1861',
#  'llmg_0316',
#  'llmg_1913',
#  'llmg_1865',
#  'llmg_1248',
#  'llmg_0887',
#  'llmg_1056',
#  'llmg_0322',
#  'llmg_0375',
#  'llmg_0376',
#  'llmg_1913',
#  'llmg_0650',
#  'llmg_0881',
#  'llmg_0588',
#  'llmg_0887',
#  'llmg_1056',
#  'llmg_0322',
#  'llmg_0887',
#  'llmg_1056',
#  'llmg_0322',
#  'llmg_0650',
#  'llmg_0881',
#  'llmg_0329',
#  'llmg_0269',
#  'llmg_1203',
#  'llmg_0989',
#  'llmg_2477',
#  'llmg_0386',
#  'llmg_1637',
#  'llmg_0738',
#  'llmg_0739',
#  'llmg_0737',
#  'llmg_0727',
#  'llmg_0126',
#  'llmg_0127',
#  'llmg_0729',
#  'llmg_0728',
#  'llmg_0366',
#  'llmg_0365',
#  'llmg_0364',
#  'llmg_0362',
#  'llmg_0701',
#  'llmg_0700',
#  'llmg_0699',
#  'llmg_1461',
#  'llmg_1458',
#  'llmg_1459',
#  'llmg_2026',
#  'llmg_2024',
#  'llmg_2025',
#  'llmg_0341',
#  'llmg_0342',
#  'llmg_0338',
#  'llmg_0335',
#  'llmg_0336',
#  'llmg_0340',
#  'llmg_0341',
#  'llmg_0342',
#  'llmg_0338',
#  'llmg_0336',
#  'llmg_0335',
#  'llmg_0340',
#  'llmg_1016',
#  'llmg_1267',
#  'llmg_1533',
#  'llmg_0628',
#  'llmg_0661',
#  'llmg_1223',
#  'llmg_2171',
#  'llmg_1490',
#  'llmg_1137',
#  'llmg_1136',
#  'llmg_1138',
#  'llmg_0024',
#  'llmg_0127',
#  'llmg_0022',
#  'llmg_0126',
#  'llmg_2560',
#  'llmg_2560',
#  'llmg_2560',
#  'llmg_2560',
#  'llmg_2560',
#  'llmg_2560',
#  'llmg_2560',
#  'llmg_2560',
#  'llmg_2560',
#  'llmg_2560',
#  'llmg_0399',
#  'llmg_0399',
#  'llmg_0910',
#  'llmg_1223',
#  'llmg_1719',
#  'llmg_2307',
#  'llmg_2311',
#  'llmg_0666',
#  'llmg_0316',
#  'llmg_0316',
#  'llmg_0316',
#  'llmg_1896',
#  'llmg_1897',
#  'llmg_1900',
#  'llmg_1901',
#  'llmg_1898',
#  'llmg_1899',
#  'llmg_0523',
#  'llmg_0316',
#  'llmg_0287',
#  'llmg_0288',
#  'llmg_0542',
#  'llmg_0289',
#  'llmg_1896',
#  'llmg_1897',
#  'llmg_1900',
#  'llmg_1901',
#  'llmg_1898',
#  'llmg_1899',
#  'llmg_1049',
#  'llmg_1048',
#  'llmg_1325',
#  'llmg_1326',
#  'llmg_1327',
#  'llmg_1328',
#  'llmg_0789',
#  'llmg_0788',
#  'llmg_0787',
#  'llmg_1195',
#  'llmg_0287',
#  'llmg_0288',
#  'llmg_0289',
#  'llmg_1195',
#  'llmg_0127',
#  'llmg_0126',
#  'llmg_0375',
#  'llmg_0376',
#  'llmg_0063',
#  'llmg_1325',
#  'llmg_1326',
#  'llmg_1327',
#  'llmg_1328',
#  'llmg_0133',
#  'llmg_0127',
#  'llmg_0126',
#  'llmg_1426',
#  'llmg_0334',
#  'llmg_0287',
#  'llmg_0288',
#  'llmg_0289',
#  'llmg_0454',
#  'llmg_0127',
#  'llmg_0453',
#  'llmg_0126',
#  'llmg_0891',
#  'llmg_0891',
#  'llmg_0316',
#  'llmg_0881',
#  'llmg_0650',
#  'llmg_0891',
#  'llmg_1345',
#  'llmg_2400',
#  'llmg_2398',
#  'llmg_2399',
#  'llmg_0887',
#  'llmg_1056',
#  'llmg_0322']

# %%
# define transmembrane list, as defined by Berdien in annotation file
transmembrane_list = [i.split(';')[0] for i in preprocessed_data[preprocessed_data["Transmembrane"].str.contains('TRANSMEM', na=False, regex=True)]["Gene names  (ordered locus )"]]
transmembrane_list = [i for i in preprocessed_data[preprocessed_data["Transmembrane"].str.contains('TRANSMEM', na=False, regex=True)]["Gene names  (ordered locus )"]]
transmembrane_list
# Out:
# ['llmg_0021',
#  'llmg_0022',
#  'llmg_0112',
#  'llmg_0114',
#  'llmg_0118',
#  'llmg_0119',
#  'llmg_0143',
#  'llmg_0168',
#  'llmg_0170',
#  'llmg_0205',
#  'llmg_0219',
#  'llmg_0226',
#  'llmg_0324',
#  'llmg_0325',
#  'llmg_0335',
#  'llmg_0336',
#  'llmg_0358',
#  'llmg_0375',
#  'llmg_0385',
#  'llmg_0386',
#  'llmg_0402',
#  'llmg_0448',
#  'llmg_0476',
#  'llmg_0540',
#  'llmg_0547',
#  'llmg_0584',
#  'llmg_0587;llmg_0588',
#  'llmg_0589',
#  'llmg_0593',
#  'llmg_0609',
#  'llmg_0625',
#  'llmg_0628',
#  'llmg_0633',
#  'llmg_0639',
#  'llmg_0643',
#  'llmg_0661',
#  'llmg_0673',
#  'llmg_0699',
#  'llmg_0727',
#  'llmg_0733',
#  'llmg_0737',
#  'llmg_0738',
#  'llmg_0752',
#  'llmg_0766',
#  'llmg_0772',
#  'llmg_0870',
#  'llmg_0891',
#  'llmg_0930',
#  'llmg_0989',
#  'llmg_1049',
#  'llmg_1067',
#  'llmg_1086',
#  'llmg_1115',
#  'llmg_1122',
#  'llmg_1186',
#  'llmg_1202',
#  'llmg_1203',
#  'llmg_1258',
#  'llmg_1311',
#  'llmg_1330',
#  'llmg_1426',
#  'llmg_1432',
#  'llmg_1448',
#  'llmg_1545',
#  'llmg_1568',
#  'llmg_1676',
#  'llmg_1679',
#  'llmg_1694;pNZ712_23',
#  'llmg_1734',
#  'llmg_1751',
#  'llmg_1809',
#  'llmg_1816',
#  'llmg_1853',
#  'llmg_1861',
#  'llmg_1862',
#  'llmg_1898',
#  'llmg_1913',
#  'llmg_1928',
#  'llmg_1942',
#  'llmg_1956',
#  'llmg_1979',
#  'llmg_1988',
#  'llmg_1999',
#  'llmg_2011',
#  'llmg_2020',
#  'llmg_2079',
#  'llmg_2156',
#  'llmg_2163',
#  'llmg_2212',
#  'llmg_2225',
#  'llmg_2272',
#  'llmg_2300',
#  'llmg_2327',
#  'llmg_2341',
#  'llmg_2361',
#  'llmg_2391',
#  'llmg_2392',
#  'llmg_2413',
#  'llmg_2416',
#  'llmg_2419',
#  'llmg_2428',
#  'llmg_2442',
#  'llmg_2490',
#  'llmg_2547',
#  'llmg_1950',
#  'llmg_1649']

# %%
Epartgenes = pd.read_csv('data/CcpA_chemostat/E_model_protein_gene_list.txt', header=None)
Epartgenes = list(Epartgenes[0])
Epartgenes
# Out:
# ['llmg_0013',
#  'llmg_0079',
#  'llmg_0098',
#  'llmg_0099',
#  'llmg_0111',
#  'llmg_0145',
#  'llmg_0174',
#  'llmg_0175',
#  'llmg_0176',
#  'llmg_0194',
#  'llmg_0204',
#  'llmg_0251',
#  'llmg_0263',
#  'llmg_0296',
#  'llmg_0302',
#  'llmg_0309',
#  'llmg_0368',
#  'llmg_0369',
#  'llmg_0371',
#  'llmg_0389',
#  'llmg_0395',
#  'llmg_0401',
#  'llmg_0419',
#  'llmg_0462',
#  'llmg_0519',
#  'llmg_0521',
#  'llmg_0528',
#  'llmg_0532',
#  'llmg_0557',
#  'llmg_0577',
#  'llmg_0591',
#  'llmg_0608',
#  'llmg_0610',
#  'llmg_0615',
#  'llmg_0617',
#  'llmg_0632',
#  'llmg_0638',
#  'llmg_0722',
#  'llmg_0771',
#  'llmg_0876',
#  'llmg_0906',
#  'llmg_0932',
#  'llmg_0936',
#  'llmg_0937',
#  'llmg_0986',
#  'llmg_1059',
#  'llmg_1100',
#  'llmg_1109',
#  'llmg_1118',
#  'llmg_1124',
#  'llmg_1194',
#  'llmg_1207',
#  'llmg_1208',
#  'llmg_1271',
#  'llmg_1315',
#  'llmg_1343',
#  'llmg_1431',
#  'llmg_1477',
#  'llmg_1478',
#  'llmg_1491',
#  'llmg_1493',
#  'llmg_1500',
#  'llmg_1524',
#  'llmg_1547',
#  'llmg_1629',
#  'llmg_1671',
#  'llmg_1681',
#  'llmg_1724',
#  'llmg_1725',
#  'llmg_1741',
#  'llmg_1753',
#  'llmg_1764',
#  'llmg_1791',
#  'llmg_1792',
#  'llmg_1796',
#  'llmg_1811',
#  'llmg_1815',
#  'llmg_1825',
#  'llmg_1843',
#  'llmg_1878',
#  'llmg_1882',
#  'llmg_1906',
#  'llmg_1921',
#  'llmg_1981',
#  'llmg_1982',
#  'llmg_2017',
#  'llmg_2029',
#  'llmg_2030',
#  'llmg_2031',
#  'llmg_2035',
#  'llmg_2040',
#  'llmg_2044',
#  'llmg_2050',
#  'llmg_2053',
#  'llmg_2063',
#  'llmg_2078',
#  'llmg_2081',
#  'llmg_2147',
#  'llmg_2154',
#  'llmg_2156',
#  'llmg_2169',
#  'llmg_2195',
#  'llmg_2196',
#  'llmg_2209',
#  'llmg_2215',
#  'llmg_2217',
#  'llmg_2276',
#  'llmg_2277',
#  'llmg_2284',
#  'llmg_2314',
#  'llmg_2332',
#  'llmg_2353',
#  'llmg_2354',
#  'llmg_2355',
#  'llmg_2356',
#  'llmg_2357',
#  'llmg_2358',
#  'llmg_2362',
#  'llmg_2363',
#  'llmg_2364',
#  'llmg_2365',
#  'llmg_2366',
#  'llmg_2367',
#  'llmg_2370',
#  'llmg_2371',
#  'llmg_2372',
#  'llmg_2373',
#  'llmg_2374',
#  'llmg_2375',
#  'llmg_2376',
#  'llmg_2377',
#  'llmg_2378',
#  'llmg_2379',
#  'llmg_2380',
#  'llmg_2381',
#  'llmg_2382',
#  'llmg_2383',
#  'llmg_2384',
#  'llmg_2388',
#  'llmg_2390',
#  'llmg_2396',
#  'llmg_2412',
#  'llmg_2418',
#  'llmg_2424',
#  'llmg_2429',
#  'llmg_2430',
#  'llmg_2444',
#  'llmg_2455',
#  'llmg_2464',
#  'llmg_2473',
#  'llmg_2475',
#  'llmg_2518',
#  'llmg_2545',
#  'llmg_2546',
#  'llmg_2556',
#  'llmg_2557',
#  'llmg_2558']

# %%
# Unused membrane proteins
down_unused = [i for i in interesting[interesting['fc']<0].index]

metabolic_prot_model = [i for i in cmod.getGeneIds() if i in lfq_stats_llmg.index] #llmg_to_uniprotID.keys()]
prot_in_model = [i for i in cmod.getGeneIds() if i in lfq_stats_llmg.index] + [i for i in Epartgenes if i in lfq_stats_llmg.index] # llmg_to_uniprotID.keys()]  llmg_to_uniprotID.keys()] 
print 'NOTE:', len(set(prot_in_model)), 'of the', len(set(cmod.getGeneIds()+ Epartgenes)), 'model proteins are measured.'

transport_prots_wd =  [i for i in set(transport_prots) if i in llmg_to_uniprotID.keys()]
transmembrane = [i for i in transmembrane_list if i in llmg_to_uniprotID.keys()]
print 'NOTE:', len(transport_prots_wd), 'of the', len(set(transport_prots)), 'transport proteins in the model are measured.'
# Out:
# NOTE: 466 of the 728 model proteins are measured.
# NOTE: 69 of the 168 transport proteins in the model are measured.

# %%
glc_transport = cmod.getAllGeneProteinAssociations()["R_GLCpts"] + cmod.getAllGeneProteinAssociations()["R_GLCt2"]
glc_transport
# Out:
# ['llmg_0727',
#  'llmg_0126',
#  'llmg_0729',
#  'llmg_0728',
#  'llmg_0437',
#  'llmg_0127',
#  'llmg_0440',
#  'llmg_0438',
#  'llmg_2561']

# %%
glycolysis_rid = ['R_TPI',
 'R_ENO',
 'R_PFK',
 'R_PGM',
 'R_HEX1',
 'R_GAPD',
 'R_PGK',
 'R_FBA',
 'R_PGI',
 'R_PYK']
glycolysis = []
for rid in glycolysis_rid:
    if rid in cmod.getAllGeneProteinAssociations().keys():
        glycolysis += cmod.getAllGeneProteinAssociations()[rid]
glycolysis
# Out:
# ['llmg_1424',
#  'llmg_0617',
#  'llmg_1118',
#  'llmg_1579',
#  'llmg_1923',
#  'llmg_0355',
#  'llmg_2299',
#  'llmg_2539',
#  'llmg_0530',
#  'llmg_0253',
#  'llmg_2167',
#  'llmg_2448',
#  'llmg_1119']

# %%
#mixed acid fermentation
MAF_rid = ['R_PFL',
 'R_ALCD2x',
 'R_ACALD',
 'R_PTAr',
 'R_ACKr',
 'R_ACt2r',
 'R_ETOHt',
 'R_FORt2',
 'R_EX_for_e',
 'R_EX_etoh_e',
 'R_EX_ac_e']

MAF = []
for rid in MAF_rid:
    if rid in cmod.getAllGeneProteinAssociations().keys():
        MAF += cmod.getAllGeneProteinAssociations()[rid]
MAF

#lactic acid fermentation
LAF_rid = ['R_LDH_L',
 'R_L_LACt2r',
 'R_EX_lac__L_e']

LAF = []
for rid in LAF_rid:
    if rid in cmod.getAllGeneProteinAssociations().keys():
        LAF += cmod.getAllGeneProteinAssociations()[rid]
LAF
# Out:
# ['llmg_0392', 'llmg_1429', 'llmg_1120']

# %%
# arginine group members
arg_members_rid = ['R_ACODA',
 'R_AGPR',
 'R_ARGTRS_1',
 'R_OCBT',
 'R_ARGDI',
 'R_ORNTAC',
 'R_ACOTA',
 'R_CBMKr',
 'R_ARGSL',
 'R_ARGORNt7',
 'R_ACGK',
 'R_ARGSS',
 'R_NH4t',
 'R_EX_nh4_e',
 'R_EX_arg__L_e',
 'R_EX_orn_e']

arg_members = []
for rid in arg_members_rid:
    if rid in cmod.getAllGeneProteinAssociations().keys():
        arg_members += cmod.getAllGeneProteinAssociations()[rid]
        
arg_members
# Out:
# ['llmg_0536',
#  'llmg_1758',
#  'llmg_2314',
#  'llmg_1754',
#  'llmg_2312',
#  'llmg_2313',
#  'llmg_1757',
#  'llmg_1756',
#  'llmg_2310',
#  'llmg_2309',
#  'llmg_0139',
#  'llmg_2307',
#  'llmg_2311',
#  'llmg_1755',
#  'llmg_0138',
#  'llmg_0910']

# %%
#list from e-part doc
ribosome = [
    "llmg_0251", 
    "llmg_0296", "llmg_0932", "llmg_1724", "llmg_1921", "llmg_2078", "llmg_2355", "llmg_2356", "llmg_2364", "llmg_2367",
    "llmg_2370", "llmg_2374", "llmg_2377", "llmg_2379", "llmg_2384", "llmg_2430", "llmg_2473", "llmg_2475", "llmg_2545",
    "llmg_2557", "llmg_2558", "llmg_0098", "llmg_0099", "llmg_0145", "llmg_0204", "llmg_0632", "llmg_0906", "llmg_1207",
    "llmg_1208", "llmg_1491", "llmg_1493", "llmg_1671", "llmg_1815", "llmg_2029", "llmg_2030", "llmg_2276", "llmg_2277",
    "llmg_2353", "llmg_2357", "llmg_2362", "llmg_2363", "llmg_2365", "llmg_2366", "llmg_2371", "llmg_2372", "llmg_2373",
    "llmg_2375", "llmg_2376", "llmg_2378", "llmg_2380", "llmg_2381", "llmg_2382", "llmg_2383", "llmg_2390", "llmg_2546"
]

# %%
#list from e-part doc
tRNAs = [
    "llmg_0079", "llmg_0174", "llmg_0175", "llmg_0176", "llmg_0389", "llmg_0401", "llmg_0722", "llmg_1477",
    "llmg_1478", "llmg_1741", "llmg_1764", "llmg_1906", "llmg_2017", "llmg_2040", "llmg_2053", "llmg_2147",
    "llmg_2169", "llmg_2195", "llmg_2196", "llmg_2215", "llmg_2217", "llmg_2314", "llmg_2332", "llmg_2412", "llmg_2455"
]

# %% [markdown]
# ## Protein fraction plots and statistics

# %%
# select wt and ccpa columns
wt_columns = [col for col in iBAQ_columns if 'wt' in col]
wt_columns
ccpa_columns = [col for col in iBAQ_columns if 'ccpa' in col]
ccpa_columns
# Out:
# ['iBAQ BvO325_ccpa_MG1363_1',
#  'iBAQ BvO326_ccpa_MG1363_2',
#  'iBAQ BvO327_ccpa_MG1363_3',
#  'iBAQ BvO328_ccpa_MG1363_4']

# %%
# create dataframe with summed iBAQ values per group
data_iBAQ_llmg

grplist = [glc_transport, glycolysis, LAF, MAF, arg_members, ribosome] #, tRNAs]
indexgrp = ('glc_transport', 'glycolysis', 'LAF', 'MAF', 'arg_members', 'ribosome', 'remaining') #'tRNAs', 'remaining')

grplist = [glc_transport, glycolysis, LAF,ribosome, MAF, arg_members] #, tRNAs]
indexgrp = ('glc_transport', 'glycolysis', 'LAF','ribosome', 'MAF', 'arg_members',  'remaining') #'tRNAs', 'remaining')

colgrp = wt_columns + ccpa_columns

groupdf_iBAQ = pd.DataFrame(index=indexgrp, columns=colgrp)
for grp in range(len(grplist)):
    groupdf_iBAQ.at[indexgrp[grp], wt_columns] = data_iBAQ_llmg.reindex(grplist[grp])[wt_columns].sum(axis=0)
    groupdf_iBAQ.at[indexgrp[grp], ccpa_columns] = data_iBAQ_llmg.reindex(grplist[grp])[ccpa_columns].sum(axis=0)

# %%
groupdf_iBAQ
# Out:
#               iBAQ BvO329_wt_MG1363_1 iBAQ BvO330_wt_MG1363_2  \
# glc_transport              2.8657e+08             3.15277e+08
# glycolysis                8.10464e+08             9.73881e+08
# LAF                        5.8311e+07             5.75463e+07
# ribosome                  4.23584e+09             4.91041e+09
# MAF                        1.3987e+08             1.44799e+08
# arg_members               1.17426e+08             1.16961e+08
# remaining                         NaN                     NaN
#
#               iBAQ BvO331_wt_MG1363_3 iBAQ BvO332_wt_MG1363_4  \
# glc_transport             3.64984e+08             2.38083e+08
# glycolysis                1.29912e+09             7.65417e+08
# LAF                       6.96591e+07               5.007e+07
# ribosome                  5.93703e+09              3.6955e+09
# MAF                       2.26038e+08             1.09835e+08
# arg_members               1.73412e+08             9.03155e+07
# remaining                         NaN                     NaN
#
#               iBAQ BvO325_ccpa_MG1363_1 iBAQ BvO326_ccpa_MG1363_2  \
# glc_transport               6.44926e+08               5.52216e+08
# glycolysis                  1.82085e+09               1.39417e+09
# LAF                         9.19316e+07               5.99709e+07
# ribosome                    6.95638e+09                5.0972e+09
# MAF                         2.03228e+08               1.86028e+08
# arg_members                 5.02091e+08                4.4604e+08
# remaining                           NaN                       NaN
#
#               iBAQ BvO327_ccpa_MG1363_3 iBAQ BvO328_ccpa_MG1363_4
# glc_transport                5.5256e+08                4.2774e+08
# glycolysis                  1.47646e+09               1.09003e+09
# LAF                         6.71817e+07                5.6397e+07
# ribosome                    5.26682e+09               4.56311e+09
# MAF                         1.83452e+08               1.22686e+08
# arg_members                 4.65375e+08               3.49455e+08
# remaining                           NaN                       NaN

# %%
# Calculate 'remaining' fraction
groupdf_iBAQ.at["remaining",wt_columns] = data_iBAQ_llmg[wt_columns].sum(axis=0) - groupdf_iBAQ[wt_columns].sum(axis=0)
groupdf_iBAQ.at["remaining",ccpa_columns] = data_iBAQ_llmg[ccpa_columns].sum(axis=0)  - groupdf_iBAQ[ccpa_columns].sum(axis=0)

# %%
groupdf_iBAQ
# Out:
#               iBAQ BvO329_wt_MG1363_1 iBAQ BvO330_wt_MG1363_2  \
# glc_transport              2.8657e+08             3.15277e+08
# glycolysis                8.10464e+08             9.73881e+08
# LAF                        5.8311e+07             5.75463e+07
# ribosome                  4.23584e+09             4.91041e+09
# MAF                        1.3987e+08             1.44799e+08
# arg_members               1.17426e+08             1.16961e+08
# remaining                 5.32635e+09              5.8066e+09
#
#               iBAQ BvO331_wt_MG1363_3 iBAQ BvO332_wt_MG1363_4  \
# glc_transport             3.64984e+08             2.38083e+08
# glycolysis                1.29912e+09             7.65417e+08
# LAF                       6.96591e+07               5.007e+07
# ribosome                  5.93703e+09              3.6955e+09
# MAF                       2.26038e+08             1.09835e+08
# arg_members               1.73412e+08             9.03155e+07
# remaining                 7.31845e+09              4.5417e+09
#
#               iBAQ BvO325_ccpa_MG1363_1 iBAQ BvO326_ccpa_MG1363_2  \
# glc_transport               6.44926e+08               5.52216e+08
# glycolysis                  1.82085e+09               1.39417e+09
# LAF                         9.19316e+07               5.99709e+07
# ribosome                    6.95638e+09                5.0972e+09
# MAF                         2.03228e+08               1.86028e+08
# arg_members                 5.02091e+08                4.4604e+08
# remaining                   7.33201e+09               5.52985e+09
#
#               iBAQ BvO327_ccpa_MG1363_3 iBAQ BvO328_ccpa_MG1363_4
# glc_transport                5.5256e+08                4.2774e+08
# glycolysis                  1.47646e+09               1.09003e+09
# LAF                         6.71817e+07                5.6397e+07
# ribosome                    5.26682e+09               4.56311e+09
# MAF                         1.83452e+08               1.22686e+08
# arg_members                 4.65375e+08               3.49455e+08
# remaining                   5.86488e+09               4.88064e+09

# %%
# Test with t-test whether fractions differ between WT and CcpA mutant

# group data per strain
groupdf_IBAQ_frac = groupdf_iBAQ.divide(groupdf_iBAQ.sum())
groupdf_IBAQ_frac_grouped = groupdf_IBAQ_frac.transpose().groupby(['wt', 'wt', 'wt', 'wt', 'ccpa', 'ccpa', 'ccpa', 'ccpa',])

# Loop over fractions and caculate p-value with t-test
for fraction in groupdf_IBAQ_frac.index:
    print fraction
    print 'p =', scipy.stats.ttest_ind(groupdf_IBAQ_frac_grouped.get_group("ccpa")[fraction], groupdf_IBAQ_frac_grouped.get_group("wt")[fraction], equal_var=True)[1]
# Out:
# glc_transport
# p = 3.451562488815674e-05
# glycolysis
# p = 0.0005114673064944997
# LAF
# p = 0.792566891547683
# ribosome
# p = 0.9183659712592791
# MAF
# p = 0.7741558336953265
# arg_members
# p = 3.424840063020325e-06
# remaining
# p = 3.6050793779763927e-06

# %%
# Caluclate average iBAQ fractions
groupdf_iBAQ_average_frac = pd.DataFrame(index=groupdf_iBAQ.index, columns=["WT", "CcpA"])
groupdf_iBAQ_average_frac['CcpA'] = groupdf_iBAQ[ccpa_columns].mean(axis=1).divide(sum(groupdf_iBAQ[ccpa_columns].mean(axis=1)))
groupdf_iBAQ_average_frac['WT'] = groupdf_iBAQ[wt_columns].mean(axis=1).divide(sum(groupdf_iBAQ[wt_columns].mean(axis=1)))
groupdf_iBAQ_average_frac
# Out:
#                      WT      CcpA
# glc_transport  0.025009  0.038756
# glycolysis     0.079886  0.102904
# LAF            0.004890  0.004903
# ribosome       0.389764  0.389499
# MAF            0.012880  0.012377
# arg_members    0.010339  0.031379
# remaining      0.477234  0.420182

# %%
# Create figure of iBAQ fractions per group

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(2,5))

from itertools import cycle, islice
color = list(islice(cycle(
    [(228./255,26./255,28./255), (55./255,126./255,184./255), (255./255,255./255,51./255), (77./255,175./255,74./255), (152./255,75./255,163./255),
    (255./255,127./255,0./255),(247./255,129./255,191./255)]
), None, len(groupdf_iBAQ_average_frac)))

groupdf_iBAQ_average_frac.transpose().loc[["WT", "CcpA"]].plot.bar(stacked=True , ax=ax, width=0.6, colors=color) #, figsize=(10,7))
ax.set_ylabel("iBAQ fraction") 
handles, labels = ax.get_legend_handles_labels()
handles, labels = ax.get_legend_handles_labels()
for i in range(len(labels)):
    if '_' in labels[i]:
        labels[i] = labels[i].replace("_", " ")
labels = ['Glucose transporter', 'Glycolysis', 'Lactic acid production', 'Ribosome', 'Mixed acid production',
         'Arginine catabolism', 'Remaining']

#ax.legend(handles, labels) #, fontsize=9)
#ax.legend().set_visible(False)
legend = ax.legend(list(reversed(handles)), list(reversed(labels)), loc='center left', bbox_to_anchor=(1, 0.5), frameon=False)
#ax = percentage_dist.plot.bar(stacked=True)
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    if 0.6 <= height*100 <= 1.2:
        ax.text(x+width/2, 
                y+height+0.005, 
                '{:.1f} %'.format(height*100), 
                horizontalalignment='center', 
                verticalalignment='center', color='w')
    elif 1.2 <= height*100 <2:
        ax.text(x+width/2, 
                y-0.005, 
                '{:.1f} %'.format(height*100), 
                horizontalalignment='center', 
                verticalalignment='center', color='w')
    else:
        ax.text(x+width/2, 
                y+height/2, 
                '{:.1f} %'.format(height*100), 
                horizontalalignment='center', 
                verticalalignment='center', color='w')

figname='iBAQ_fraction_ccpawt_3'
fig.savefig(os.path.join("Figures", figname+'.svg'), dpi=fig.dpi,  bbox_extra_artists=(legend,), bbox_inches='tight')
fig.savefig(os.path.join("Figures", figname+'.pdf'), dpi=fig.dpi,  bbox_extra_artists=(legend,), bbox_inches='tight')
fig.show()
# Out:
# C:\Anaconda2\envs\cbmviz1994\lib\site-packages\pandas\plotting\_core.py:185: UserWarning: 'colors' is being deprecated. Please use 'color'instead of 'colors'
#   warnings.warn(("'colors' is being deprecated. Please use 'color'"
# C:\Anaconda2\envs\cbmviz1994\lib\site-packages\matplotlib\figure.py:457: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# ### Membrane checks

# %% [markdown]
# Protein iBAQ fraction in transport proteins (proteins assigned as transporters in the model).

# %%
print "ccpa:", np.mean(list(data_iBAQ_llmg.reindex(list(set(transport_prots_wd))).sum(axis=0)[ccpa_columns]/data_iBAQ_llmg.sum(axis=0)[ccpa_columns]))
print "wt:", np.mean(list(data_iBAQ_llmg.reindex(list(set(transport_prots_wd))).sum(axis=0)[wt_columns]/data_iBAQ_llmg.sum(axis=0)[wt_columns]))
# Out:
# ccpa: 0.07717270441014257
# wt: 0.08520201530273133

# %% [markdown]
# Protein iBAQ fraction in transmembrane list (proteins assigned as transmembrane protein according to uniprot, retrieved from preprocessed_data dataframe).

# %%
print "ccpa:", np.mean(list(data_iBAQ_llmg.reindex(list(set(transmembrane_list))).sum(axis=0)[ccpa_columns]/data_iBAQ_llmg.sum(axis=0)[ccpa_columns]))
print "wt:", np.mean(list(data_iBAQ_llmg.reindex(list(set(transmembrane_list))).sum(axis=0)[wt_columns]/data_iBAQ_llmg.sum(axis=0)[wt_columns]))
# Out:
# ccpa: 0.032579599157394334
# wt: 0.03417384264482814

# %% [markdown]
# Protein iBAQ fraction in transport proteins and transmembrane list together

# %%
print "ccpa:", np.mean(list(data_iBAQ_llmg.reindex(list(set(transport_prots_wd+transmembrane_list))).sum(axis=0)[ccpa_columns]/data_iBAQ_llmg.sum(axis=0)[ccpa_columns]))
print "wt:", np.mean(list(data_iBAQ_llmg.reindex(list(set(transport_prots_wd+transmembrane_list))).sum(axis=0)[wt_columns]/data_iBAQ_llmg.sum(axis=0)[wt_columns]))
# Out:
# ccpa: 0.09691371808471769
# wt: 0.1071025885977946

# %%
# fisher exact test on membrane proteins vs rest in ccpa and wt
# select significant changed proteins
# Check:
membrsignif = 0
signifrest = 0
for llmg in interesting.index:
    # if in membrane list: sign membr +1    transmembrane_list
    if llmg in transmembrane_list:
        membrsignif +=1
    else:
        signifrest +=1
# else: sign rest +1
# len membrane list - sign membr
restmembr = len(set(transmembrane_list)) - membrsignif
# len all - membrane list - sign rest
rest = len(iBAQ_frac_llmg) - len(transmembrane_list) - signifrest

print membrsignif
print signifrest
print restmembr
print rest

# Fisher exact test
oddsratio, pvalue = stats.fisher_exact([[11,95],[40,760]])
pvalue
# Out:
# 11
# 40
# 95
# 760
# 0.03943741418251649

# %%
# fisher exact test on membrane proteins vs rest in ccpa and wt
# select significant changed proteins
# Check:
membrsignif = 0
signifrest = 0
for llmg in interesting.index:
    # if in membrane list: sign membr +1    transmembrane_list
    if llmg in set(transport_prots_wd + transmembrane_list):
        membrsignif +=1
    else:
        signifrest +=1
# else: sign rest +1
# len membrane list - sign membr
restmembr = len(set(transport_prots_wd + transmembrane_list)) - membrsignif
# len all - membrane list - sign rest
rest = len(iBAQ_frac_llmg) - len(set(transport_prots_wd + transmembrane_list)) - signifrest

print membrsignif
print signifrest
print restmembr
print rest

# Fisher exact test
oddsratio, pvalue = stats.fisher_exact([[14,131],[37,724]])
pvalue
# Out:
# 14
# 37
# 131
# 724
# 0.029511717905305976

# %%
# fisher exact test on membrane proteins vs rest in ccpa and wt
# select significant changed proteins
# Check:
membrsignif = 0
signifrest = 0
for llmg in interesting.index:
    # if in membrane list: sign membr +1    transmembrane_list
    if llmg in set(transport_prots_wd):
        membrsignif +=1
    else:
        signifrest +=1
# else: sign rest +1
# len membrane list - sign membr
restmembr = len(set(transport_prots_wd)) - membrsignif
# len all - membrane list - sign rest
rest = len(iBAQ_frac_llmg) - len(set(transport_prots_wd)) - signifrest

print membrsignif
print signifrest
print restmembr
print rest

# Fisher exact test
oddsratio, pvalue = stats.fisher_exact([[8,61],[43,794]])
pvalue
# Out:
# 8
# 43
# 61
# 794
# 0.049073251914988396

# %% [markdown]
# <a id='volcano_plots'></a>

# %% [markdown]
# ## 5. Volcano plot of proteome data CcpA mutant vs. WT
# Fold-changes, p-values and significance line were generated with Perseus.

# %%
# load the volcano significance line data from perseus
#sigline = pd.read_csv(os.path.join(workbookDir, "data", "CcpA_chemostat", "20190809_perseusprocessed_significant_curve_vulcanoplot.txt"), sep='\t',
#                       na_filter = False, dtype='a')
sigline = pd.read_csv(os.path.join(workbookDir, "data", "CcpA_chemostat", "20191108_perseusprocessed_significant_curve_vulcanoplot.txt"), sep='\t',
                       na_filter = False, dtype='a')
sigline = sigline.drop([0,1], axis=0)
sigline
# Out:
#                       x                  y
# 2                    30    0.1766417324543
# 3      29.9899997711182  0.176642745733261
# 4      29.9799995422363  0.176643759012222
# 5      29.9699993133545  0.176644787192345
# 6      29.9599990844727  0.176645800471306
# 7      29.9500007629395  0.176646813750267
# 8      29.9400005340576  0.176647841930389
# 9      29.9300003051758  0.176648855209351
# 10     29.9200000762939  0.176649883389473
# 11     29.9099998474121  0.176650896668434
# 12     29.8999996185303  0.176651924848557
# 13     29.8899993896484  0.176652953028679
# 14     29.8799991607666   0.17665396630764
# 15     29.8700008392334  0.176654994487762
# 16     29.8600006103516  0.176656022667885
# 17     29.8500003814697  0.176657050848007
# 18     29.8400001525879   0.17665807902813
# 19     29.8299999237061  0.176659107208252
# 20     29.8199996948242  0.176660120487213
# 21     29.8099994659424  0.176661163568497
# 22     29.7999992370605  0.176662191748619
# 23     29.7900009155273  0.176663219928741
# 24     29.7800006866455  0.176664248108864
# 25     29.7700004577637  0.176665276288986
# 26     29.7600002288818  0.176666304469109
# 27                29.75  0.176667347550392
# 28     29.7399997711182  0.176668375730515
# 29     29.7299995422363  0.176669403910637
# 30     29.7199993133545   0.17667044699192
# 31     29.7099990844727  0.176671475172043
# ...                 ...                ...
# 5884  -29.7099990844727  0.176671475172043
# 5885  -29.7199993133545   0.17667044699192
# 5886  -29.7299995422363  0.176669403910637
# 5887  -29.7399997711182  0.176668375730515
# 5888             -29.75  0.176667347550392
# 5889  -29.7600002288818  0.176666304469109
# 5890  -29.7700004577637  0.176665276288986
# 5891  -29.7800006866455  0.176664248108864
# 5892  -29.7900009155273  0.176663219928741
# 5893  -29.7999992370605  0.176662191748619
# 5894  -29.8099994659424  0.176661163568497
# 5895  -29.8199996948242  0.176660120487213
# 5896  -29.8299999237061  0.176659107208252
# 5897  -29.8400001525879   0.17665807902813
# 5898  -29.8500003814697  0.176657050848007
# 5899  -29.8600006103516  0.176656022667885
# 5900  -29.8700008392334  0.176654994487762
# 5901  -29.8799991607666   0.17665396630764
# 5902  -29.8899993896484  0.176652953028679
# 5903  -29.8999996185303  0.176651924848557
# 5904  -29.9099998474121  0.176650896668434
# 5905  -29.9200000762939  0.176649883389473
# 5906  -29.9300003051758  0.176648855209351
# 5907  -29.9400005340576  0.176647841930389
# 5908  -29.9500007629395  0.176646813750267
# 5909  -29.9599990844727  0.176645800471306
# 5910  -29.9699993133545  0.176644787192345
# 5911  -29.9799995422363  0.176643759012222
# 5912  -29.9899997711182  0.176642745733261
# 5913                -30    0.1766417324543
#
# [5912 rows x 2 columns]

# %%
sigline['x'] = sigline['x'].astype(float)
sigline['y'] = sigline['y'].astype(float)

sigline = sigline[sigline['x']<4]
sigline = sigline[sigline['x']>-4]
sigline
# Out:
#          x         y
# 2603  3.99  0.198957
# 2604  3.98  0.199030
# 2605  3.97  0.199103
# 2606  3.96  0.199176
# 2607  3.95  0.199250
# 2608  3.94  0.199324
# 2609  3.93  0.199399
# 2610  3.92  0.199474
# 2611  3.91  0.199550
# 2612  3.90  0.199626
# 2613  3.89  0.199703
# 2614  3.88  0.199780
# 2615  3.87  0.199857
# 2616  3.86  0.199935
# 2617  3.85  0.200013
# 2618  3.84  0.200092
# 2619  3.83  0.200172
# 2620  3.82  0.200251
# 2621  3.81  0.200332
# 2622  3.80  0.200412
# 2623  3.79  0.200494
# 2624  3.78  0.200575
# 2625  3.77  0.200658
# 2626  3.76  0.200740
# 2627  3.75  0.200824
# 2628  3.74  0.200908
# 2629  3.73  0.200992
# 2630  3.72  0.201077
# 2631  3.71  0.201162
# 2632  3.70  0.201248
# ...    ...       ...
# 3283 -3.70  0.201248
# 3284 -3.71  0.201162
# 3285 -3.72  0.201077
# 3286 -3.73  0.200992
# 3287 -3.74  0.200908
# 3288 -3.75  0.200824
# 3289 -3.76  0.200740
# 3290 -3.77  0.200658
# 3291 -3.78  0.200575
# 3292 -3.79  0.200494
# 3293 -3.80  0.200412
# 3294 -3.81  0.200332
# 3295 -3.82  0.200251
# 3296 -3.83  0.200172
# 3297 -3.84  0.200092
# 3298 -3.85  0.200013
# 3299 -3.86  0.199935
# 3300 -3.87  0.199857
# 3301 -3.88  0.199780
# 3302 -3.89  0.199703
# 3303 -3.90  0.199626
# 3304 -3.91  0.199550
# 3305 -3.92  0.199474
# 3306 -3.93  0.199399
# 3307 -3.94  0.199324
# 3308 -3.95  0.199250
# 3309 -3.96  0.199176
# 3310 -3.97  0.199103
# 3311 -3.98  0.199030
# 3312 -3.99  0.198957
#
# [710 rows x 2 columns]

# %%
# Some lists for highlighting in volcano plot
glc = ['llmg_0729','llmg_0727'] #'llmg_0728' is TRANSMEMBRANE (not measured), llmg_0727 also TRANSMEMBRANE
arg = ['llmg_0138','llmg_0139']
arc_genes = [
       'llmg_2307', #arcD2   TRANSMEMBRANE, not measured
       'llmg_2308', #arcT
       'llmg_2309', #arcC2
       'llmg_2310', #arcC1
       'llmg_2311', #arcD1   TRANSMEMBRANE, not measured
       'llmg_2312', #arcB
       'llmg_2313', #arcA
      ]
arc = [i for i in arc_genes if i in data_iBAQ_llmg.index] #2307 and 2311 are transmembrane proteins, but not measured!

# Unused membrane proteins

opp = ['llmg_0701','llmg_0697', 'llmg_0698', 'llmg_0699', 'llmg_0702'] #llmg_0700 is also part of operon, TRANSMEMBRANE, not measured
                                                                       #llmg_0699 TRANSMEMBRANE
tellurium = ['llmg_1350', 'llmg_1351', 'llmg_1352']
nox = ['llmg_1734', 'llmg_1735', 'llmg_1770', 'llmg_0408'] #llmg_1734 is noxB is TRANSMEMBRANE
ptc_cel = ["llmg_0437", "llmg_0438"]

# %%
# Interesting ones highlighted
fig, ax = plt.subplots()

from itertools import cycle, islice
color = list(islice(cycle(
    [(228./255,26./255,28./255), (55./255,126./255,184./255), (255./255,255./255,51./255), (77./255,175./255,74./255), (152./255,75./255,163./255),
    (255./255,127./255,0./255),(247./255,129./255,191./255)]
), None, len(groupdf_iBAQ_average_frac)))

# Show the significance line (s0=1, FDR = 0.05)
ax.plot(np.log2(10**(sigline['x'])), sigline['y'], label = 'Significance line', color='black', linewidth=1.)

# Data points
ax.scatter(np.log2(10**(lfq_stats_llmg['fc'])), lfq_stats_llmg['-log p'], 
           label='Measured proteins', alpha=1., color='lightsteelblue',s=5 ) #, c=color, s=scale, label=color, alpha=0.3, edgecolors='none')
ax.scatter(np.log2(10**(lfq_stats_llmg.loc[glc]['fc'])), lfq_stats_llmg.loc[glc]['-log p'], 
           label='glucose ptn mannose', color=(228./255,26./255,28./255))#'dodgerblue') #, marker='^'
ax.scatter(np.log2(10**(lfq_stats_llmg.loc[ptc_cel]['fc'])), lfq_stats_llmg.loc[ptc_cel]['-log p'], 
           label='glucose ptc cellobiose', color=(228./255,26./255,28./255)) #'royalblue') #, marker='^'
ax.scatter(np.log2(10**(lfq_stats_llmg.loc[arg]['fc'])), lfq_stats_llmg.loc[arg]['-log p'], 
           label='arg arginine', color=(255./255,127./255,0./255)) #'limegreen') #, marker = 'o')
ax.scatter(np.log2(10**(lfq_stats_llmg.loc[arc]['fc'])), lfq_stats_llmg.loc[arc]['-log p'], 
           label='arc arginine', color=(255./255,127./255,0./255)) #'darkcyan') #, marker = 'o')

ax.scatter(np.log2(10**(lfq_stats_llmg.loc[opp]['fc'])), lfq_stats_llmg.loc[opp]['-log p'], 
           label='oligopeptide transport', color=(0./255,0./255,205./255)) #, alpha=0.7) #'orangered', alpha = 0.7)
ax.scatter(np.log2(10**(lfq_stats_llmg.loc[tellurium]['fc'])), lfq_stats_llmg.loc[tellurium]['-log p'], 
           label='tellurium resistance', color=(0./255,100./255,0./255))#'indianred', alpha = 0.7)
ax.scatter(np.log2(10**(lfq_stats_llmg.loc[nox]['fc'])), lfq_stats_llmg.loc[nox]['-log p'], 
           label='nox', color='fuchsia', alpha = 0.7)


plt.rc('axes', labelsize=12, titlesize=10) 
#plt.rc('xtick', labelsize=10)

ax.set(xlabel='Log2 fold change CcpA/WT', ylabel='-Log10 p-value', title='')
ax.set_ylim((-0.1,8.5))
ax.set_xlim((-12,12))

#ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0., fontsize=12)
#ax.grid(False)

handles, labels = ax.get_legend_handles_labels()

ax.legend(handles[0:2], labels[0:2], bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
          mode="expand", 
          borderaxespad=0, ncol=2, fontsize=12, frameon=False)

# Label significant model proteins
for i in glc + ptc_cel+arg+arc+opp+tellurium+nox:
    x = np.log2(10**(lfq_stats_llmg.loc[i]['fc']))
    y = lfq_stats_llmg.loc[i]['-log p']
    #ax.scatter(x, y, marker='o', color='fuchsia', s=5, alpha = 0.5)
    name = preprocessed_data[preprocessed_data["Gene names  (ordered locus )"]==i]["Gene names"][0].split(' ')[0]
    if name in ['telC']:
        ax.text(x-0.15, y-0.2, name, horizontalalignment='right', verticalalignment='center', fontsize=12)
    elif name in ['noxC']:
        ax.text(x-0.15, y-0.2, name, horizontalalignment='right', verticalalignment='center', fontsize=12)
    elif name in ['arcC1']:
        ax.text(x, y-0.2, name, horizontalalignment='left', verticalalignment='center', fontsize=12)
    elif name in ['ptcB']:
        ax.text(x+0.25, y+0.15, name, horizontalalignment='left', verticalalignment='center', fontsize=12)
    elif name in ['arcT']:
        ax.text(x+0.2, y+0.15, name, horizontalalignment='left', verticalalignment='center', fontsize=12)
    elif name in ['telB']:
        ax.text(x-0.1, y+0.15, name, horizontalalignment='right', verticalalignment='center', fontsize=12)
    elif name in ['noxE', 'noxB', 'ptnD', 'oppB', 'ptnAB']:
        ax.text(x-0.25, y, name, horizontalalignment='right', verticalalignment='center', fontsize=12)
    else:
        ax.text(x+0.25, y, name, horizontalalignment='left', verticalalignment='center', fontsize=12)

filename = 'volcano_ccpa_wt_interesting_largefont'
plt.savefig('Figures/'+filename+'.png', bbox_inches = 'tight')
plt.savefig('Figures/'+filename+'.pdf', bbox_inches = 'tight')
plt.savefig('Figures/'+filename+'.eps', bbox_inches = 'tight')
plt.savefig('Figures/'+filename+'.svg', bbox_inches = 'tight')


plt.show()

# %% [markdown]
# <a id='flux'></a>

# %% [markdown]
# # 6. Exchange fluxes

# %% [markdown]
# ### Import amino acid uptake rate data

# %%
aafluxes = pd.read_csv("data\CcpA_chemostat\Fluxdata.txt")
aafluxes

# NOR_Conc is intern standard
# Out:
#    id strain reactornum  ALA_Conc  ARG_Conc  ASN_Conc  ASP_Conc  CYS_Conc  \
# 0   5   ccpa         R1 -0.317641 -0.778894 -0.242649 -0.016349 -0.057732
# 1   6   ccpa         R2 -0.319839 -0.774038 -0.244242 -0.037876 -0.048232
# 2   7   ccpa         R3 -0.302748 -0.772843 -0.245338 -0.064652 -0.005918
# 3   8   ccpa         R4 -0.302654 -0.780943 -0.257293 -0.167763  0.236307
# 4   9     WT         R1 -0.304088 -0.659394 -0.261572 -0.228794  0.504517
# 5  10     WT         R2 -0.300326 -0.641180 -0.259450 -0.249456  0.513266
# 6  11     WT         R3 -0.319498 -0.734271 -0.239984 -0.010070 -0.084484
# 7  12     WT         R4 -0.311324 -0.714792 -0.230217 -0.023023 -0.074691
#
#    GLN_Conc  GLU_Conc  ...  LEU_Conc  LYS_Conc  MET_Conc  NOR_Conc  PHE_Conc  \
# 0 -0.333289  0.012478  ... -0.306030 -0.222953 -0.078707       0.0 -0.066173
# 1 -0.341379 -0.001315  ... -0.301824 -0.234947 -0.079642       0.0 -0.072878
# 2 -0.336667 -0.007076  ... -0.291175 -0.230344 -0.074252       0.0 -0.067355
# 3 -0.357081 -0.047703  ... -0.275602 -0.294124 -0.075959       0.0 -0.069079
# 4 -0.394652 -0.040165  ... -0.244085 -0.307123 -0.071523       0.0 -0.084618
# 5 -0.390749 -0.055282  ... -0.240889 -0.314742 -0.068005       0.0 -0.091531
# 6 -0.153692  0.083990  ... -0.272582 -0.078815 -0.070983       0.0 -0.071822
# 7 -0.151482  0.074983  ... -0.268404 -0.066414 -0.068640       0.0 -0.072632
#
#    SER_Conc  THR_Conc  TRP_Conc  TYR_Conc  VAL_Conc
# 0 -0.839217 -0.281930 -0.064660 -0.037607 -0.234797
# 1 -0.830139 -0.279907 -0.074315 -0.045717 -0.237323
# 2 -0.827301 -0.280857 -0.073935 -0.037492 -0.235792
# 3 -0.824442 -0.300279 -0.070774 -0.036424 -0.256902
# 4 -0.886365 -0.318198 -0.067804 -0.049333 -0.270326
# 5 -0.876785 -0.330830 -0.076736 -0.049259 -0.275261
# 6 -0.952169 -0.181330 -0.086507 -0.047637 -0.211141
# 7 -0.926093 -0.174494 -0.081264 -0.046798 -0.211698
#
# [8 rows x 23 columns]

# %%
# Remove nor column, which is the internal standard
aafluxes.drop(columns=["NOR_Conc"], inplace=True)

# Convert to long format for plotting
aafluxes_long = pd.melt(aafluxes, 
                        id_vars=['id','strain', 'reactornum'], 
                        var_name='amino_acid',
                        value_vars=aafluxes.columns[3:22],
                        value_name='flux')

aafluxes_long #['id','strain', 'reactornum']
# Out:
#      id strain reactornum amino_acid      flux
# 0     5   ccpa         R1   ALA_Conc -0.317641
# 1     6   ccpa         R2   ALA_Conc -0.319839
# 2     7   ccpa         R3   ALA_Conc -0.302748
# 3     8   ccpa         R4   ALA_Conc -0.302654
# 4     9     WT         R1   ALA_Conc -0.304088
# 5    10     WT         R2   ALA_Conc -0.300326
# 6    11     WT         R3   ALA_Conc -0.319498
# 7    12     WT         R4   ALA_Conc -0.311324
# 8     5   ccpa         R1   ARG_Conc -0.778894
# 9     6   ccpa         R2   ARG_Conc -0.774038
# 10    7   ccpa         R3   ARG_Conc -0.772843
# 11    8   ccpa         R4   ARG_Conc -0.780943
# 12    9     WT         R1   ARG_Conc -0.659394
# 13   10     WT         R2   ARG_Conc -0.641180
# 14   11     WT         R3   ARG_Conc -0.734271
# 15   12     WT         R4   ARG_Conc -0.714792
# 16    5   ccpa         R1   ASN_Conc -0.242649
# 17    6   ccpa         R2   ASN_Conc -0.244242
# 18    7   ccpa         R3   ASN_Conc -0.245338
# 19    8   ccpa         R4   ASN_Conc -0.257293
# 20    9     WT         R1   ASN_Conc -0.261572
# 21   10     WT         R2   ASN_Conc -0.259450
# 22   11     WT         R3   ASN_Conc -0.239984
# 23   12     WT         R4   ASN_Conc -0.230217
# 24    5   ccpa         R1   ASP_Conc -0.016349
# 25    6   ccpa         R2   ASP_Conc -0.037876
# 26    7   ccpa         R3   ASP_Conc -0.064652
# 27    8   ccpa         R4   ASP_Conc -0.167763
# 28    9     WT         R1   ASP_Conc -0.228794
# 29   10     WT         R2   ASP_Conc -0.249456
# ..   ..    ...        ...        ...       ...
# 122   7   ccpa         R3   THR_Conc -0.280857
# 123   8   ccpa         R4   THR_Conc -0.300279
# 124   9     WT         R1   THR_Conc -0.318198
# 125  10     WT         R2   THR_Conc -0.330830
# 126  11     WT         R3   THR_Conc -0.181330
# 127  12     WT         R4   THR_Conc -0.174494
# 128   5   ccpa         R1   TRP_Conc -0.064660
# 129   6   ccpa         R2   TRP_Conc -0.074315
# 130   7   ccpa         R3   TRP_Conc -0.073935
# 131   8   ccpa         R4   TRP_Conc -0.070774
# 132   9     WT         R1   TRP_Conc -0.067804
# 133  10     WT         R2   TRP_Conc -0.076736
# 134  11     WT         R3   TRP_Conc -0.086507
# 135  12     WT         R4   TRP_Conc -0.081264
# 136   5   ccpa         R1   TYR_Conc -0.037607
# 137   6   ccpa         R2   TYR_Conc -0.045717
# 138   7   ccpa         R3   TYR_Conc -0.037492
# 139   8   ccpa         R4   TYR_Conc -0.036424
# 140   9     WT         R1   TYR_Conc -0.049333
# 141  10     WT         R2   TYR_Conc -0.049259
# 142  11     WT         R3   TYR_Conc -0.047637
# 143  12     WT         R4   TYR_Conc -0.046798
# 144   5   ccpa         R1   VAL_Conc -0.234797
# 145   6   ccpa         R2   VAL_Conc -0.237323
# 146   7   ccpa         R3   VAL_Conc -0.235792
# 147   8   ccpa         R4   VAL_Conc -0.256902
# 148   9     WT         R1   VAL_Conc -0.270326
# 149  10     WT         R2   VAL_Conc -0.275261
# 150  11     WT         R3   VAL_Conc -0.211141
# 151  12     WT         R4   VAL_Conc -0.211698
#
# [152 rows x 5 columns]

# %%
aafluxes_error = pd.read_csv("data\CcpA_chemostat\Fluxerror.txt")
aafluxes_error
# Out:
#    id strain reactornum  ALA_Conc  ARG_Conc  ASN_Conc  ASP_Conc  CYS_Conc  \
# 0   5   ccpa         R1  0.010077  0.019115  0.009985  0.000855  0.003797
# 1   6   ccpa         R2  0.008078  0.015978  0.008304  0.001619  0.004796
# 2   7   ccpa         R3  0.016651  0.016813  0.017128  0.004081  0.001077
# 3   8   ccpa         R4  0.006190  0.011491  0.007151  0.009626  0.041380
# 4   9     WT         R1  0.009102  0.051525  0.010762  0.013378  0.073961
# 5  10     WT         R2  0.011848  0.035866  0.012050  0.017140  0.047764
# 6  11     WT         R3  0.008516  0.037458  0.006128  0.000245  0.004905
# 7  12     WT         R4  0.012051  0.032704  0.006916  0.000558  0.007977
#
#    GLN_Conc  GLU_Conc  ...  LEU_Conc  LYS_Conc  MET_Conc  NOR_Conc  PHE_Conc  \
# 0  0.012419  0.000546  ...  0.008658  0.008295  0.002335       0.0  0.002428
# 1  0.010645  0.000043  ...  0.008570  0.006483  0.002577       0.0  0.001859
# 2  0.017805  0.000407  ...  0.017028  0.013335  0.004942       0.0  0.003789
# 3  0.089794  0.001633  ...  0.008498  0.018823  0.003891       0.0  0.002690
# 4  0.010022  0.001704  ...  0.011345  0.032783  0.002670       0.0  0.002209
# 5  0.019409  0.002908  ...  0.003664  0.024840  0.004472       0.0  0.003244
# 6  0.004296  0.002038  ...  0.007969  0.003929  0.001991       0.0  0.001898
# 7  0.006981  0.002063  ...  0.012997  0.004244  0.002884       0.0  0.002932
#
#    SER_Conc  THR_Conc  TRP_Conc  TYR_Conc  VAL_Conc
# 0  0.027538  0.016445  0.011132  0.002168  0.009753
# 1  0.020186  0.010767  0.012173  0.001224  0.007460
# 2  0.045563  0.023488  0.006103  0.002099  0.014721
# 3  0.035410  0.134327  0.004438  0.001726  0.010541
# 4  0.033535  0.037768  0.012057  0.001416  0.012536
# 5  0.016036  0.113185  0.005653  0.001301  0.016413
# 6  0.027825  0.005438  0.002808  0.001289  0.005702
# 7  0.042586  0.006205  0.003516  0.001580  0.006260
#
# [8 rows x 23 columns]

# %%
aaR_EX = [
    "R_EX_ala__D_e", #R_EX_ala__L_e
    "R_EX_arg__L_e",
    "R_EX_asn__L_e",
    "R_EX_asp__L_e",
    "R_EX_cys__L_e",
    "R_EX_gln__L_e",
    "R_EX_glu__L_e",
    "R_EX_gly_e",
    "R_EX_his__L_e",
    "R_EX_ile__L_e",
    "R_EX_leu__L_e",
    "R_EX_lys__L_e",
    "R_EX_met__L_e", #R_EX_met__D_e
    None, #NOR_Conc
    "R_EX_phe__L_e",
    "R_EX_ser__L_e", #R_EX_ser__D_e
    "R_EX_thr__L_e",
    "R_EX_trp__L_e",
    "R_EX_tyr__L_e",
    "R_EX_val__L_e"
]

# %%
aafluxmapping = dict()
for i, aa in enumerate(list(aafluxes.columns[3:])):
    aafluxmapping[aa] = aaR_EX[i]
#del(aafluxmapping['NOR_Conc'])
aafluxmapping
# Out:
# {'ALA_Conc': 'R_EX_ala__D_e',
#  'ARG_Conc': 'R_EX_arg__L_e',
#  'ASN_Conc': 'R_EX_asn__L_e',
#  'ASP_Conc': 'R_EX_asp__L_e',
#  'CYS_Conc': 'R_EX_cys__L_e',
#  'GLN_Conc': 'R_EX_gln__L_e',
#  'GLU_Conc': 'R_EX_glu__L_e',
#  'GLY_Conc': 'R_EX_gly_e',
#  'HIS_Conc': 'R_EX_his__L_e',
#  'ISO_Conc': 'R_EX_ile__L_e',
#  'LEU_Conc': 'R_EX_leu__L_e',
#  'LYS_Conc': 'R_EX_lys__L_e',
#  'MET_Conc': 'R_EX_met__L_e',
#  'PHE_Conc': None,
#  'SER_Conc': 'R_EX_phe__L_e',
#  'THR_Conc': 'R_EX_ser__L_e',
#  'TRP_Conc': 'R_EX_thr__L_e',
#  'TYR_Conc': 'R_EX_trp__L_e',
#  'VAL_Conc': 'R_EX_tyr__L_e'}

# %%
aafluxmapping2 = {y:x for x,y in aafluxmapping.iteritems()}
aafluxmapping2
# Out:
# {None: 'PHE_Conc',
#  'R_EX_ala__D_e': 'ALA_Conc',
#  'R_EX_arg__L_e': 'ARG_Conc',
#  'R_EX_asn__L_e': 'ASN_Conc',
#  'R_EX_asp__L_e': 'ASP_Conc',
#  'R_EX_cys__L_e': 'CYS_Conc',
#  'R_EX_gln__L_e': 'GLN_Conc',
#  'R_EX_glu__L_e': 'GLU_Conc',
#  'R_EX_gly_e': 'GLY_Conc',
#  'R_EX_his__L_e': 'HIS_Conc',
#  'R_EX_ile__L_e': 'ISO_Conc',
#  'R_EX_leu__L_e': 'LEU_Conc',
#  'R_EX_lys__L_e': 'LYS_Conc',
#  'R_EX_met__L_e': 'MET_Conc',
#  'R_EX_phe__L_e': 'SER_Conc',
#  'R_EX_ser__L_e': 'THR_Conc',
#  'R_EX_thr__L_e': 'TRP_Conc',
#  'R_EX_trp__L_e': 'TYR_Conc',
#  'R_EX_tyr__L_e': 'VAL_Conc'}

# %%
# Caluculate averages for aa fluxes and errors
aa_means = pd.DataFrame(columns = ["ccpa", "wt"])
aa_errors = pd.DataFrame(columns = ["ccpa", "wt"])
aafluxes_grouped = aafluxes.groupby("strain")
aa_means["ccpa"] = aafluxes_grouped.get_group("ccpa").iloc[:,1:].mean()
aa_means["wt"] = aafluxes_grouped.get_group("WT").iloc[:,1:].mean()

aa_errors['ccpa'] = aafluxes_grouped.get_group("ccpa").iloc[:,1:].std()
aa_errors['wt'] = aafluxes_grouped.get_group("WT").iloc[:,1:].std()

# %%
aa_means
# Out:
#               ccpa        wt
# ALA_Conc -0.310720 -0.308809
# ARG_Conc -0.776680 -0.687409
# ASN_Conc -0.247380 -0.247806
# ASP_Conc -0.071660 -0.127836
# CYS_Conc  0.031106  0.214652
# GLN_Conc -0.342104 -0.272644
# GLU_Conc -0.010904  0.015882
# GLY_Conc -0.063561 -0.087996
# HIS_Conc -0.002374  0.006781
# ISO_Conc -0.268178 -0.269981
# LEU_Conc -0.293658 -0.256490
# LYS_Conc -0.245592 -0.191773
# MET_Conc -0.077140 -0.069788
# PHE_Conc -0.068871 -0.080151
# SER_Conc -0.830275 -0.910353
# THR_Conc -0.285743 -0.251213
# TRP_Conc -0.070921 -0.078078
# TYR_Conc -0.039310 -0.048257
# VAL_Conc -0.241204 -0.242106

# %%
#aa_means.to_csv("data/CcpA_chemostat/aa_mean_fluxes.txt")
#aa_errors.to_csv("data/CcpA_chemostat/aa_stdev.txt")

# %% [markdown]
# ### Amino acid residual concentrations

# %%
aa_residuals = pd.read_csv("data/CcpA_chemostat/AA_residual_conc.txt")
aa_residuals
# Out:
#    id strain reactornum  ASP_Conc  GLU_Conc  ASN_Conc  SER_Conc  GLN_Conc  \
# 0   5   ccpa         R1  0.999900  0.679340  0.169140  0.127520  0.059940
# 1   6   ccpa         R2  0.960760  0.654520  0.163520  0.134480  0.041540
# 2   7   ccpa         R3  0.912125  0.644075  0.160850  0.137300  0.049125
# 3   8   ccpa         R4  0.728400  0.571340  0.144020  0.157980  0.018840
# 4   9     WT         R1  0.661217  0.592283  0.184683  0.210717  0.024383
# 5  10     WT         R2  0.624083  0.567100  0.184050  0.212450  0.024567
# 6  11     WT         R3  1.013700  0.787017  0.233717  0.161600  0.421200
# 7  12     WT         R4  0.992583  0.776483  0.238350  0.159767  0.417717
#
#    HIS_Conc  GLY_Conc  ...  TYR_Conc  CYS_Conc  VAL_Conc  MET_Conc  NOR_Conc  \
# 0  0.102600   0.22238  ...  0.208320  0.243480  0.311860  0.113160       0.0
# 1  0.101340   0.22204  ...  0.193220  0.260020  0.304640  0.110580       0.0
# 2  0.128425   0.25260  ...  0.208000  0.336575  0.306750  0.120125       0.0
# 3  0.268520   0.38890  ...  0.210620  0.771140  0.273320  0.118460       0.0
# 4  0.271817   0.40825  ...  0.196583  1.158967  0.299200  0.139633       0.0
# 5  0.220883   0.43610  ...  0.195933  1.181050  0.286967  0.144233       0.0
# 6  0.086133   0.07560  ...  0.202150  0.216417  0.407000  0.144733       0.0
# 7  0.087467   0.07415  ...  0.201317  0.228183  0.396483  0.145233       0.0
#
#    TRP_Conc  PHE_Conc  ISO_Conc  LEU_Conc  LYS_Conc
# 0  0.060020  0.268400  0.140040  0.341660  0.622860
# 1  0.041820  0.255520  0.142380  0.345820  0.598640
# 2  0.042300  0.265325  0.139200  0.364275  0.606325
# 3  0.049360  0.263500  0.144180  0.397680  0.496260
# 4  0.067217  0.251267  0.169633  0.499317  0.529700
# 5  0.051650  0.238717  0.156050  0.500700  0.512533
# 6  0.042283  0.276133  0.221767  0.469717  0.901700
# 7  0.046700  0.271567  0.230050  0.463950  0.917883
#
# [8 rows x 23 columns]

# %%
# Remove nor column, which is the internal standard
aa_residuals.drop(columns=["NOR_Conc"], inplace=True)

# Convert to long format for plotting
aa_residuals_long = pd.melt(aa_residuals, 
                            id_vars=['id','strain', 'reactornum'], 
                            var_name='amino_acid',
                            value_vars=aa_residuals.columns[3:22],
                            value_name='concentration')
aa_residuals_long #['id','strain', 'reactornum']
# Out:
#      id strain reactornum amino_acid  concentration
# 0     5   ccpa         R1   ASP_Conc       0.999900
# 1     6   ccpa         R2   ASP_Conc       0.960760
# 2     7   ccpa         R3   ASP_Conc       0.912125
# 3     8   ccpa         R4   ASP_Conc       0.728400
# 4     9     WT         R1   ASP_Conc       0.661217
# 5    10     WT         R2   ASP_Conc       0.624083
# 6    11     WT         R3   ASP_Conc       1.013700
# 7    12     WT         R4   ASP_Conc       0.992583
# 8     5   ccpa         R1   GLU_Conc       0.679340
# 9     6   ccpa         R2   GLU_Conc       0.654520
# 10    7   ccpa         R3   GLU_Conc       0.644075
# 11    8   ccpa         R4   GLU_Conc       0.571340
# 12    9     WT         R1   GLU_Conc       0.592283
# 13   10     WT         R2   GLU_Conc       0.567100
# 14   11     WT         R3   GLU_Conc       0.787017
# 15   12     WT         R4   GLU_Conc       0.776483
# 16    5   ccpa         R1   ASN_Conc       0.169140
# 17    6   ccpa         R2   ASN_Conc       0.163520
# 18    7   ccpa         R3   ASN_Conc       0.160850
# 19    8   ccpa         R4   ASN_Conc       0.144020
# 20    9     WT         R1   ASN_Conc       0.184683
# 21   10     WT         R2   ASN_Conc       0.184050
# 22   11     WT         R3   ASN_Conc       0.233717
# 23   12     WT         R4   ASN_Conc       0.238350
# 24    5   ccpa         R1   SER_Conc       0.127520
# 25    6   ccpa         R2   SER_Conc       0.134480
# 26    7   ccpa         R3   SER_Conc       0.137300
# 27    8   ccpa         R4   SER_Conc       0.157980
# 28    9     WT         R1   SER_Conc       0.210717
# 29   10     WT         R2   SER_Conc       0.212450
# ..   ..    ...        ...        ...            ...
# 122   7   ccpa         R3   PHE_Conc       0.265325
# 123   8   ccpa         R4   PHE_Conc       0.263500
# 124   9     WT         R1   PHE_Conc       0.251267
# 125  10     WT         R2   PHE_Conc       0.238717
# 126  11     WT         R3   PHE_Conc       0.276133
# 127  12     WT         R4   PHE_Conc       0.271567
# 128   5   ccpa         R1   ISO_Conc       0.140040
# 129   6   ccpa         R2   ISO_Conc       0.142380
# 130   7   ccpa         R3   ISO_Conc       0.139200
# 131   8   ccpa         R4   ISO_Conc       0.144180
# 132   9     WT         R1   ISO_Conc       0.169633
# 133  10     WT         R2   ISO_Conc       0.156050
# 134  11     WT         R3   ISO_Conc       0.221767
# 135  12     WT         R4   ISO_Conc       0.230050
# 136   5   ccpa         R1   LEU_Conc       0.341660
# 137   6   ccpa         R2   LEU_Conc       0.345820
# 138   7   ccpa         R3   LEU_Conc       0.364275
# 139   8   ccpa         R4   LEU_Conc       0.397680
# 140   9     WT         R1   LEU_Conc       0.499317
# 141  10     WT         R2   LEU_Conc       0.500700
# 142  11     WT         R3   LEU_Conc       0.469717
# 143  12     WT         R4   LEU_Conc       0.463950
# 144   5   ccpa         R1   LYS_Conc       0.622860
# 145   6   ccpa         R2   LYS_Conc       0.598640
# 146   7   ccpa         R3   LYS_Conc       0.606325
# 147   8   ccpa         R4   LYS_Conc       0.496260
# 148   9     WT         R1   LYS_Conc       0.529700
# 149  10     WT         R2   LYS_Conc       0.512533
# 150  11     WT         R3   LYS_Conc       0.901700
# 151  12     WT         R4   LYS_Conc       0.917883
#
# [152 rows x 5 columns]

# %%
aa_residuals_sem = pd.read_csv("data/CcpA_chemostat/AA_residual_conc_sem.txt")
aa_residuals_sem
# Out:
#    id strain reactornum  ASP_Conc  GLU_Conc  ASN_Conc  SER_Conc  GLN_Conc  \
# 0   5   ccpa         R1  0.046196  0.024624  0.005587  0.002778  0.001681
# 1   6   ccpa         R2  0.035971  0.016879  0.004417  0.001728  0.000971
# 2   7   ccpa         R3  0.054048  0.034319  0.010671  0.006947  0.002368
# 3   8   ccpa         R4  0.040397  0.017662  0.003396  0.006375  0.004730
# 4   9     WT         R1  0.038326  0.024715  0.007465  0.007806  0.000590
# 5  10     WT         R2  0.042569  0.029463  0.008412  0.003466  0.001203
# 6  11     WT         R3  0.018830  0.014523  0.004697  0.003978  0.009726
# 7  12     WT         R4  0.022077  0.020024  0.006785  0.007185  0.018828
#
#    HIS_Conc  GLY_Conc  ...  TYR_Conc  CYS_Conc  VAL_Conc  MET_Conc  NOR_Conc  \
# 0  0.003601  0.004352  ...  0.010865  0.014857  0.010452  0.001886       0.0
# 1  0.004624  0.011367  ...  0.003297  0.025294  0.007222  0.002756       0.0
# 2  0.020132  0.024488  ...  0.010728  0.060808  0.017951  0.007556       0.0
# 3  0.041467  0.034605  ...  0.009489  0.134559  0.010469  0.005812       0.0
# 4  0.036326  0.032718  ...  0.005436  0.169667  0.013683  0.005100       0.0
# 5  0.024227  0.013816  ...  0.004916  0.109474  0.016946  0.009410       0.0
# 6  0.002510  0.001591  ...  0.004449  0.012094  0.008927  0.003359       0.0
# 7  0.004874  0.002292  ...  0.006518  0.024272  0.011089  0.005941       0.0
#
#    TRP_Conc  PHE_Conc  ISO_Conc  LEU_Conc  LYS_Conc
# 0  0.010228  0.007323  0.003246  0.004809  0.017419
# 1  0.006795  0.003828  0.002900  0.006742  0.010961
# 2  0.003368  0.013764  0.008028  0.019774  0.032528
# 3  0.003009  0.009499  0.010159  0.010775  0.030908
# 4  0.011942  0.006268  0.005744  0.022889  0.056394
# 5  0.003781  0.008228  0.008802  0.006395  0.040227
# 6  0.001200  0.005859  0.004772  0.011568  0.042650
# 7  0.001970  0.010647  0.006384  0.022020  0.057993
#
# [8 rows x 23 columns]

# %%
# Caluculate averages for aa fluxes and errors
aa_residuals_mean = pd.DataFrame(columns = ["ccpa", "wt"])
aa_residual_errors = pd.DataFrame(columns = ["ccpa", "wt"])
aa_residuals_grouped = aa_residuals.groupby("strain")
aa_residuals_mean["ccpa"] = aa_residuals_grouped.get_group("ccpa").iloc[:,1:].mean()
aa_residuals_mean["wt"] = aa_residuals_grouped.get_group("WT").iloc[:,1:].mean()

aa_residual_errors['ccpa'] = aa_residuals_grouped.get_group("ccpa").iloc[:,1:].std()
aa_residual_errors['wt'] = aa_residuals_grouped.get_group("WT").iloc[:,1:].std()

# %%
aa_residuals_mean
# Out:
#               ccpa        wt
# ASP_Conc  0.900296  0.822896
# GLU_Conc  0.637319  0.680721
# ASN_Conc  0.159382  0.210200
# SER_Conc  0.139320  0.186133
# GLN_Conc  0.042361  0.221967
# HIS_Conc  0.150221  0.166575
# GLY_Conc  0.271480  0.248525
# THR_Conc  0.055619  0.168771
# ARG_Conc  0.000000  0.305737
# ALA_Conc  0.898815  0.967067
# TYR_Conc  0.205040  0.198996
# CYS_Conc  0.402804  0.696154
# VAL_Conc  0.299143  0.347413
# MET_Conc  0.115581  0.143458
# TRP_Conc  0.048375  0.051962
# PHE_Conc  0.263186  0.259421
# ISO_Conc  0.141450  0.194375
# LEU_Conc  0.362359  0.483421
# LYS_Conc  0.581021  0.715454

# %%
aa_residual_errors
# Out:
#               ccpa        wt
# ASP_Conc  0.120090  0.208859
# GLU_Conc  0.046406  0.117190
# ASN_Conc  0.010809  0.029891
# SER_Conc  0.013101  0.029405
# GLN_Conc  0.017404  0.228048
# HIS_Conc  0.079847  0.094436
# GLY_Conc  0.079580  0.200837
# THR_Conc  0.015570  0.141871
# ARG_Conc  0.000000  0.051172
# ALA_Conc  0.017322  0.004241
# TYR_Conc  0.007966  0.003190
# CYS_Conc  0.248884  0.547255
# VAL_Conc  0.017480  0.063079
# MET_Conc  0.004465  0.002582
# TRP_Conc  0.008494  0.010865
# PHE_Conc  0.005496  0.017531
# ISO_Conc  0.002263  0.036986
# LEU_Conc  0.025516  0.019306
# LYS_Conc  0.057404  0.224608

# %% [markdown]
# ### Plot uptake rate in WT and CcpA mutant per amino acid

# %%
# t-test difference in amino acid residual concentration
for aa in set(aa_residuals_long['amino_acid']):
    print aa
    print scipy.stats.ttest_ind(aa_residuals_grouped.get_group("ccpa")[aa], aa_residuals_grouped.get_group("WT")[aa],equal_var=False)[1]
# Out:
# ALA_Conc
# 0.0030822701218014598
# GLU_Conc
# 0.5296267822098517
# ASN_Conc
# 0.03583971806102024
# PHE_Conc
# 0.7051750037490923
# ISO_Conc
# 0.06419232041713951
# LYS_Conc
# 0.32125372169219696
# LEU_Conc
# 0.0003868006523852331
# GLN_Conc
# 0.21327551288715457
# HIS_Conc
# 0.8004982751530493
# TRP_Conc
# 0.6225684581881141
# CYS_Conc
# 0.3820335827762104
# THR_Conc
# 0.20889016202491464
# TYR_Conc
# 0.23275791308510504
# ASP_Conc
# 0.5500204202863064
# GLY_Conc
# 0.8422965814200729
# VAL_Conc
# 0.22495532355924855
# ARG_Conc
# 0.0012606126104459216
# MET_Conc
# 0.000148955042735196
# SER_Conc
# 0.04189029484342711

# %%
ax = sns.barplot(data=aa_residuals_long, hue='strain', x='amino_acid', y='concentration', capsize=.1, ci=None, order=aafluxes.columns[3:22], alpha=.5, hue_order=["WT", "ccpa"])
sns.stripplot(data=aa_residuals_long, hue='strain', x='amino_acid', y='concentration', dodge=True, alpha=1., size=4., order=aafluxes.columns[3:22], hue_order=["WT", "ccpa"])

ax.set_xticklabels(ax.get_xticklabels(), rotation=90, horizontalalignment='right')

labels = [item.get_text() for item in ax.get_xticklabels()]
labels = [item[0:3].lower() for item in labels]
labels[9] = 'ile' #was iso

ax.set_xticklabels(labels)
ax.set_xlabel("")
ax.set_ylabel("Residual concentration (mM)")

handles, labels = ax.get_legend_handles_labels()
labels[1] = 'CcpA'
labels[3] = 'CcpA'

ax.legend(handles[0:2], labels[0:2], markerscale=0.5, frameon=False) 
          
# statistical annotation; independent t-test, equal variance, p < 0.05

fontsizetext = 15

# ala
x1, x2 = 0, 0   
y, h, col = aa_residuals_long[aa_residuals_long['amino_acid']=='ALA_Conc']['concentration'].max()+0.02, 0.025, 'k'
#y=0.05
plt.plot([x1-0.2, x1-0.2, x2+0.2, x2+0.2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y +h, "*", ha='center', va='bottom', color=col, fontsize=fontsizetext)

# arg
x1, x2 = 1, 1   
y, h, col = aa_residuals_long[aa_residuals_long['amino_acid']=='ARG_Conc']['concentration'].max()+0.02, 0.025, 'k'
#y=0.05
plt.plot([x1-0.2, x1-0.2, x2+0.2, x2+0.2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y +h, "*", ha='center', va='bottom', color=col, fontsize=fontsizetext)

# asn
x1, x2 = 2, 2   
y, h, col = aa_residuals_long[aa_residuals_long['amino_acid']=='ASN_Conc']['concentration'].max()+0.02, 0.025, 'k'
#y=0.05
plt.plot([x1-0.2, x1-0.2, x2+0.2, x2+0.2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y +h, "*", ha='center', va='bottom', color=col, fontsize=fontsizetext)

# leu
x1, x2 = 10, 10   
y, h, col = aa_residuals_long[aa_residuals_long['amino_acid']=='LEU_Conc']['concentration'].max()+0.02, 0.025, 'k'
#y=0.05
plt.plot([x1-0.2, x1-0.2, x2+0.2, x2+0.2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y +h, "*", ha='center', va='bottom', color=col, fontsize=fontsizetext)

# met
x1, x2 = 12, 12   
y, h, col = aa_residuals_long[aa_residuals_long['amino_acid']=='MET_Conc']['concentration'].max()+0.02, 0.025, 'k'
#y=0.05
plt.plot([x1-0.2, x1-0.2, x2+0.2, x2+0.2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y +h, "*", ha='center', va='bottom', color=col, fontsize=fontsizetext)

#ser
x1, x2 = 14, 14   
y, h, col = aa_residuals_long[aa_residuals_long['amino_acid']=='SER_Conc']['concentration'].max()+0.02, 0.025, 'k'
#y=0.05
plt.plot([x1-0.2, x1-0.2, x2+0.2, x2+0.2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y +h, "*", ha='center', va='bottom', color=col, fontsize=fontsizetext) 


plt.savefig("Figures/aa_residuals_barplot.svg")
plt.savefig("Figures/aa_residuals_barplot.eps")
plt.savefig("Figures/aa_residuals_barplot.pdf")
plt.savefig("Figures/aa_residuals_barplot.png")

plt.show()

# %%
fig, ax = plt.subplots(figsize=(0.5,1.25))
ax = sns.barplot(data=aa_residuals_long[aa_residuals_long['amino_acid']=='ARG_Conc'], hue='strain', x='amino_acid', y='concentration', capsize=.1, ci=None,  alpha=.5, hue_order=["WT", "ccpa"], palette=[(55./255,126./255,184./255,1.),(255./255,127./255,0./255,1.)])
sns.stripplot(data=aa_residuals_long[aa_residuals_long['amino_acid']=='ARG_Conc'], hue='strain', x='amino_acid', y='concentration', dodge=True, alpha=1., size=4., hue_order=["WT", "ccpa"], palette=[(55./255,126./255,184./255,1.),(255./255,127./255,0./255,1.)])

ax.set_xticklabels([''])
ax.set_xticks([], [])

ax.set_xlabel("")

ax.set_ylabel("Residual arginine\n (mM)")

handles, labels = ax.get_legend_handles_labels()
labels[1] = 'CcpA'
labels[3] = 'CcpA'

ax.legend(handles[0:2], labels[0:2], markerscale=0.5, frameon=False) 
ax.legend().set_visible(False)

plt.savefig("Figures/arg_residuals_barplot.svg")
plt.savefig("Figures/arg_residuals_barplot.eps")
plt.savefig("Figures/arg_residuals_barplot.pdf")
plt.savefig("Figures/arg_residuals_barplot.png")

plt.show()

# %%
# t-test difference in amino acid flux 
for aa in set(aafluxes_long['amino_acid']):
    print aa
    print scipy.stats.ttest_ind(aafluxes_grouped.get_group("ccpa")[aa], aafluxes_grouped.get_group("WT")[aa],equal_var=False)[1]
# Out:
# ALA_Conc
# 0.7715427594874938
# GLU_Conc
# 0.5335230888097345
# ASN_Conc
# 0.9615956057657854
# PHE_Conc
# 0.09584637371124727
# ISO_Conc
# 0.863686321091866
# LYS_Conc
# 0.49716113784219984
# LEU_Conc
# 0.013463490569194428
# GLN_Conc
# 0.39060160161748597
# HIS_Conc
# 0.8134825220270895
# TRP_Conc
# 0.1798096365378573
# CYS_Conc
# 0.3741622771371951
# THR_Conc
# 0.47649600166741607
# TYR_Conc
# 0.021027681606539454
# ASP_Conc
# 0.47786284634383275
# GLY_Conc
# 0.7366653246205856
# VAL_Conc
# 0.9637336593781908
# ARG_Conc
# 0.02684132353693336
# MET_Conc
# 0.0038294485572382517
# SER_Conc
# 0.017987602019777123

# %%
ax = sns.barplot(data=aafluxes_long, hue='strain', x='amino_acid', y='flux', capsize=.1, ci=None, order=aafluxes.columns[3:22], alpha=.5, hue_order=["WT", "ccpa"], palette=[(55./255,126./255,184./255,1.),(255./255,127./255,0./255,1.)])
sns.stripplot(data=aafluxes_long, hue='strain', x='amino_acid', y='flux', dodge=True, alpha=1., size=4., order=aafluxes.columns[3:22], hue_order=["WT", "ccpa"], palette=[(55./255,126./255,184./255,1.),(255./255,127./255,0./255,1.)])

ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right', fontsize=12)

labels = [item.get_text() for item in ax.get_xticklabels()]
labels = [item[0:3].lower() for item in labels]
labels[9] = 'ile' #was iso

ax.set_xticklabels(labels)
ax.set_xlabel("")
ax.set_ylabel("Flux (mmol/gCDW/h)")

handles, labels = ax.get_legend_handles_labels()
labels[1] = 'CcpA'
labels[3] = 'CcpA'

ax.legend(handles[0:2], labels[0:2], markerscale=0.5, frameon=False) 

# statistical annotation; independent t-test, equal variance, p < 0.05

fontsizetext = 15

# arg
x1, x2 = 1, 1   
y, h, col = aafluxes_long['flux'].max(), 0.025, 'k'
y=0.02
plt.plot([x1-0.2, x1-0.2, x2+0.2, x2+0.2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y +h, "*", ha='center', va='bottom', color=col, fontsize=fontsizetext)

# tyr
x1, x2 = 17, 17   
y, h, col = aafluxes_long['flux'].max(), 0.025, 'k'
y=0.02
plt.plot([x1-0.2, x1-0.2, x2+0.2, x2+0.2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y +h, "*", ha='center', va='bottom', color=col, fontsize=fontsizetext)

# leu
x1, x2 = 10, 10   
y, h, col = aafluxes_long['flux'].max(), 0.025, 'k'
y=0.02
plt.plot([x1-0.2, x1-0.2, x2+0.2, x2+0.2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y +h, "*", ha='center', va='bottom', color=col, fontsize=fontsizetext)

# met
x1, x2 = 12, 12   
y, h, col = aafluxes_long['flux'].max(), 0.025, 'k'
y=0.02
plt.plot([x1-0.2, x1-0.2, x2+0.2, x2+0.2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y +h, "*", ha='center', va='bottom', color=col, fontsize=fontsizetext)

#ser
x1, x2 = 14, 14   
y, h, col = aafluxes_long['flux'].max(), 0.025, 'k'
y=0.02
plt.plot([x1-0.2, x1-0.2, x2+0.2, x2+0.2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y +h, "*", ha='center', va='bottom', color=col, fontsize=fontsizetext)
           
plt.savefig("Figures/aa_fluxes_barplot.svg")
plt.savefig("Figures/aa_fluxes_barplot.eps")
plt.savefig("Figures/aa_fluxes_barplot.pdf")
plt.savefig("Figures/aa_fluxes_barplot.svg")

plt.show()

# %%
# Organic acid fluxes
oafluxes = pd.read_csv("data/CcpA_chemostat/2018_05chemostats_wtccpa_fluxdata_organic_acids.txt", sep='\t')
oafluxes
# Out:
#   strain reactor   Acetate  Arabinose   Ethanol    Glucose    Lactate  \
# 0     WT      R1  2.386709        0.0  5.025169 -16.277510  25.196991
# 1     WT      R2  2.448445        0.0  5.833607 -15.912156  24.436461
# 2     WT      R3  2.420291        0.0  5.692875 -16.351165  25.346896
# 3     WT      R4  2.322344        0.0  6.259597 -16.488126  24.108254
# 4   ccpa      R1  2.806199        0.0  4.880751 -16.145828  23.035873
# 5   ccpa      R2  3.477015        0.0  7.028267 -15.755452  20.437781
# 6   ccpa      R3  3.182457        0.0  7.182044 -15.761175  19.905920
# 7   ccpa      R4  2.820720        0.0  6.154667 -15.768271  21.565950
#
#    Pyruvate  Succinate   Formate        unit
# 0  0.054782   0.022265  5.439403  mmol/gDW/h
# 1  0.050313   0.023790  5.574549  mmol/gDW/h
# 2  0.006554   0.021950  5.252737  mmol/gDW/h
# 3  0.006609   0.023183  4.935570  mmol/gDW/h
# 4  0.108878   0.017264  6.277405  mmol/gDW/h
# 5  0.113995   0.018644  8.076796  mmol/gDW/h
# 6  0.106734   0.021234  7.436295  mmol/gDW/h
# 7  0.097452   0.022930  6.746462  mmol/gDW/h

# %%
# Remove nor column, which is the internal standard
oafluxes.drop(columns=["Arabinose"], inplace=True)
oafluxes
# Out:
#   strain reactor   Acetate   Ethanol    Glucose    Lactate  Pyruvate  \
# 0     WT      R1  2.386709  5.025169 -16.277510  25.196991  0.054782
# 1     WT      R2  2.448445  5.833607 -15.912156  24.436461  0.050313
# 2     WT      R3  2.420291  5.692875 -16.351165  25.346896  0.006554
# 3     WT      R4  2.322344  6.259597 -16.488126  24.108254  0.006609
# 4   ccpa      R1  2.806199  4.880751 -16.145828  23.035873  0.108878
# 5   ccpa      R2  3.477015  7.028267 -15.755452  20.437781  0.113995
# 6   ccpa      R3  3.182457  7.182044 -15.761175  19.905920  0.106734
# 7   ccpa      R4  2.820720  6.154667 -15.768271  21.565950  0.097452
#
#    Succinate   Formate        unit
# 0   0.022265  5.439403  mmol/gDW/h
# 1   0.023790  5.574549  mmol/gDW/h
# 2   0.021950  5.252737  mmol/gDW/h
# 3   0.023183  4.935570  mmol/gDW/h
# 4   0.017264  6.277405  mmol/gDW/h
# 5   0.018644  8.076796  mmol/gDW/h
# 6   0.021234  7.436295  mmol/gDW/h
# 7   0.022930  6.746462  mmol/gDW/h

# %%
oafluxes = oafluxes.reset_index()
oafluxes
# Out:
#    index strain reactor   Acetate   Ethanol    Glucose    Lactate  Pyruvate  \
# 0      0     WT      R1  2.386709  5.025169 -16.277510  25.196991  0.054782
# 1      1     WT      R2  2.448445  5.833607 -15.912156  24.436461  0.050313
# 2      2     WT      R3  2.420291  5.692875 -16.351165  25.346896  0.006554
# 3      3     WT      R4  2.322344  6.259597 -16.488126  24.108254  0.006609
# 4      4   ccpa      R1  2.806199  4.880751 -16.145828  23.035873  0.108878
# 5      5   ccpa      R2  3.477015  7.028267 -15.755452  20.437781  0.113995
# 6      6   ccpa      R3  3.182457  7.182044 -15.761175  19.905920  0.106734
# 7      7   ccpa      R4  2.820720  6.154667 -15.768271  21.565950  0.097452
#
#    Succinate   Formate        unit
# 0   0.022265  5.439403  mmol/gDW/h
# 1   0.023790  5.574549  mmol/gDW/h
# 2   0.021950  5.252737  mmol/gDW/h
# 3   0.023183  4.935570  mmol/gDW/h
# 4   0.017264  6.277405  mmol/gDW/h
# 5   0.018644  8.076796  mmol/gDW/h
# 6   0.021234  7.436295  mmol/gDW/h
# 7   0.022930  6.746462  mmol/gDW/h

# %%
# Convert to long format for plotting
oafluxes_long = pd.melt(oafluxes, 
                            id_vars=['strain', 'reactor'], 
                            var_name='metabolite',
                            value_vars=oafluxes.columns[3:10],
                            value_name='flux')
oafluxes_long
# Out:
#    strain reactor metabolite       flux
# 0      WT      R1    Acetate   2.386709
# 1      WT      R2    Acetate   2.448445
# 2      WT      R3    Acetate   2.420291
# 3      WT      R4    Acetate   2.322344
# 4    ccpa      R1    Acetate   2.806199
# 5    ccpa      R2    Acetate   3.477015
# 6    ccpa      R3    Acetate   3.182457
# 7    ccpa      R4    Acetate   2.820720
# 8      WT      R1    Ethanol   5.025169
# 9      WT      R2    Ethanol   5.833607
# 10     WT      R3    Ethanol   5.692875
# 11     WT      R4    Ethanol   6.259597
# 12   ccpa      R1    Ethanol   4.880751
# 13   ccpa      R2    Ethanol   7.028267
# 14   ccpa      R3    Ethanol   7.182044
# 15   ccpa      R4    Ethanol   6.154667
# 16     WT      R1    Glucose -16.277510
# 17     WT      R2    Glucose -15.912156
# 18     WT      R3    Glucose -16.351165
# 19     WT      R4    Glucose -16.488126
# 20   ccpa      R1    Glucose -16.145828
# 21   ccpa      R2    Glucose -15.755452
# 22   ccpa      R3    Glucose -15.761175
# 23   ccpa      R4    Glucose -15.768271
# 24     WT      R1    Lactate  25.196991
# 25     WT      R2    Lactate  24.436461
# 26     WT      R3    Lactate  25.346896
# 27     WT      R4    Lactate  24.108254
# 28   ccpa      R1    Lactate  23.035873
# 29   ccpa      R2    Lactate  20.437781
# 30   ccpa      R3    Lactate  19.905920
# 31   ccpa      R4    Lactate  21.565950
# 32     WT      R1   Pyruvate   0.054782
# 33     WT      R2   Pyruvate   0.050313
# 34     WT      R3   Pyruvate   0.006554
# 35     WT      R4   Pyruvate   0.006609
# 36   ccpa      R1   Pyruvate   0.108878
# 37   ccpa      R2   Pyruvate   0.113995
# 38   ccpa      R3   Pyruvate   0.106734
# 39   ccpa      R4   Pyruvate   0.097452
# 40     WT      R1  Succinate   0.022265
# 41     WT      R2  Succinate   0.023790
# 42     WT      R3  Succinate   0.021950
# 43     WT      R4  Succinate   0.023183
# 44   ccpa      R1  Succinate   0.017264
# 45   ccpa      R2  Succinate   0.018644
# 46   ccpa      R3  Succinate   0.021234
# 47   ccpa      R4  Succinate   0.022930
# 48     WT      R1    Formate   5.439403
# 49     WT      R2    Formate   5.574549
# 50     WT      R3    Formate   5.252737
# 51     WT      R4    Formate   4.935570
# 52   ccpa      R1    Formate   6.277405
# 53   ccpa      R2    Formate   8.076796
# 54   ccpa      R3    Formate   7.436295
# 55   ccpa      R4    Formate   6.746462

# %%
# Caluculate averages for oa fluxes and errors
oa_means = pd.DataFrame(columns = ["ccpa", "wt"])
oa_errors = pd.DataFrame(columns = ["ccpa", "wt"])
oafluxes_grouped = oafluxes.groupby("strain")
oa_means["ccpa"] = oafluxes_grouped.get_group("ccpa").iloc[:,1:].mean()
oa_means["wt"] = oafluxes_grouped.get_group("WT").iloc[:,1:].mean()

oa_errors['ccpa'] = oafluxes_grouped.get_group("ccpa").iloc[:,1:].std()
oa_errors['wt'] = oafluxes_grouped.get_group("WT").iloc[:,1:].std()

# %%
oa_means
# Out:
#                 ccpa         wt
# Acetate     3.071598   2.394447
# Ethanol     6.311432   5.702812
# Glucose   -15.857681 -16.257239
# Lactate    21.236381  24.772150
# Pyruvate    0.106765   0.029564
# Succinate   0.020018   0.022797
# Formate     7.134239   5.300565

# %%
oa_errors
# Out:
#                ccpa        wt
# Acetate    0.321470  0.054291
# Ethanol    1.055658  0.511994
# Glucose    0.192169  0.246051
# Lactate    1.385000  0.595614
# Pyruvate   0.006915  0.026602
# Succinate  0.002545  0.000844
# Formate    0.788287  0.276798

# %%
# t-test difference in external metabolite flux 
for aa in set(oafluxes_long['metabolite']):
    print aa
    print scipy.stats.ttest_ind(oafluxes_grouped.get_group("ccpa")[aa], oafluxes_grouped.get_group("WT")[aa],equal_var=True)[1]
# Out:
# Formate
# 0.0046202046094675235
# Pyruvate
# 0.0013588515186135945
# Acetate
# 0.005984212165984262
# Ethanol
# 0.33950296665614504
# Lactate
# 0.0033592188017089724
# Succinate
# 0.08356783152989045
# Glucose
# 0.042931351524388116

# %%
# t-test difference in external metabolite flux 
for aa in set(oafluxes_long['metabolite']):
    print aa
    print scipy.stats.ttest_ind(oafluxes_grouped.get_group("ccpa")[aa], oafluxes_grouped.get_group("WT")[aa],equal_var=False)[1]
# Out:
# Formate
# 0.013767209630600607
# Pyruvate
# 0.007883881960291399
# Acetate
# 0.022749813346976316
# Ethanol
# 0.35385113974194665
# Lactate
# 0.008972082546746689
# Succinate
# 0.11353017571871575
# Glucose
# 0.0451761230753081

# %%
oafluxes_long

ax = sns.barplot(data=oafluxes_long, hue='strain', x='metabolite', y='flux', capsize=.1, ci=None, alpha=.5)
sns.stripplot(data=oafluxes_long, hue='strain', x='metabolite', y='flux', dodge=True, alpha=1., size=4.)

ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

#labels = [item.get_text() for item in ax.get_xticklabels()]
#labels = [item[0:3].lower() for item in labels]
#labels[9] = 'ile' #was iso

#ax.set_xticklabels(labels)
ax.set_xlabel("")
ax.set_ylabel("Flux (mmol/gCDW/h)")

handles, labels = ax.get_legend_handles_labels()
labels[1] = 'CcpA'

ax.legend(handles[0:2], labels[0:2], markerscale=0.5, frameon=False)
           
# statistical annotation; independent t-test, equal variance, p < 0.05

fontsizetext = 15

# ace
x1, x2 = 0, 0
y, h, col = oafluxes_long[oafluxes_long['metabolite']=='Acetate']['flux'].max()+1., 1., 'k'
#y=0.02
plt.plot([x1-0.2, x1-0.2, x2+0.2, x2+0.2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y , "*", ha='center', va='bottom', color=col, fontsize=fontsizetext)

# glc
x1, x2 = 2, 2
y, h, col = 0.+1., 1., 'k'
#y=0.02
plt.plot([x1-0.2, x1-0.2, x2+0.2, x2+0.2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y , "*", ha='center', va='bottom', color=col, fontsize=fontsizetext)

# lac
x1, x2 = 3, 3
y, h, col = oafluxes_long[oafluxes_long['metabolite']=='Lactate']['flux'].max()+1., 1., 'k'
#y=0.02
plt.plot([x1-0.2, x1-0.2, x2+0.2, x2+0.2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y , "*", ha='center', va='bottom', color=col, fontsize=fontsizetext)

# pyr
x1, x2 = 4, 4
y, h, col = oafluxes_long[oafluxes_long['metabolite']=='Pyruvate']['flux'].max()+1., 1., 'k'
#y=0.02
plt.plot([x1-0.2, x1-0.2, x2+0.2, x2+0.2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y , "*", ha='center', va='bottom', color=col, fontsize=fontsizetext)

# for
x1, x2 = 6, 6
y, h, col = oafluxes_long[oafluxes_long['metabolite']=='Formate']['flux'].max()+1., 1., 'k'
#y=0.02
plt.plot([x1-0.2, x1-0.2, x2+0.2, x2+0.2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y, "*", ha='center', va='bottom', color=col, fontsize=fontsizetext)

plt.savefig("Figures/oafluxes_barplot.svg", bbox_inches = 'tight')
plt.savefig("Figures/oafluxes_barplot.eps", bbox_inches = 'tight')
plt.savefig("Figures/oafluxes_barplot.png", bbox_inches = 'tight')
plt.savefig("Figures/oafluxes_barplot.pdf", bbox_inches = 'tight')

plt.show()

# %% [markdown]
# <a id='pca'></a>

# %% [markdown]
# # 7. Principal Component analysis

# %%
# Select LFQ data
#LFQ data is already log10 transformed, so no standardization step is done in the following
data_LFQ = preprocessed_data[LFQ_columns] 
data_LFQ.head()
# Out:
#                      LFQ intensity BvO325_ccpa_MG1363_1  \
# Majority protein IDs
# A2RH74                                 7.10085296630859
# A2RH77                                 6.71917390823364
# A2RH80                                 8.33607959747314
# A2RH85                                 6.60785150527954
# A2RH86                                 6.63816976547241
#
#                      LFQ intensity BvO326_ccpa_MG1363_2  \
# Majority protein IDs
# A2RH74                                 7.24870872497559
# A2RH77                                 6.74067831039429
# A2RH80                                 8.33189296722412
# A2RH85                                  6.4954195022583
# A2RH86                                 6.88871288299561
#
#                      LFQ intensity BvO327_ccpa_MG1363_3  \
# Majority protein IDs
# A2RH74                                 7.14429378509521
# A2RH77                                 6.78864192962646
# A2RH80                                 8.33817768096924
# A2RH85                                 6.38399457931519
# A2RH86                                  6.7448091506958
#
#                      LFQ intensity BvO328_ccpa_MG1363_4  \
# Majority protein IDs
# A2RH74                                 7.12968969345093
# A2RH77                                  6.8233437538147
# A2RH80                                 8.37763404846191
# A2RH85                                 6.56883525848389
# A2RH86                                  6.7226505279541
#
#                      LFQ intensity BvO329_wt_MG1363_1  \
# Majority protein IDs
# A2RH74                               7.30323934555054
# A2RH77                               6.82106113433838
# A2RH80                               8.35715293884277
# A2RH85                               6.69289064407349
# A2RH86                               7.00509452819824
#
#                      LFQ intensity BvO330_wt_MG1363_2  \
# Majority protein IDs
# A2RH74                               7.25556182861328
# A2RH77                               6.78719806671143
# A2RH80                               8.41195583343506
# A2RH85                               6.35147190093994
# A2RH86                               6.90873146057129
#
#                      LFQ intensity BvO331_wt_MG1363_3  \
# Majority protein IDs
# A2RH74                               7.28990077972412
# A2RH77                                6.7553334236145
# A2RH80                               8.30541610717773
# A2RH85                               6.39392614364624
# A2RH86                               6.65474414825439
#
#                      LFQ intensity BvO332_wt_MG1363_4
# Majority protein IDs
# A2RH74                               7.30323934555054
# A2RH77                               6.92593574523926
# A2RH80                               8.27216625213623
# A2RH85                               6.67344856262207
# A2RH86                                6.8839225769043

# %%
# Select features
features = list(data_LFQ.index)
#print features

# Select data
x = data_LFQ.transpose().loc[:, features].values
#print x

# Seperate target values
y = ['ccpa', 'ccpa', 'ccpa', 'ccpa', 'WT', 'WT', 'WT', 'WT']

# %%
# Do PCA
pca = PCA()#n_components=4)
principalComponents = pca.fit_transform(x)

principalDF = pd.DataFrame(data=principalComponents) #, columns=['PC1', 'PC2'])
print principalDF

principalDF['strain'] = y #pd.concat([principalDF, y], axis=1)
finalDF = principalDF.copy()
finalDF
# Out:
#           0         1         2         3         4         5         6  \
# 0 -4.649852 -0.525040  1.074351  1.107646 -0.961320  2.181881 -0.729915
# 1 -4.751315  0.117532  0.108498  0.448772  0.026442 -0.286397  2.424225
# 2 -4.634163  0.591953 -0.781009 -1.213204 -2.069105 -1.541414 -0.901756
# 3 -4.176695  0.747103 -0.879369 -0.521916  3.071853 -0.166301 -0.804067
# 4  4.752826 -0.007721 -2.689083  2.902657 -0.208531 -0.375219 -0.202101
# 5  5.012296 -1.694012 -1.894195 -2.663291 -0.225683  1.069349  0.419229
# 6  3.145881 -3.909494  2.938802  0.299033  0.428016 -0.949046 -0.248824
# 7  5.301021  4.679680  2.122005 -0.359697 -0.061673  0.067147  0.043209
#
#               7
# 0  2.061800e-14
# 1  2.061800e-14
# 2  2.061800e-14
# 3  2.061800e-14
# 4  2.061800e-14
# 5  2.061800e-14
# 6  2.061800e-14
# 7  2.061800e-14
#           0         1         2         3         4         5         6  \
# 0 -4.649852 -0.525040  1.074351  1.107646 -0.961320  2.181881 -0.729915
# 1 -4.751315  0.117532  0.108498  0.448772  0.026442 -0.286397  2.424225
# 2 -4.634163  0.591953 -0.781009 -1.213204 -2.069105 -1.541414 -0.901756
# 3 -4.176695  0.747103 -0.879369 -0.521916  3.071853 -0.166301 -0.804067
# 4  4.752826 -0.007721 -2.689083  2.902657 -0.208531 -0.375219 -0.202101
# 5  5.012296 -1.694012 -1.894195 -2.663291 -0.225683  1.069349  0.419229
# 6  3.145881 -3.909494  2.938802  0.299033  0.428016 -0.949046 -0.248824
# 7  5.301021  4.679680  2.122005 -0.359697 -0.061673  0.067147  0.043209
#
#               7 strain
# 0  2.061800e-14   ccpa
# 1  2.061800e-14   ccpa
# 2  2.061800e-14   ccpa
# 3  2.061800e-14   ccpa
# 4  2.061800e-14     WT
# 5  2.061800e-14     WT
# 6  2.061800e-14     WT
# 7  2.061800e-14     WT

# %%
# Principal components percentage of explanation of data
pca.explained_variance_ratio_
# Out:
# array([5.86193062e-01, 1.43231568e-01, 9.20397706e-02, 6.56582809e-02,
#        5.18176976e-02, 3.27624570e-02, 2.82971641e-02, 1.18081997e-29])

# %%
# PCA figure of LFQ data
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1' + ' (' + str(round(pca.explained_variance_ratio_[0]*100, 1)) + '%)', fontsize = 15)
ax.set_ylabel('Principal Component 2' + ' (' + str(round(pca.explained_variance_ratio_[1]*100, 1)) + '%)', fontsize = 15)
#ax.set_title('2 component PCA', fontsize = 20)
strains = ['WT', 'ccpa']
#colors = ['r', 'b']
#for strain, color in zip(strains,colors):
for strain in strains:
    indicesToKeep = finalDF['strain'] == strain
    ax.scatter(finalDF.loc[indicesToKeep, 0]
               , finalDF.loc[indicesToKeep, 1]
               #, c = color
               , s = 50)
ax.legend(["WT", "CcpA"])
ax.grid()

fig.savefig('Figures/pca_LFQdata.svg')
